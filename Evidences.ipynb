# %%
import pandas as pd

# %%
df1 = pd.read_csv('01-Dec-2017-ClinicalEvidenceSummaries.csv')
df1
# Out:
#         gene  entrez_id           variant  \
# 0       JAK2       3717             V617F
# 1     PDGFRA       5156             D842V
# 2     DNMT3A       1788              R882
# 3     DNMT3A       1788              R882
# 4       JAK2       3717             V617F
# ...      ...        ...               ...
# 2345   BRCA1        672  LOSS-OF-FUNCTION
# 2346   RAD50      10111            L1237F
# 2347     MET       4233    OVEREXPRESSION
# 2348    PTEN       5728              LOSS
# 2349  ERRFI1      54206           E384Ter
#
#                                    disease     doid               drugs  \
# 0                        Lymphoid Leukemia  10747.0                 NaN
# 1           Gastrointestinal Stromal Tumor   9253.0                 NaN
# 2                   Acute Myeloid Leukemia   9119.0                 NaN
# 3                   Acute Myeloid Leukemia   9119.0                 NaN
# 4                 Chronic Myeloid Leukemia   8552.0                 NaN
# ...

# %%
df2 = pd.read_csv('01-Dec-2018-ClinicalEvidenceSummaries.csv')
df2
# Out:
#         gene  entrez_id        variant                         disease  \
# 0       JAK2       3717          V617F               Lymphoid Leukemia
# 1     PDGFRA       5156          D842V  Gastrointestinal Stromal Tumor
# 2     DNMT3A       1788           R882          Acute Myeloid Leukemia
# 3     DNMT3A       1788           R882          Acute Myeloid Leukemia
# 4       JAK2       3717          V617F        Chronic Myeloid Leukemia
# ...      ...        ...            ...                             ...
# 2922    BRAF        673          V600K                        Melanoma
# 2923    BRAF        673           V600                        Melanoma
# 2924    ABL1         25  BCR-ABL F359V        Chronic Myeloid Leukemia
# 2925    ABL1         25  BCR-ABL E255V        Chronic Myeloid Leukemia
# 2926    ABL1         25          C475V        Chronic Myeloid Leukemia
#
#          doid phenotypes                        drugs drug_interaction_type  \
# ...

# %%
df = pd.merge(df1, df2, right_index=True, left_index=True, how = 'outer')
df
df.to_csv('df.csv', index=False)

# %%
df3 = pd.read_csv('01-Dec-2019-ClinicalEvidenceSummaries.csv')
df3
# Out:
#         gene  entrez_id       variant                            disease  \
# 0       JAK2       3717         V617F                  Lymphoid Leukemia
# 1     PDGFRA       5156         D842V     Gastrointestinal Stromal Tumor
# 2     DNMT3A       1788          R882             Acute Myeloid Leukemia
# 3     DNMT3A       1788          R882             Acute Myeloid Leukemia
# 4       JAK2       3717         V617F           Chronic Myeloid Leukemia
# ...      ...        ...           ...                                ...
# 2852     RET       5979         M918T  Thyroid Gland Medullary Carcinoma
# 2853    IDH1       3417      MUTATION                     Chondrosarcoma
# 2854    IDH2       3418      MUTATION                     Chondrosarcoma
# 2855    BRAF        673  N486_P490del                  Pancreatic Cancer
# 2856    BRAF        673         D594G                             Cancer
#
#          doid phenotypes         drugs drug_interaction_type evidence_type  \
# ...

# %%
df = pd.merge(df, df3, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# 2     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 3     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 4       JAK2       3717.0     V617F        Chronic Myeloid Leukemia   8552.0
# ...      ...          ...       ...                             ...      ...
# 2922     NaN          NaN       NaN                             NaN      NaN
# 2923     NaN          NaN       NaN                             NaN      NaN
# 2924     NaN          NaN       NaN                             NaN      NaN
# 2925     NaN          NaN       NaN                             NaN      NaN
# 2926     NaN          NaN       NaN                             NaN      NaN
#
# ...

# %%
df4 = pd.read_csv('01-Dec-2020-ClinicalEvidenceSummaries.csv')
df4
# Out:
#         gene  entrez_id        variant  \
# 0       JAK2       3717          V617F
# 1     PDGFRA       5156          D842V
# 2     DNMT3A       1788           R882
# 3     DNMT3A       1788           R882
# 4       JAK2       3717          V617F
# ...      ...        ...            ...
# 3635   FOXO1       2308     PAX7-FOXO1
# 3636   NTRK3       4916     ETV6-NTRK3
# 3637    NRAS       4893           Q61K
# 3638    BRAF        673  KIAA1549-BRAF
# 3639    BRAF        673  KIAA1549-BRAF
#
#                                             disease     doid phenotypes  \
# 0                                 Lymphoid Leukemia   1037.0        NaN
# 1                    Gastrointestinal Stromal Tumor   9253.0        NaN
# 2                            Acute Myeloid Leukemia   9119.0        NaN
# 3                            Acute Myeloid Leukemia   9119.0        NaN
# 4                          Chronic Myeloid Leukemia   8552.0        NaN
# ...

# %%
df = pd.merge(df, df4, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/3337349739.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'ensembl_version_x', 'evidence_type_x', 'chromosome_x', 'clinical_significance_x', 'stop2_x', 'variant_summary_x', 'representative_transcript_x', 'evidence_civic_url_x', 'entrez_id_x', 'disease_x', 'doid_x', 'variant_origin_x', 'reference_bases_x', 'evidence_status_x', 'representative_transcript2_x', 'chromosome2_x', 'start_x', 'drugs_x', 'gene_civic_url_x', 'variant_civic_url_x', 'variant_x', 'evidence_level_x', 'gene_id_x', 'evidence_id_x', 'citation_x', 'variant_id_x', 'evidence_direction_x', 'rating_x', 'stop_x', 'reference_build_x', 'gene_x', 'evidence_statement_x', 'variant_bases_x', 'start2_x', 'last_review_date_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df4, right_index=True, left_index=True, how = 'outer')
# ...

# %%
df5 = pd.read_csv('01-Dec-2021-ClinicalEvidenceSummaries.csv')
df5
# Out:
#         gene  entrez_id variant                         disease    doid  \
# 0       JAK2       3717   V617F               Lymphoid Leukemia  1037.0
# 1     PDGFRA       5156   D842V  Gastrointestinal Stromal Tumor  9253.0
# 2     DNMT3A       1788    R882          Acute Myeloid Leukemia  9119.0
# 3     DNMT3A       1788    R882          Acute Myeloid Leukemia  9119.0
# 4       JAK2       3717   V617F        Chronic Myeloid Leukemia  8552.0
# ...      ...        ...     ...                             ...     ...
# 3840    TP53       7157   R342P                             NaN     NaN
# 3841    TP53       7157   L330P                             NaN     NaN
# 3842    TP53       7157   L330R                             NaN     NaN
# 3843    TP53       7157   R337P                             NaN     NaN
# 3844    TP53       7157   L344P                             NaN     NaN
#
#      phenotypes drugs drug_interaction_type evidence_type evidence_direction  \
# ...

# %%
df = pd.merge(df, df5, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/3575292880.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'drug_interaction_type_x', 'nct_ids_x', 'phenotypes_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df5, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# 2     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 3     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 4       JAK2       3717.0     V617F        Chronic Myeloid Leukemia   8552.0
# ...      ...          ...       ...                             ...      ...
# 3840     NaN          NaN       NaN                             NaN      NaN
# ...

# %%
df6 = pd.read_csv('01-Feb-2016-ClinicalEvidenceSummaries.csv')
df6
# Out:
#        gene  entrez_id        variant                         disease  \
# 0      JAK2     3717.0          V617F               Lymphoid Leukemia
# 1    PDGFRA     5156.0          D842V  Gastrointestinal Stromal Tumor
# 2    DNMT3A     1788.0           R882          Acute Myeloid Leukemia
# 3    DNMT3A     1788.0           R882          Acute Myeloid Leukemia
# 4      JAK2     3717.0          V617F        Chronic Myeloid Leukemia
# ..      ...        ...            ...                             ...
# 977     ALK      238.0       EML4-ALK      Lung Acinar Adenocarcinoma
# 978   ERBB2     2064.0  AMPLIFICATION                   Breast Cancer
# 979   BRCA1      672.0        P1018FS                   Breast Cancer
# 980   BRCA1      672.0        P1018FS                  Ovarian Cancer
# 981   ERBB2     2064.0    M774INSAYVM             Lung Adenocarcinoma
#
#         doid        drugs pubchem_ids evidence_type evidence_direction  \
# ...

# %%
df = pd.merge(df, df6, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/788311426.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'entrez_id_x', 'disease_x', 'variant_x', 'gene_x', 'doid_x', 'evidence_direction_x', 'evidence_type_x', 'citation_x', 'clinical_significance_x', 'drugs_x', 'rating_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df6, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# 2     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 3     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 4       JAK2       3717.0     V617F        Chronic Myeloid Leukemia   8552.0
# ...

# %%
df7 = pd.read_csv('01-Feb-2017-ClinicalEvidenceSummaries.csv')
df7
# Out:
#         gene  entrez_id                   variant  \
# 0       JAK2       3717                     V617F
# 1     PDGFRA       5156                     D842V
# 2     DNMT3A       1788                      R882
# 3     DNMT3A       1788                      R882
# 4       JAK2       3717                     V617F
# ...      ...        ...                       ...
# 1693   FGFR1       2260             AMPLIFICATION
# 1694   FGFR2       2263                    FUSION
# 1695     VHL       7428  M54Ifs (162_166DELGGAGG)
# 1696    TSC1       7248                    R1062W
# 1697    AKT3      10000              UPREGULATION
#
#                              disease     doid    drugs evidence_type  \
# 0                  Lymphoid Leukemia  10747.0      NaN    Diagnostic
# 1     Gastrointestinal Stromal Tumor   9253.0      NaN    Diagnostic
# 2             Acute Myeloid Leukemia   9119.0      NaN    Diagnostic
# 3             Acute Myeloid Leukemia   9119.0      NaN    Diagnostic
# ...

# %%
df = pd.merge(df, df7, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/1400683469.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'ensembl_version_x', 'chromosome_x', 'stop2_x', 'variant_summary_x', 'representative_transcript_x', 'evidence_civic_url_x', 'variant_origin_x', 'reference_bases_x', 'evidence_status_x', 'representative_transcript2_x', 'chromosome2_x', 'start_x', 'gene_civic_url_x', 'variant_civic_url_x', 'evidence_level_x', 'gene_id_x', 'evidence_id_x', 'variant_id_x', 'stop_x', 'reference_build_x', 'evidence_statement_x', 'pubmed_id_x', 'variant_bases_x', 'start2_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df7, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# ...

# %%
df8 = pd.read_csv('01-Feb-2018-ClinicalEvidenceSummaries.csv')
df8
# Out:
#         gene  entrez_id        variant                           disease  \
# 0       JAK2       3717          V617F                 Lymphoid Leukemia
# 1     PDGFRA       5156          D842V    Gastrointestinal Stromal Tumor
# 2     DNMT3A       1788           R882            Acute Myeloid Leukemia
# 3     DNMT3A       1788           R882            Acute Myeloid Leukemia
# 4       JAK2       3717          V617F          Chronic Myeloid Leukemia
# ...      ...        ...            ...                               ...
# 2494   ERBB2       2064  AMPLIFICATION                 Pancreatic Cancer
# 2495   ERBB2       2064  AMPLIFICATION                    Uterine Cancer
# 2496    IDH1       3417          R132H  Pancreatic Ductal Adenocarcinoma
# 2497    BCL2        596       MUTATION               Follicular Lymphoma
# 2498    TLK2      11011  AMPLIFICATION                     Breast Cancer
#
#          doid                   drugs evidence_type evidence_direction  \
# ...

# %%
df = pd.merge(df, df8, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/223680818.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'entrez_id_x', 'disease_x', 'variant_x', 'gene_x', 'doid_x', 'evidence_direction_x', 'evidence_type_x', 'citation_x', 'clinical_significance_x', 'drugs_x', 'rating_x', 'last_review_date_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df8, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# 2     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 3     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 4       JAK2       3717.0     V617F        Chronic Myeloid Leukemia   8552.0
# ...

# %%
df9 = pd.read_csv('01-Feb-2019-ClinicalEvidenceSummaries.csv')
df9
# Out:
#         gene  entrez_id        variant                         disease  \
# 0       JAK2       3717          V617F               Lymphoid Leukemia
# 1     PDGFRA       5156          D842V  Gastrointestinal Stromal Tumor
# 2     DNMT3A       1788           R882          Acute Myeloid Leukemia
# 3     DNMT3A       1788           R882          Acute Myeloid Leukemia
# 4       JAK2       3717          V617F        Chronic Myeloid Leukemia
# ...      ...        ...            ...                             ...
# 2691    ABL1         25  BCR-ABL F359V        Chronic Myeloid Leukemia
# 2692    ABL1         25  BCR-ABL L248V        Chronic Myeloid Leukemia
# 2693    ABL1         25  BCR-ABL F317L        Chronic Myeloid Leukemia
# 2694    ABL1         25  BCR-ABL E459K        Chronic Myeloid Leukemia
# 2695     RET       5979     EXPRESSION             Lung Adenocarcinoma
#
#          doid phenotypes              drugs drug_interaction_type  \
# ...

# %%
df = pd.merge(df, df9, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/1959774139.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'ensembl_version_x', 'chromosome_x', 'stop2_x', 'variant_summary_x', 'representative_transcript_x', 'evidence_civic_url_x', 'variant_origin_x', 'reference_bases_x', 'evidence_status_x', 'representative_transcript2_x', 'chromosome2_x', 'start_x', 'gene_civic_url_x', 'variant_civic_url_x', 'evidence_level_x', 'source_type_x', 'gene_id_x', 'evidence_id_x', 'variant_id_x', 'citation_id_x', 'stop_x', 'reference_build_x', 'evidence_statement_x', 'variant_bases_x', 'asco_abstract_id_x', 'start2_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df9, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# ...

# %%
df10 = pd.read_csv('01-Jun-2021-ClinicalEvidenceSummaries.csv')
df10
# Out:
#          gene  entrez_id     variant                            disease  \
# 0        JAK2       3717       V617F                  Lymphoid Leukemia
# 1      PDGFRA       5156       D842V     Gastrointestinal Stromal Tumor
# 2      DNMT3A       1788        R882             Acute Myeloid Leukemia
# 3      DNMT3A       1788        R882             Acute Myeloid Leukemia
# 4        JAK2       3717       V617F           Chronic Myeloid Leukemia
# ...       ...        ...         ...                                ...
# 3788  PPP2R1A       5518       P179R                                NaN
# 3789     ABL1         25  RCSD1-ABL1  B-lymphoblastic Leukemia/lymphoma
# 3790   CDKN1A       1026   rs1059234                     Retinoblastoma
# 3791     TP53       7157       P250L                                NaN
# 3792     TP53       7157       A161T                                NaN
#
#          doid phenotypes      drugs drug_interaction_type evidence_type  \
# ...

# %%
df = pd.merge(df, df10, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/1798698559.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'entrez_id_x', 'disease_x', 'nct_ids_x', 'variant_x', 'gene_x', 'doid_x', 'evidence_direction_x', 'drug_interaction_type_x', 'evidence_type_x', 'citation_x', 'clinical_significance_x', 'drugs_x', 'rating_x', 'last_review_date_x', 'phenotypes_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df10, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# 2     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 3     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# ...

# %%
df11 = pd.read_csv('01-Feb-2020-ClinicalEvidenceSummaries.csv')
df11
# Out:
#         gene  entrez_id         variant                               disease  \
# 0       JAK2       3717           V617F                     Lymphoid Leukemia
# 1     PDGFRA       5156           D842V        Gastrointestinal Stromal Tumor
# 2     DNMT3A       1788            R882                Acute Myeloid Leukemia
# 3     DNMT3A       1788            R882                Acute Myeloid Leukemia
# 4       JAK2       3717           V617F              Chronic Myeloid Leukemia
# ...      ...        ...             ...                                   ...
# 2917   NT5C2      22978  NT5C2 MUTATION  Childhood Acute Lymphocytic Leukemia
# 2918    BRAF        673        Non-V600                           Solid Tumor
# 2919   NT5C2      22978           R367Q  Childhood Acute Lymphocytic Leukemia
# 2920   NT5C2      22978           R238W  Childhood Acute Lymphocytic Leukemia
# 2921   NT5C2      22978           S445F  Childhood Acute Lymphocytic Leukemia
#
# ...

# %%
df = pd.merge(df, df11, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/2556175001.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'ensembl_version_x', 'chromosome_x', 'stop2_x', 'variant_summary_x', 'representative_transcript_x', 'evidence_civic_url_x', 'variant_origin_x', 'reference_bases_x', 'evidence_status_x', 'representative_transcript2_x', 'chromosome2_x', 'start_x', 'gene_civic_url_x', 'variant_civic_url_x', 'evidence_level_x', 'source_type_x', 'gene_id_x', 'evidence_id_x', 'variant_id_x', 'citation_id_x', 'stop_x', 'reference_build_x', 'evidence_statement_x', 'variant_bases_x', 'asco_abstract_id_x', 'start2_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df11, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# ...

# %%
df12 = pd.read_csv('01-Feb-2021-ClinicalEvidenceSummaries.csv')
df12
# Out:
#         gene  entrez_id                        variant  \
# 0       JAK2       3717                          V617F
# 1     PDGFRA       5156                          D842V
# 2     DNMT3A       1788                           R882
# 3     DNMT3A       1788                           R882
# 4       JAK2       3717                          V617F
# ...      ...        ...                            ...
# 3698     VHL       7428               C77fs (c.230del)
# 3699     VHL       7428               L118P (c.353T>C)
# 3700     VHL       7428  Q96_P97delinsH (c.288_290del)
# 3701     VHL       7428          G144fs (c.429_439del)
# 3702    BRAF        673                          V600E
#
#                                 disease     doid  \
# 0                     Lymphoid Leukemia   1037.0
# 1        Gastrointestinal Stromal Tumor   9253.0
# 2                Acute Myeloid Leukemia   9119.0
# 3                Acute Myeloid Leukemia   9119.0
# 4              Chronic Myeloid Leukemia   8552.0
# ...

# %%
df = pd.merge(df, df12, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/1640034033.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'entrez_id_x', 'disease_x', 'nct_ids_x', 'variant_x', 'gene_x', 'doid_x', 'evidence_direction_x', 'drug_interaction_type_x', 'evidence_type_x', 'citation_x', 'clinical_significance_x', 'drugs_x', 'rating_x', 'last_review_date_x', 'phenotypes_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df12, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# 2     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 3     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# ...

# %%
df13 = pd.read_csv('01-Feb-2022-ClinicalEvidenceSummaries.csv')
df13
# Out:
#         gene  entrez_id          variant                         disease  \
# 0       JAK2       3717            V617F               Lymphoid Leukemia
# 1     PDGFRA       5156            D842V  Gastrointestinal Stromal Tumor
# 2     DNMT3A       1788             R882          Acute Myeloid Leukemia
# 3     DNMT3A       1788             R882          Acute Myeloid Leukemia
# 4       JAK2       3717            V617F        Chronic Myeloid Leukemia
# ...      ...        ...              ...                             ...
# 3873   IGF1R       3480   Overexpression                   Breast Cancer
# 3874   SF3B1      23451            K700E                        Leukemia
# 3875   ERCC1       2067  Underexpression   Lung Non-small Cell Carcinoma
# 3876    RRM1       6240  Underexpression   Lung Non-small Cell Carcinoma
# 3877    IDH1       3417            R132C                          Cancer
#
#         doid phenotypes                    drugs drug_interaction_type  \
# ...

# %%
df = pd.merge(df, df13, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/607125807.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'ensembl_version_x', 'chromosome_x', 'stop2_x', 'variant_summary_x', 'representative_transcript_x', 'evidence_civic_url_x', 'variant_origin_x', 'reference_bases_x', 'evidence_status_x', 'representative_transcript2_x', 'chromosome2_x', 'start_x', 'gene_civic_url_x', 'variant_civic_url_x', 'evidence_level_x', 'source_type_x', 'gene_id_x', 'evidence_id_x', 'variant_id_x', 'citation_id_x', 'stop_x', 'reference_build_x', 'evidence_statement_x', 'variant_bases_x', 'asco_abstract_id_x', 'start2_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df13, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# ...

# %%
df14 = pd.read_csv('01-Jan-2016-ClinicalEvidenceSummaries.csv')
df14
# Out:
#        gene  entrez_id              variant  \
# 0      JAK2     3717.0                V617F
# 1    PDGFRA     5156.0                D842V
# 2    DNMT3A     1788.0                 R882
# 3    DNMT3A     1788.0                 R882
# 4      JAK2     3717.0                V617F
# ..      ...        ...                  ...
# 647   STAT3     6774.0  SH2 DOMAIN MUTATION
# 648  POU5F1     5460.0           EXPRESSION
# 649   ERBB2     2064.0          M774INSAYVM
# 650   ERBB2     2064.0       OVEREXPRESSION
# 651   ERBB2     2064.0       OVEREXPRESSION
#
#                                  disease     doid                       drugs  \
# 0                      Lymphoid Leukemia  10747.0                         NaN
# 1         Gastrointestinal Stromal Tumor   9253.0                         NaN
# 2                 Acute Myeloid Leukemia   9119.0                         NaN
# 3                 Acute Myeloid Leukemia   9119.0                         NaN
# ...

# %%
df = pd.merge(df, df14, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/1265922883.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'disease_x', 'entrez_id_x', 'variant_x', 'gene_x', 'doid_x', 'evidence_direction_x', 'evidence_type_x', 'pubmed_id_x', 'citation_x', 'clinical_significance_x', 'drugs_x', 'rating_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df14, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# 2     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 3     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 4       JAK2       3717.0     V617F        Chronic Myeloid Leukemia   8552.0
# ...

# %%
df15 = pd.read_csv('01-Jan-2017-ClinicalEvidenceSummaries.csv')
df15
# Out:
#         gene  entrez_id           variant                         disease  \
# 0       JAK2     3717.0             V617F               Lymphoid Leukemia
# 1     PDGFRA     5156.0             D842V  Gastrointestinal Stromal Tumor
# 2     DNMT3A     1788.0              R882          Acute Myeloid Leukemia
# 3     DNMT3A     1788.0              R882          Acute Myeloid Leukemia
# 4       JAK2     3717.0             V617F        Chronic Myeloid Leukemia
# ...      ...        ...               ...                             ...
# 1620   DDX41    51428.0             R164W              Hematologic Cancer
# 1621   ERBB2     2064.0     AMPLIFICATION   Non-small Cell Lung Carcinoma
# 1622   PTPRB     5787.0  LOSS-OF-FUNCTION                    Angiosarcoma
# 1623     VHL     7428.0  A149S (c.445G>T)       Von Hippel-Lindau Disease
# 1624    KRAS     3845.0              G12D               Colorectal Cancer
#
#          doid                     drugs evidence_type evidence_direction  \
# ...

# %%
df = pd.merge(df, df15, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# 2     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 3     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 4       JAK2       3717.0     V617F        Chronic Myeloid Leukemia   8552.0
# ...      ...          ...       ...                             ...      ...
# 3873     NaN          NaN       NaN                             NaN      NaN
# 3874     NaN          NaN       NaN                             NaN      NaN
# 3875     NaN          NaN       NaN                             NaN      NaN
# 3876     NaN          NaN       NaN                             NaN      NaN
# 3877     NaN          NaN       NaN                             NaN      NaN
#
# ...

# %%
df16 = pd.read_csv('01-Jan-2018-ClinicalEvidenceSummaries.csv')
df16
# Out:
#         gene  entrez_id         variant                         disease  \
# 0       JAK2       3717           V617F               Lymphoid Leukemia
# 1     PDGFRA       5156           D842V  Gastrointestinal Stromal Tumor
# 2     DNMT3A       1788            R882          Acute Myeloid Leukemia
# 3     DNMT3A       1788            R882          Acute Myeloid Leukemia
# 4       JAK2       3717           V617F        Chronic Myeloid Leukemia
# ...      ...        ...             ...                             ...
# 2367     MET       4233  OVEREXPRESSION               Stomach Carcinoma
# 2368    PTEN       5728            LOSS                          Cancer
# 2369    BRAF        673           V600E              Cholangiocarcinoma
# 2370    BRAF        673           V600E              Cholangiocarcinoma
# 2371    BRAF        673           V600E              Cholangiocarcinoma
#
#          doid                       drugs evidence_type evidence_direction  \
# ...

# %%
df = pd.merge(df, df16, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/2221169544.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'ensembl_version_x', 'evidence_type_x', 'chromosome_x', 'clinical_significance_x', 'stop2_x', 'variant_summary_x', 'representative_transcript_x', 'evidence_civic_url_x', 'entrez_id_x', 'disease_x', 'doid_x', 'variant_origin_x', 'reference_bases_x', 'evidence_status_x', 'representative_transcript2_x', 'chromosome2_x', 'start_x', 'drugs_x', 'gene_civic_url_x', 'variant_civic_url_x', 'variant_x', 'evidence_level_x', 'gene_id_x', 'evidence_id_x', 'citation_x', 'variant_id_x', 'evidence_direction_x', 'rating_x', 'stop_x', 'reference_build_x', 'gene_x', 'evidence_statement_x', 'pubmed_id_x', 'variant_bases_x', 'start2_x', 'last_review_date_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df16, right_index=True, left_index=True, how = 'outer')
# ...

# %%
df17 = pd.read_csv('01-Jan-2019-ClinicalEvidenceSummaries.csv')
df17
# Out:
#         gene  entrez_id              variant  \
# 0       JAK2       3717                V617F
# 1     PDGFRA       5156                D842V
# 2     DNMT3A       1788                 R882
# 3     DNMT3A       1788                 R882
# 4       JAK2       3717                V617F
# ...      ...        ...                  ...
# 2992   FOXO1       2308           PAX3-FOXO1
# 2993   FOXO1       2308    PAX7-FOXO1 fusion
# 2994    HEY1      23462    HEY1-NCOA2 fusion
# 2995  PDGFRA       5156  FIP1L1-PDGFRA T674I
# 2996    JAK2       3717           JAK2 F694L
#
#                                                 disease     doid  \
# 0                                     Lymphoid Leukemia  10747.0
# 1                        Gastrointestinal Stromal Tumor   9253.0
# 2                                Acute Myeloid Leukemia   9119.0
# 3                                Acute Myeloid Leukemia   9119.0
# 4                              Chronic Myeloid Leukemia   8552.0
# ...

# %%
df = pd.merge(df, df17, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/1178724849.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'drug_interaction_type_x', 'nct_ids_x', 'phenotypes_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df17, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# 2     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 3     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 4       JAK2       3717.0     V617F        Chronic Myeloid Leukemia   8552.0
# ...      ...          ...       ...                             ...      ...
# 3873     NaN          NaN       NaN                             NaN      NaN
# ...

# %%
df18 = pd.read_csv('01-Jan-2020-ClinicalEvidenceSummaries.csv')
df18
# Out:
#         gene  entrez_id              variant  \
# 0       JAK2       3717                V617F
# 1     PDGFRA       5156                D842V
# 2     DNMT3A       1788                 R882
# 3     DNMT3A       1788                 R882
# 4       JAK2       3717                V617F
# ...      ...        ...                  ...
# 2903    ABL1         25        BCR-ABL T315I
# 2904    ABL1         25        BCR-ABL T315I
# 2905    ABL1         25        BCR-ABL T315I
# 2906    ABL1         25  BCR-ABL E255K V299L
# 2907    ABL1         25           ABL1-RCSD1
#
#                                  disease     doid phenotypes  \
# 0                      Lymphoid Leukemia  10747.0        NaN
# 1         Gastrointestinal Stromal Tumor   9253.0        NaN
# 2                 Acute Myeloid Leukemia   9119.0        NaN
# 3                 Acute Myeloid Leukemia   9119.0        NaN
# 4               Chronic Myeloid Leukemia   8552.0        NaN
# ...

# %%
df = pd.merge(df, df18, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/119578406.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'ensembl_version_x', 'evidence_type_x', 'chromosome_x', 'clinical_significance_x', 'stop2_x', 'variant_summary_x', 'representative_transcript_x', 'evidence_civic_url_x', 'entrez_id_x', 'disease_x', 'doid_x', 'variant_origin_x', 'reference_bases_x', 'evidence_status_x', 'representative_transcript2_x', 'chromosome2_x', 'start_x', 'drugs_x', 'gene_civic_url_x', 'variant_civic_url_x', 'variant_x', 'evidence_level_x', 'gene_id_x', 'evidence_id_x', 'citation_x', 'variant_id_x', 'evidence_direction_x', 'rating_x', 'stop_x', 'reference_build_x', 'gene_x', 'evidence_statement_x', 'variant_bases_x', 'start2_x', 'last_review_date_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df18, right_index=True, left_index=True, how = 'outer')
# ...

# %%
df19 = pd.read_csv('01-Jan-2021-ClinicalEvidenceSummaries.csv')
df19
# Out:
#         gene  entrez_id         variant                          disease  \
# 0       JAK2       3717           V617F                Lymphoid Leukemia
# 1     PDGFRA       5156           D842V   Gastrointestinal Stromal Tumor
# 2     DNMT3A       1788            R882           Acute Myeloid Leukemia
# 3     DNMT3A       1788            R882           Acute Myeloid Leukemia
# 4       JAK2       3717           V617F         Chronic Myeloid Leukemia
# ...      ...        ...             ...                              ...
# 3650    FLT3       2322             ITD           Acute Myeloid Leukemia
# 3651    NRAS       4893            Q61K      Ovary Serous Adenocarcinoma
# 3652    BRAF        673   KIAA1549-BRAF  Childhood Pilocytic Astrocytoma
# 3653    BRAF        673   KIAA1549-BRAF  Childhood Pilocytic Astrocytoma
# 3654    TP53       7157  OVEREXPRESSION               Renal Wilms' Tumor
#
#         doid phenotypes         drugs drug_interaction_type evidence_type  \
# ...

# %%
df = pd.merge(df, df19, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/1888988120.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'nct_ids_x', 'drug_interaction_type_x', 'source_type_x', 'asco_abstract_id_x', 'phenotypes_x', 'citation_id_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df19, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# 2     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 3     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 4       JAK2       3717.0     V617F        Chronic Myeloid Leukemia   8552.0
# ...      ...          ...       ...                             ...      ...
# ...

# %%
df20 = pd.read_csv('01-Jan-2022-ClinicalEvidenceSummaries.csv')
df20
# Out:
#         gene  entrez_id   variant                                 disease  \
# 0       JAK2       3717     V617F                       Lymphoid Leukemia
# 1     PDGFRA       5156     D842V          Gastrointestinal Stromal Tumor
# 2     DNMT3A       1788      R882                  Acute Myeloid Leukemia
# 3     DNMT3A       1788      R882                  Acute Myeloid Leukemia
# 4       JAK2       3717     V617F                Chronic Myeloid Leukemia
# ...      ...        ...       ...                                     ...
# 3850   ACVR1         90     G328V  Diffuse Midline Glioma, H3 K27M-mutant
# 3851   ACVR1         90     R206H  Diffuse Midline Glioma, H3 K27M-mutant
# 3852   ACVR1         90     G328W  Diffuse Midline Glioma, H3 K27M-mutant
# 3853   ACVR1         90  MUTATION  Diffuse Midline Glioma, H3 K27M-mutant
# 3854   ACVR1         90     G356D  Diffuse Midline Glioma, H3 K27M-mutant
#
#          doid phenotypes drugs drug_interaction_type evidence_type  \
# ...

# %%
df = pd.merge(df, df20, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/939677.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'ensembl_version_x', 'evidence_type_x', 'chromosome_x', 'clinical_significance_x', 'is_flagged_x', 'stop2_x', 'variant_summary_x', 'representative_transcript_x', 'evidence_civic_url_x', 'entrez_id_x', 'disease_x', 'doid_x', 'variant_origin_x', 'reference_bases_x', 'evidence_status_x', 'representative_transcript2_x', 'chromosome2_x', 'start_x', 'drugs_x', 'gene_civic_url_x', 'variant_civic_url_x', 'variant_x', 'evidence_level_x', 'gene_id_x', 'evidence_id_x', 'citation_x', 'variant_id_x', 'evidence_direction_x', 'rating_x', 'stop_x', 'reference_build_x', 'gene_x', 'evidence_statement_x', 'variant_bases_x', 'start2_x', 'last_review_date_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df20, right_index=True, left_index=True, how = 'outer')
# ...

# %%
df21 = pd.read_csv('01-Jul-2015-ClinicalEvidenceSummaries.csv')
df21
# Out:
#                                                  gene  entrez_id  \
# 0                                                JAK2       3717
# 1                                              PDGFRA       5156
# 2                                              DNMT3A       1788
# 3                                              DNMT3A       1788
# 4                                                JAK2       3717
# ..                                                ...        ...
# 377                                              EZH2       2146
# 378                                              EZH2       2146
# 379                                             KMT2D       8085
# 380  Mutations were predicted to be loss-of-function.   21796119
# 381                                               BTK        695
#
#                         variant                         disease     doid  \
# 0                         V617F               Lymphoid Leukemia  10747.0
# ...

# %%
df = pd.merge(df, df21, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/3857731425.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'pubmed_id_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df21, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# 2     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 3     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 4       JAK2       3717.0     V617F        Chronic Myeloid Leukemia   8552.0
# ...      ...          ...       ...                             ...      ...
# 3873     NaN          NaN       NaN                             NaN      NaN
# ...

# %%
df22 = pd.read_csv('01-Jul-2016-ClinicalEvidenceSummaries.csv')
df22
# Out:
#         gene  entrez_id         variant                               disease  \
# 0       JAK2       3717           V617F                     Lymphoid Leukemia
# 1     PDGFRA       5156           D842V        Gastrointestinal Stromal Tumor
# 2     DNMT3A       1788            R882                Acute Myeloid Leukemia
# 3     DNMT3A       1788            R882                Acute Myeloid Leukemia
# 4       JAK2       3717           V617F              Chronic Myeloid Leukemia
# ...      ...        ...             ...                                   ...
# 1354    BRAF        673           D594G                     Colorectal Cancer
# 1355    FLT3       2322           D835H                Acute Myeloid Leukemia
# 1356    FLT3       2322         D835H/Y                Acute Myeloid Leukemia
# 1357   RUNX1        861        MUTATION                Acute Myeloid Leukemia
# 1358   ERBB2       2064  OVEREXPRESSION  Her2-receptor Positive Breast Cancer
#
# ...

# %%
df = pd.merge(df, df22, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/1993464068.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'entrez_id_x', 'disease_x', 'variant_x', 'gene_x', 'doid_x', 'evidence_direction_x', 'evidence_type_x', 'citation_x', 'clinical_significance_x', 'drugs_x', 'rating_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df22, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# 2     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 3     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 4       JAK2       3717.0     V617F        Chronic Myeloid Leukemia   8552.0
# ...

# %%
df23 = pd.read_csv('01-Jul-2017-ClinicalEvidenceSummaries.csv')
df23
# Out:
#         gene  entrez_id                 variant  \
# 0       JAK2       3717                   V617F
# 1     PDGFRA       5156                   D842V
# 2     DNMT3A       1788                    R882
# 3     DNMT3A       1788                    R882
# 4       JAK2       3717                   V617F
# ...      ...        ...                     ...
# 2043    FLT3       2322                MUTATION
# 2044     VHL       7428        X214L (c.641G>T)
# 2045     VHL       7428  *214Wext*15 (c.642A>G)
# 2046    BAP1       8314                MUTATION
# 2047    RRM1       6240         UNDEREXPRESSION
#
#                              disease     doid                 drugs  \
# 0                  Lymphoid Leukemia  10747.0                   NaN
# 1     Gastrointestinal Stromal Tumor   9253.0                   NaN
# 2             Acute Myeloid Leukemia   9119.0                   NaN
# 3             Acute Myeloid Leukemia   9119.0                   NaN
# ...

# %%
df = pd.merge(df, df23, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/1479165768.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'ensembl_version_x', 'chromosome_x', 'stop2_x', 'variant_summary_x', 'representative_transcript_x', 'evidence_civic_url_x', 'variant_origin_x', 'reference_bases_x', 'evidence_status_x', 'representative_transcript2_x', 'chromosome2_x', 'start_x', 'gene_civic_url_x', 'variant_civic_url_x', 'evidence_level_x', 'gene_id_x', 'evidence_id_x', 'variant_id_x', 'stop_x', 'reference_build_x', 'evidence_statement_x', 'pubmed_id_x', 'variant_bases_x', 'start2_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df23, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# ...

# %%
df24 = pd.read_csv('01-Jul-2018-ClinicalEvidenceSummaries.csv')
df24
# Out:
#         gene  entrez_id        variant                         disease  \
# 0       JAK2       3717          V617F               Lymphoid Leukemia
# 1     PDGFRA       5156          D842V  Gastrointestinal Stromal Tumor
# 2     DNMT3A       1788           R882          Acute Myeloid Leukemia
# 3     DNMT3A       1788           R882          Acute Myeloid Leukemia
# 4       JAK2       3717          V617F        Chronic Myeloid Leukemia
# ...      ...        ...            ...                             ...
# 2553    ABL1         25  BCR-ABL F317L        Chronic Myeloid Leukemia
# 2554    ABL1         25  BCR-ABL F317V        Chronic Myeloid Leukemia
# 2555    ABL1         25          M351T        Chronic Myeloid Leukemia
# 2556    ABL1         25  BCR-ABL E355G        Chronic Myeloid Leukemia
# 2557    ABL1         25  BCR-ABL F359V        Chronic Myeloid Leukemia
#
#          doid phenotypes              drugs evidence_type evidence_direction  \
# ...

# %%
df = pd.merge(df, df24, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/1262843643.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'entrez_id_x', 'nct_ids_x', 'disease_x', 'variant_x', 'gene_x', 'doid_x', 'evidence_direction_x', 'evidence_type_x', 'citation_x', 'clinical_significance_x', 'drugs_x', 'rating_x', 'last_review_date_x', 'phenotypes_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df24, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# 2     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 3     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 4       JAK2       3717.0     V617F        Chronic Myeloid Leukemia   8552.0
# ...

# %%
df25 = pd.read_csv('01-Jul-2019-ClinicalEvidenceSummaries.csv')
df25
# Out:
#         gene  entrez_id         variant                         disease  \
# 0       JAK2       3717           V617F               Lymphoid Leukemia
# 1     PDGFRA       5156           D842V  Gastrointestinal Stromal Tumor
# 2     DNMT3A       1788            R882          Acute Myeloid Leukemia
# 3     DNMT3A       1788            R882          Acute Myeloid Leukemia
# 4       JAK2       3717           V617F        Chronic Myeloid Leukemia
# ...      ...        ...             ...                             ...
# 2791   FGFR1       2260   FGFR1 FUSIONS          Acute Myeloid Leukemia
# 2792  PDGFRA       5156   FIP1L1-PDGFRA          Acute Myeloid Leukemia
# 2793     KIT       3815           N822K          Acute Myeloid Leukemia
# 2794   FGFR1       2260  FGFR1OP2-FGFR1          Acute Myeloid Leukemia
# 2795    FLT3       2322             ITD                        Leukemia
#
#          doid phenotypes                drugs drug_interaction_type  \
# ...

# %%
df = pd.merge(df, df25, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/195689625.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'ensembl_version_x', 'chromosome_x', 'stop2_x', 'variant_summary_x', 'representative_transcript_x', 'evidence_civic_url_x', 'variant_origin_x', 'reference_bases_x', 'evidence_status_x', 'representative_transcript2_x', 'chromosome2_x', 'start_x', 'gene_civic_url_x', 'variant_civic_url_x', 'evidence_level_x', 'source_type_x', 'drug_interaction_type_x', 'gene_id_x', 'evidence_id_x', 'variant_id_x', 'citation_id_x', 'stop_x', 'reference_build_x', 'evidence_statement_x', 'variant_bases_x', 'asco_abstract_id_x', 'start2_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df25, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# ...

# %%
df26 = pd.read_csv('01-Jun-2020-ClinicalEvidenceSummaries.csv')
df26
# Out:
#         gene  entrez_id         variant  \
# 0       JAK2       3717           V617F
# 1     PDGFRA       5156           D842V
# 2     DNMT3A       1788            R882
# 3     DNMT3A       1788            R882
# 4       JAK2       3717           V617F
# ...      ...        ...             ...
# 3459  PIK3CA       5290           V955I
# 3460    ABL1         25       Double Ph
# 3461    JAK2       3717      SSBP2-JAK2
# 3462   CCND1        595  OVEREXPRESSION
# 3463     PML       5371  PML-RARA A216V
#
#                                                disease     doid phenotypes  \
# 0                                    Lymphoid Leukemia  10747.0        NaN
# 1                       Gastrointestinal Stromal Tumor   9253.0        NaN
# 2                               Acute Myeloid Leukemia   9119.0        NaN
# 3                               Acute Myeloid Leukemia   9119.0        NaN
# 4                             Chronic Myeloid Leukemia   8552.0        NaN
# ...

# %%
df = pd.merge(df, df26, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/3915522968.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'entrez_id_x', 'disease_x', 'nct_ids_x', 'variant_x', 'gene_x', 'doid_x', 'evidence_direction_x', 'evidence_type_x', 'citation_x', 'clinical_significance_x', 'drugs_x', 'rating_x', 'last_review_date_x', 'phenotypes_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df26, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# 2     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 3     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 4       JAK2       3717.0     V617F        Chronic Myeloid Leukemia   8552.0
# ...

# %%
df27 = pd.read_csv('01-Jul-2020-ClinicalEvidenceSummaries.csv')
df27
# Out:
#         gene  entrez_id          variant                         disease  \
# 0       JAK2       3717            V617F               Lymphoid Leukemia
# 1     PDGFRA       5156            D842V  Gastrointestinal Stromal Tumor
# 2     DNMT3A       1788             R882          Acute Myeloid Leukemia
# 3     DNMT3A       1788             R882          Acute Myeloid Leukemia
# 4       JAK2       3717            V617F        Chronic Myeloid Leukemia
# ...      ...        ...              ...                             ...
# 3468   MYOD1       4654            L122R   Spindle Cell Rhabdomyosarcoma
# 3469   MYOD1       4654            L122R   Spindle Cell Rhabdomyosarcoma
# 3470   MYOD1       4654            L122R   Spindle Cell Rhabdomyosarcoma
# 3471  PIK3CA       5290           H1047R               Colorectal Cancer
# 3472    KRAS       3845  EXON 2 MUTATION               Colorectal Cancer
#
#          doid phenotypes                             drugs  \
# ...

# %%
df = pd.merge(df, df27, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/1488477255.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'ensembl_version_x', 'chromosome_x', 'stop2_x', 'variant_summary_x', 'representative_transcript_x', 'evidence_civic_url_x', 'variant_origin_x', 'reference_bases_x', 'evidence_status_x', 'representative_transcript2_x', 'chromosome2_x', 'start_x', 'gene_civic_url_x', 'variant_civic_url_x', 'evidence_level_x', 'source_type_x', 'drug_interaction_type_x', 'gene_id_x', 'evidence_id_x', 'variant_id_x', 'citation_id_x', 'stop_x', 'reference_build_x', 'evidence_statement_x', 'variant_bases_x', 'asco_abstract_id_x', 'start2_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df27, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# ...

# %%
df28 = pd.read_csv('01-Jul-2021-ClinicalEvidenceSummaries.csv')
df28
# Out:
#         gene  entrez_id variant                         disease    doid  \
# 0       JAK2       3717   V617F               Lymphoid Leukemia  1037.0
# 1     PDGFRA       5156   D842V  Gastrointestinal Stromal Tumor  9253.0
# 2     DNMT3A       1788    R882          Acute Myeloid Leukemia  9119.0
# 3     DNMT3A       1788    R882          Acute Myeloid Leukemia  9119.0
# 4       JAK2       3717   V617F        Chronic Myeloid Leukemia  8552.0
# ...      ...        ...     ...                             ...     ...
# 3800     ALK        238  I1171T                   Neuroblastoma   769.0
# 3801    EZH2       2146    Y646                             NaN     NaN
# 3802  PIK3R2       5296   G373R                             NaN     NaN
# 3803    PTEN       5728   C136R                             NaN     NaN
# 3804    CD44        960  CD44v6                  Ovarian Cancer  2394.0
#
#            phenotypes      drugs drug_interaction_type evidence_type  \
# ...

# %%
df = pd.merge(df, df28, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/589876970.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'entrez_id_x', 'disease_x', 'nct_ids_x', 'variant_x', 'gene_x', 'doid_x', 'evidence_direction_x', 'evidence_type_x', 'citation_x', 'clinical_significance_x', 'drugs_x', 'rating_x', 'last_review_date_x', 'phenotypes_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df28, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# 2     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 3     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 4       JAK2       3717.0     V617F        Chronic Myeloid Leukemia   8552.0
# ...

# %%
df29 = pd.read_csv('01-Jun-2016-ClinicalEvidenceSummaries.csv')
df29
# Out:
#         gene  entrez_id           variant  \
# 0       JAK2       3717             V617F
# 1     PDGFRA       5156             D842V
# 2     DNMT3A       1788              R882
# 3     DNMT3A       1788              R882
# 4       JAK2       3717             V617F
# ...      ...        ...               ...
# 1209  PDGFRB       5159    PDGFRB FUSIONS
# 1210   FGFR1       2260     FGFR1 FUSIONS
# 1211    JAK2       3717  PCM1-JAK2 FUSION
# 1212    ROS1       6098     REARRANGEMENT
# 1213   BIRC5        332    OVEREXPRESSION
#
#                                    disease     doid        drugs  \
# 0                        Lymphoid Leukemia  10747.0          NaN
# 1           Gastrointestinal Stromal Tumor   9253.0          NaN
# 2                   Acute Myeloid Leukemia   9119.0          NaN
# 3                   Acute Myeloid Leukemia   9119.0          NaN
# 4                 Chronic Myeloid Leukemia   8552.0          NaN
# ...

# %%
df = pd.merge(df, df29, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/4103862143.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'ensembl_version_x', 'chromosome_x', 'stop2_x', 'variant_summary_x', 'representative_transcript_x', 'evidence_civic_url_x', 'variant_origin_x', 'reference_bases_x', 'evidence_status_x', 'representative_transcript2_x', 'chromosome2_x', 'start_x', 'gene_civic_url_x', 'variant_civic_url_x', 'evidence_level_x', 'gene_id_x', 'evidence_id_x', 'variant_id_x', 'stop_x', 'reference_build_x', 'evidence_statement_x', 'pubmed_id_x', 'variant_bases_x', 'start2_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df29, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# ...

# %%
df30 = pd.read_csv('01-Jun-2017-ClinicalEvidenceSummaries.csv')
df30
# Out:
#         gene  entrez_id           variant                         disease  \
# 0       JAK2       3717             V617F               Lymphoid Leukemia
# 1     PDGFRA       5156             D842V  Gastrointestinal Stromal Tumor
# 2     DNMT3A       1788              R882          Acute Myeloid Leukemia
# 3     DNMT3A       1788              R882          Acute Myeloid Leukemia
# 4       JAK2       3717             V617F        Chronic Myeloid Leukemia
# ...      ...        ...               ...                             ...
# 1946    KRAS       3845          MUTATION   Non-small Cell Lung Carcinoma
# 1947   BRCA2        675  LOSS-OF-FUNCTION                  Ovarian Cancer
# 1948   BRCA1        672  LOSS-OF-FUNCTION                  Ovarian Cancer
# 1949    KRAS       3845          MUTATION   Non-small Cell Lung Carcinoma
# 1950    KRAS       3845          MUTATION   Non-small Cell Lung Carcinoma
#
#          doid                  drugs evidence_type evidence_direction  \
# ...

# %%
df = pd.merge(df, df30, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/2031976264.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'entrez_id_x', 'disease_x', 'variant_x', 'gene_x', 'doid_x', 'evidence_direction_x', 'evidence_type_x', 'citation_x', 'clinical_significance_x', 'drugs_x', 'rating_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df30, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# 2     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 3     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 4       JAK2       3717.0     V617F        Chronic Myeloid Leukemia   8552.0
# ...

# %%
df31 = pd.read_csv('01-Jun-2018-ClinicalEvidenceSummaries.csv')
df31
# Out:
#         gene  entrez_id variant                         disease     doid  \
# 0       JAK2       3717   V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156   D842V  Gastrointestinal Stromal Tumor   9253.0
# 2     DNMT3A       1788    R882          Acute Myeloid Leukemia   9119.0
# 3     DNMT3A       1788    R882          Acute Myeloid Leukemia   9119.0
# 4       JAK2       3717   V617F        Chronic Myeloid Leukemia   8552.0
# ...      ...        ...     ...                             ...      ...
# 2527    BRAF        673   V600E       Colorectal Adenocarcinoma  50861.0
# 2528    BRAF        673   V600E                        Melanoma   1909.0
# 2529    BRAF        673   V600K                        Melanoma   1909.0
# 2530    EGFR       1956   G719A   Non-small Cell Lung Carcinoma   3908.0
# 2531    EGFR       1956   R705K   Non-small Cell Lung Carcinoma   3908.0
#
#      phenotypes                   drugs evidence_type evidence_direction  \
# ...

# %%
df = pd.merge(df, df31, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/3139731954.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'ensembl_version_x', 'chromosome_x', 'stop2_x', 'variant_summary_x', 'representative_transcript_x', 'evidence_civic_url_x', 'variant_origin_x', 'reference_bases_x', 'evidence_status_x', 'representative_transcript2_x', 'chromosome2_x', 'start_x', 'gene_civic_url_x', 'variant_civic_url_x', 'evidence_level_x', 'gene_id_x', 'evidence_id_x', 'variant_id_x', 'stop_x', 'reference_build_x', 'evidence_statement_x', 'pubmed_id_x', 'variant_bases_x', 'start2_x', 'last_review_date_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df31, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# ...

# %%
df32 = pd.read_csv('01-Jun-2019-ClinicalEvidenceSummaries.csv')
df32
# Out:
#         gene  entrez_id        variant                             disease  \
# 0       JAK2       3717          V617F                   Lymphoid Leukemia
# 1     PDGFRA       5156          D842V      Gastrointestinal Stromal Tumor
# 2     DNMT3A       1788           R882              Acute Myeloid Leukemia
# 3     DNMT3A       1788           R882              Acute Myeloid Leukemia
# 4       JAK2       3717          V617F            Chronic Myeloid Leukemia
# ...      ...        ...            ...                                 ...
# 2782     KIT       3815   K550_K559DEL      Gastrointestinal Stromal Tumor
# 2783    ABL1         25     FOXP1-ABL1  Pediatric B-lymphoblastic Leukemia
# 2784  CDKN2A       1029       MUTATION                   Pancreatic Cancer
# 2785  CDKN2A       1029       MUTATION                  Cholangiocarcinoma
# 2786    BRAF        673  KIAA1549-BRAF               Pilocytic Astrocytoma
#
# ...

# %%
df = pd.merge(df, df32, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/860818591.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'entrez_id_x', 'disease_x', 'nct_ids_x', 'variant_x', 'gene_x', 'doid_x', 'evidence_direction_x', 'source_type_x', 'drug_interaction_type_x', 'evidence_type_x', 'citation_x', 'clinical_significance_x', 'asco_abstract_id_x', 'drugs_x', 'rating_x', 'phenotypes_x', 'citation_id_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df32, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# 2     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 3     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# ...

# %%
df33 = pd.read_csv('01-Jun-2020-ClinicalEvidenceSummaries.csv')
df33
# Out:
#         gene  entrez_id         variant  \
# 0       JAK2       3717           V617F
# 1     PDGFRA       5156           D842V
# 2     DNMT3A       1788            R882
# 3     DNMT3A       1788            R882
# 4       JAK2       3717           V617F
# ...      ...        ...             ...
# 3459  PIK3CA       5290           V955I
# 3460    ABL1         25       Double Ph
# 3461    JAK2       3717      SSBP2-JAK2
# 3462   CCND1        595  OVEREXPRESSION
# 3463     PML       5371  PML-RARA A216V
#
#                                                disease     doid phenotypes  \
# 0                                    Lymphoid Leukemia  10747.0        NaN
# 1                       Gastrointestinal Stromal Tumor   9253.0        NaN
# 2                               Acute Myeloid Leukemia   9119.0        NaN
# 3                               Acute Myeloid Leukemia   9119.0        NaN
# 4                             Chronic Myeloid Leukemia   8552.0        NaN
# ...

# %%
df = pd.merge(df, df33, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/307649183.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'ensembl_version_x', 'chromosome_x', 'stop2_x', 'variant_summary_x', 'representative_transcript_x', 'evidence_civic_url_x', 'variant_origin_x', 'reference_bases_x', 'evidence_status_x', 'representative_transcript2_x', 'chromosome2_x', 'start_x', 'gene_civic_url_x', 'variant_civic_url_x', 'evidence_level_x', 'gene_id_x', 'evidence_id_x', 'variant_id_x', 'stop_x', 'reference_build_x', 'evidence_statement_x', 'variant_bases_x', 'start2_x', 'last_review_date_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df33, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# ...

# %%
df34 = pd.read_csv('01-Mar-2017-ClinicalEvidenceSummaries.csv')
df34
# Out:
#         gene  entrez_id variant                         disease     doid  \
# 0       JAK2       3717   V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156   D842V  Gastrointestinal Stromal Tumor   9253.0
# 2     DNMT3A       1788    R882          Acute Myeloid Leukemia   9119.0
# 3     DNMT3A       1788    R882          Acute Myeloid Leukemia   9119.0
# 4       JAK2       3717   V617F        Chronic Myeloid Leukemia   8552.0
# ...      ...        ...     ...                             ...      ...
# 1764    IDH1       3417   R132C          Acute Myeloid Leukemia   9119.0
# 1765    IDH1       3417   R132C          Acute Myeloid Leukemia   9119.0
# 1766    IDH1       3417   R132S                Malignant Glioma   3070.0
# 1767    GNAS       2778   T393C    Bladder Urothelial Carcinoma   4006.0
# 1768    GNAS       2778   T393C               Colorectal Cancer   9256.0
#
#                                                   drugs evidence_type  \
# ...

# %%
df = pd.merge(df, df34, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/1868808441.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'entrez_id_x', 'disease_x', 'variant_x', 'gene_x', 'doid_x', 'evidence_direction_x', 'evidence_type_x', 'citation_x', 'clinical_significance_x', 'drugs_x', 'rating_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df34, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# 2     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 3     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 4       JAK2       3717.0     V617F        Chronic Myeloid Leukemia   8552.0
# ...

# %%
df35 = pd.read_csv('01-Mar-2018-ClinicalEvidenceSummaries.csv')
df35
# Out:
#         gene  entrez_id        variant                           disease  \
# 0       JAK2       3717          V617F                 Lymphoid Leukemia
# 1     PDGFRA       5156          D842V    Gastrointestinal Stromal Tumor
# 2     DNMT3A       1788           R882            Acute Myeloid Leukemia
# 3     DNMT3A       1788           R882            Acute Myeloid Leukemia
# 4       JAK2       3717          V617F          Chronic Myeloid Leukemia
# ...      ...        ...            ...                               ...
# 2494   ERBB2       2064  AMPLIFICATION                 Pancreatic Cancer
# 2495   ERBB2       2064  AMPLIFICATION                    Uterine Cancer
# 2496    IDH1       3417          R132H  Pancreatic Ductal Adenocarcinoma
# 2497    BCL2        596       MUTATION               Follicular Lymphoma
# 2498    TLK2      11011  AMPLIFICATION                     Breast Cancer
#
#          doid                   drugs evidence_type evidence_direction  \
# ...

# %%
df = pd.merge(df, df35, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/3150173672.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'ensembl_version_x', 'chromosome_x', 'stop2_x', 'variant_summary_x', 'representative_transcript_x', 'evidence_civic_url_x', 'variant_origin_x', 'reference_bases_x', 'evidence_status_x', 'representative_transcript2_x', 'chromosome2_x', 'start_x', 'gene_civic_url_x', 'variant_civic_url_x', 'evidence_level_x', 'gene_id_x', 'evidence_id_x', 'variant_id_x', 'stop_x', 'reference_build_x', 'evidence_statement_x', 'pubmed_id_x', 'variant_bases_x', 'start2_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df35, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# ...

# %%
df36 = pd.read_csv('01-Mar-2019-ClinicalEvidenceSummaries.csv')
df36
# Out:
#         gene  entrez_id        variant                         disease  \
# 0       JAK2       3717          V617F               Lymphoid Leukemia
# 1     PDGFRA       5156          D842V  Gastrointestinal Stromal Tumor
# 2     DNMT3A       1788           R882          Acute Myeloid Leukemia
# 3     DNMT3A       1788           R882          Acute Myeloid Leukemia
# 4       JAK2       3717          V617F        Chronic Myeloid Leukemia
# ...      ...        ...            ...                             ...
# 2753    BRAF        673  KIAA1549-BRAF           Pilocytic Astrocytoma
# 2754    BRAF        673          V600E               Colorectal Cancer
# 2755    BRAF        673          V600E               Colorectal Cancer
# 2756    BRAF        673       MUTATION               Colorectal Cancer
# 2757    BRAF        673       MUTATION               Colorectal Cancer
#
#          doid phenotypes drugs drug_interaction_type evidence_type  \
# ...

# %%
df = pd.merge(df, df35, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/3150173672.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'entrez_id_x', 'disease_x', 'variant_x', 'gene_x', 'doid_x', 'evidence_direction_x', 'evidence_type_x', 'citation_x', 'clinical_significance_x', 'drugs_x', 'rating_x', 'last_review_date_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df35, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# 2     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 3     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 4       JAK2       3717.0     V617F        Chronic Myeloid Leukemia   8552.0
# ...

# %%
df37 = pd.read_csv('01-Mar-2020-ClinicalEvidenceSummaries.csv')
df37
# Out:
#         gene  entrez_id          variant  \
# 0       JAK2       3717            V617F
# 1     PDGFRA       5156            D842V
# 2     DNMT3A       1788             R882
# 3     DNMT3A       1788             R882
# 4       JAK2       3717            V617F
# ...      ...        ...              ...
# 2944   PRPS1       5631   PRPS1 MUTATION
# 2945   PRPS1       5631            L191F
# 2946   PRPS1       5631            A190T
# 2947     IL6       3569   OVEREXPRESSION
# 2948   CHEK2      11200  R474C c.1420C>T
#
#                                             disease     doid phenotypes  \
# 0                                 Lymphoid Leukemia  10747.0        NaN
# 1                    Gastrointestinal Stromal Tumor   9253.0        NaN
# 2                            Acute Myeloid Leukemia   9119.0        NaN
# 3                            Acute Myeloid Leukemia   9119.0        NaN
# 4                          Chronic Myeloid Leukemia   8552.0        NaN
# ...

# %%
df = pd.merge(df, df37, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/48481928.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'ensembl_version_x', 'chromosome_x', 'stop2_x', 'variant_summary_x', 'representative_transcript_x', 'evidence_civic_url_x', 'nct_ids_x', 'variant_origin_x', 'reference_bases_x', 'evidence_status_x', 'representative_transcript2_x', 'chromosome2_x', 'start_x', 'gene_civic_url_x', 'variant_civic_url_x', 'evidence_level_x', 'drug_interaction_type_x', 'source_type_x', 'gene_id_x', 'evidence_id_x', 'variant_id_x', 'citation_id_x', 'stop_x', 'reference_build_x', 'evidence_statement_x', 'variant_bases_x', 'asco_abstract_id_x', 'start2_x', 'phenotypes_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df37, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# ...

# %%
df38 = pd.read_csv('01-Mar-2021-ClinicalEvidenceSummaries.csv')
df38
# Out:
#         gene  entrez_id                variant  \
# 0       JAK2       3717                  V617F
# 1     PDGFRA       5156                  D842V
# 2     DNMT3A       1788                   R882
# 3     DNMT3A       1788                   R882
# 4       JAK2       3717                  V617F
# ...      ...        ...                    ...
# 3492     VHL       7428  G144fs (c.429_439del)
# 3493    BRAF        673                  V600E
# 3494     VHL       7428  Null (Large deletion)
# 3495    ABL1         25          BCR-ABL G250E
# 3496    ABL1         25          BCR-ABL H396P
#
#                                 disease     doid  \
# 0                     Lymphoid Leukemia   1037.0
# 1        Gastrointestinal Stromal Tumor   9253.0
# 2                Acute Myeloid Leukemia   9119.0
# 3                Acute Myeloid Leukemia   9119.0
# 4              Chronic Myeloid Leukemia   8552.0
# ...                                 ...      ...
# ...

# %%
df = pd.merge(df, df38, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/778974800.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'entrez_id_x', 'disease_x', 'variant_x', 'gene_x', 'doid_x', 'evidence_direction_x', 'evidence_type_x', 'citation_x', 'clinical_significance_x', 'drugs_x', 'rating_x', 'last_review_date_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df38, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# 2     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 3     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 4       JAK2       3717.0     V617F        Chronic Myeloid Leukemia   8552.0
# ...

# %%
df39 = pd.read_csv('01-Mar-2022-ClinicalEvidenceSummaries.csv')
df39
# Out:
#          gene  entrez_id          variant                         disease  \
# 0        JAK2       3717            V617F               Lymphoid Leukemia
# 1      PDGFRA       5156            D842V  Gastrointestinal Stromal Tumor
# 2      DNMT3A       1788             R882          Acute Myeloid Leukemia
# 3      DNMT3A       1788             R882          Acute Myeloid Leukemia
# 4        JAK2       3717            V617F        Chronic Myeloid Leukemia
# ...       ...        ...              ...                             ...
# 3883    ERCC1       2067  Underexpression   Lung Non-small Cell Carcinoma
# 3884     RRM1       6240  Underexpression   Lung Non-small Cell Carcinoma
# 3885     IDH1       3417            R132C                          Cancer
# 3886  SLC29A1       2030   Overexpression       Pancreatic Adenocarcinoma
# 3887    NTRK1       4914    Amplification                     Solid Tumor
#
#         doid phenotypes                    drugs drug_interaction_type  \
# ...

# %%
df = pd.merge(df, df39, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/2601563594.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'ensembl_version_x', 'chromosome_x', 'is_flagged_x', 'stop2_x', 'variant_summary_x', 'representative_transcript_x', 'evidence_civic_url_x', 'nct_ids_x', 'variant_origin_x', 'reference_bases_x', 'evidence_status_x', 'representative_transcript2_x', 'chromosome2_x', 'start_x', 'gene_civic_url_x', 'variant_civic_url_x', 'evidence_level_x', 'drug_interaction_type_x', 'source_type_x', 'gene_id_x', 'evidence_id_x', 'variant_id_x', 'citation_id_x', 'stop_x', 'reference_build_x', 'evidence_statement_x', 'variant_bases_x', 'asco_abstract_id_x', 'start2_x', 'phenotypes_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df39, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# ...

# %%
df40 = pd.read_csv('01-May-2015-ClinicalEvidenceSummaries.csv')
df40
# Out:
#        gene  entrez_id        variant                     disease   doid  \
# 0      ABL1         25        BCR-ABL    Chronic Myeloid Leukemia   8552
# 1      ABL1         25        BCR-ABL    Chronic Myeloid Leukemia   8552
# 2      ABL1         25        BCR-ABL    Chronic Myeloid Leukemia   8552
# 3      ABL1         25  BCR-ABL E255K    Chronic Myeloid Leukemia   8552
# 4      ABL1         25  BCR-ABL T315I    Chronic Myeloid Leukemia   8552
# ..      ...        ...            ...                         ...    ...
# 404     KIT       3815          K642E            Mucosal Melanoma  50929
# 405    BRAF        673          V600E           Colorectal Cancer   9256
# 406  PDGFRA       5156          G853D  Acral Lentiginous Melanoma   6367
# 407    BRAF        673          G469L         Lung Adenocarcinoma   3910
# 408    MTOR       2475         Q2223K        Renal Cell Carcinoma   4450
#
#                    drugs pubchem_ids evidence_type evidence_direction  \
# ...

# %%
df = pd.merge(df, df40, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/2156593589.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'entrez_id_x', 'disease_x', 'variant_x', 'gene_x', 'doid_x', 'evidence_direction_x', 'evidence_type_x', 'pubmed_id_x', 'citation_x', 'clinical_significance_x', 'statement_x', 'drugs_x', 'rating_x', 'pubchem_ids_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df40, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# 2     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 3     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 4       JAK2       3717.0     V617F        Chronic Myeloid Leukemia   8552.0
# ...

# %%
df42 = pd.read_csv('01-May-2016-ClinicalEvidenceSummaries.csv')
df42
# Out:
#         gene  entrez_id        variant                         disease  \
# 0       JAK2       3717          V617F               Lymphoid Leukemia
# 1     PDGFRA       5156          D842V  Gastrointestinal Stromal Tumor
# 2     DNMT3A       1788           R882          Acute Myeloid Leukemia
# 3     DNMT3A       1788           R882          Acute Myeloid Leukemia
# 4       JAK2       3717          V617F        Chronic Myeloid Leukemia
# ...      ...        ...            ...                             ...
# 1071    KRAS       3845           G12R               Pancreatic Cancer
# 1072    KRAS       3845           G12D               Pancreatic Cancer
# 1073    ROS1       6098  REARRANGEMENT       Colorectal Adenocarcinoma
# 1074    KRAS       3845           G12D      Tumor Of Exocrine Pancreas
# 1075    FLT3       2322          T227M            Renal Cell Carcinoma
#
#          doid       drugs evidence_type evidence_direction evidence_level  \
# ...

# %%
df = pd.merge(df, df42, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# 2     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 3     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 4       JAK2       3717.0     V617F        Chronic Myeloid Leukemia   8552.0
# ...      ...          ...       ...                             ...      ...
# 3883     NaN          NaN       NaN                             NaN      NaN
# 3884     NaN          NaN       NaN                             NaN      NaN
# 3885     NaN          NaN       NaN                             NaN      NaN
# 3886     NaN          NaN       NaN                             NaN      NaN
# 3887     NaN          NaN       NaN                             NaN      NaN
#
# ...

# %%
df43 = pd.read_csv('01-May-2017-ClinicalEvidenceSummaries.csv')
df43
# Out:
#         gene  entrez_id           variant                         disease  \
# 0       JAK2       3717             V617F               Lymphoid Leukemia
# 1     PDGFRA       5156             D842V  Gastrointestinal Stromal Tumor
# 2     DNMT3A       1788              R882          Acute Myeloid Leukemia
# 3     DNMT3A       1788              R882          Acute Myeloid Leukemia
# 4       JAK2       3717             V617F        Chronic Myeloid Leukemia
# ...      ...        ...               ...                             ...
# 1892    EGFR       1956  EXON 19 DELETION   Non-small Cell Lung Carcinoma
# 1893    EGFR       1956             L858R   Non-small Cell Lung Carcinoma
# 1894    KRAS       3845          MUTATION   Non-small Cell Lung Carcinoma
# 1895    EGFR       1956     AMPLIFICATION   Non-small Cell Lung Carcinoma
# 1896  CTNNB1       1499              S45P            Desmoid Fibromatosis
#
#          doid                    drugs evidence_type evidence_direction  \
# ...

# %%
df = pd.merge(df, df43, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/4179008961.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'ensembl_version_x', 'evidence_type_x', 'chromosome_x', 'clinical_significance_x', 'stop2_x', 'variant_summary_x', 'representative_transcript_x', 'evidence_civic_url_x', 'entrez_id_x', 'disease_x', 'doid_x', 'variant_origin_x', 'reference_bases_x', 'evidence_status_x', 'representative_transcript2_x', 'chromosome2_x', 'start_x', 'drugs_x', 'gene_civic_url_x', 'variant_civic_url_x', 'variant_x', 'evidence_level_x', 'gene_id_x', 'evidence_id_x', 'citation_x', 'variant_id_x', 'evidence_direction_x', 'rating_x', 'stop_x', 'reference_build_x', 'gene_x', 'evidence_statement_x', 'pubmed_id_x', 'variant_bases_x', 'start2_x', 'last_review_date_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df43, right_index=True, left_index=True, how = 'outer')
# ...

# %%
df44 = pd.read_csv('01-May-2018-ClinicalEvidenceSummaries.csv')
df44
# Out:
#         gene  entrez_id           variant  \
# 0       JAK2       3717             V617F
# 1     PDGFRA       5156             D842V
# 2     DNMT3A       1788              R882
# 3     DNMT3A       1788              R882
# 4       JAK2       3717             V617F
# ...      ...        ...               ...
# 2520    BCL2        596          MUTATION
# 2521   RASA1       5921  LOSS-OF-FUNCTION
# 2522    TLK2      11011     AMPLIFICATION
# 2523     ALK        238       ALK FUSIONS
# 2524     ALK        238       ALK FUSIONS
#
#                                                disease     doid phenotypes  \
# 0                                    Lymphoid Leukemia  10747.0        NaN
# 1                       Gastrointestinal Stromal Tumor   9253.0        NaN
# 2                               Acute Myeloid Leukemia   9119.0        NaN
# 3                               Acute Myeloid Leukemia   9119.0        NaN
# 4                             Chronic Myeloid Leukemia   8552.0        NaN
# ...

# %%
df = pd.merge(df, df44, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# 2     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 3     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 4       JAK2       3717.0     V617F        Chronic Myeloid Leukemia   8552.0
# ...      ...          ...       ...                             ...      ...
# 3883     NaN          NaN       NaN                             NaN      NaN
# 3884     NaN          NaN       NaN                             NaN      NaN
# 3885     NaN          NaN       NaN                             NaN      NaN
# 3886     NaN          NaN       NaN                             NaN      NaN
# 3887     NaN          NaN       NaN                             NaN      NaN
#
# ...

# %%
df45 = pd.read_csv('01-May-2019-ClinicalEvidenceSummaries.csv')
df45
# Out:
#         gene  entrez_id           variant                         disease  \
# 0       JAK2       3717             V617F               Lymphoid Leukemia
# 1     PDGFRA       5156             D842V  Gastrointestinal Stromal Tumor
# 2     DNMT3A       1788              R882          Acute Myeloid Leukemia
# 3     DNMT3A       1788              R882          Acute Myeloid Leukemia
# 4       JAK2       3717             V617F        Chronic Myeloid Leukemia
# ...      ...        ...               ...                             ...
# 2766    BRAF        673             V600E               Colorectal Cancer
# 2767    BRAF        673          MUTATION               Colorectal Cancer
# 2768    BRAF        673          MUTATION               Colorectal Cancer
# 2769    TP53       7157             R248Q                        Lymphoma
# 2770   CRLF2      64109  CRLF2-IGH fusion  Adult B-Lymphoblastic Leukemia
#
#          doid phenotypes drugs drug_interaction_type evidence_type  \
# ...

# %%
df = pd.merge(df, df45, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/4020360775.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'ensembl_version_x', 'evidence_type_x', 'chromosome_x', 'clinical_significance_x', 'stop2_x', 'variant_summary_x', 'representative_transcript_x', 'evidence_civic_url_x', 'entrez_id_x', 'disease_x', 'nct_ids_x', 'doid_x', 'variant_origin_x', 'reference_bases_x', 'evidence_status_x', 'representative_transcript2_x', 'chromosome2_x', 'start_x', 'drugs_x', 'gene_civic_url_x', 'variant_civic_url_x', 'variant_x', 'evidence_level_x', 'gene_id_x', 'evidence_id_x', 'citation_x', 'variant_id_x', 'evidence_direction_x', 'rating_x', 'stop_x', 'reference_build_x', 'gene_x', 'evidence_statement_x', 'variant_bases_x', 'start2_x', 'last_review_date_x', 'phenotypes_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df45, right_index=True, left_index=True, how = 'outer')
# ...

# %%
df46 = pd.read_csv('01-May-2020-ClinicalEvidenceSummaries.csv')
df46
# Out:
#         gene  entrez_id        variant  \
# 0       JAK2       3717          V617F
# 1     PDGFRA       5156          D842V
# 2     DNMT3A       1788           R882
# 3     DNMT3A       1788           R882
# 4       JAK2       3717          V617F
# ...      ...        ...            ...
# 3426    JAK2       3717    ZNF340-JAK2
# 3427    ABL1         25  BCR-ABL F359V
# 3428  PIK3CA       5290          V955I
# 3429    ABL1         25      Double Ph
# 3430    JAK2       3717     SSBP2-JAK2
#
#                                                disease     doid phenotypes  \
# 0                                    Lymphoid Leukemia  10747.0        NaN
# 1                       Gastrointestinal Stromal Tumor   9253.0        NaN
# 2                               Acute Myeloid Leukemia   9119.0        NaN
# 3                               Acute Myeloid Leukemia   9119.0        NaN
# 4                             Chronic Myeloid Leukemia   8552.0        NaN
# ...

# %%
df = pd.merge(df, df46, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/2803490763.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'source_type_x', 'asco_abstract_id_x', 'drug_interaction_type_x', 'citation_id_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df46, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# 2     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 3     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 4       JAK2       3717.0     V617F        Chronic Myeloid Leukemia   8552.0
# ...      ...          ...       ...                             ...      ...
# ...

# %%
df47 = pd.read_csv('01-May-2021-ClinicalEvidenceSummaries.csv')
df47
# Out:
#          gene  entrez_id      variant  \
# 0        JAK2       3717        V617F
# 1      PDGFRA       5156        D842V
# 2      DNMT3A       1788         R882
# 3      DNMT3A       1788         R882
# 4        JAK2       3717        V617F
# ...       ...        ...          ...
# 3778     ABL1         25  RANBP2-ABL1
# 3779  PPP2R1A       5518        P179R
# 3780   CDKN1A       1026    rs1059234
# 3781     TP53       7157        P250L
# 3782     TP53       7157        A161T
#
#                                                disease     doid phenotypes  \
# 0                                    Lymphoid Leukemia   1037.0        NaN
# 1                       Gastrointestinal Stromal Tumor   9253.0        NaN
# 2                               Acute Myeloid Leukemia   9119.0        NaN
# 3                               Acute Myeloid Leukemia   9119.0        NaN
# 4                             Chronic Myeloid Leukemia   8552.0        NaN
# ...

# %%
df = pd.merge(df, df47, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/915395000.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'ensembl_version_x', 'evidence_type_x', 'chromosome_x', 'clinical_significance_x', 'stop2_x', 'variant_summary_x', 'representative_transcript_x', 'evidence_civic_url_x', 'entrez_id_x', 'disease_x', 'nct_ids_x', 'doid_x', 'variant_origin_x', 'reference_bases_x', 'evidence_status_x', 'representative_transcript2_x', 'chromosome2_x', 'start_x', 'drugs_x', 'gene_civic_url_x', 'variant_civic_url_x', 'variant_x', 'evidence_level_x', 'gene_id_x', 'evidence_id_x', 'citation_x', 'variant_id_x', 'evidence_direction_x', 'rating_x', 'stop_x', 'reference_build_x', 'gene_x', 'evidence_statement_x', 'variant_bases_x', 'start2_x', 'last_review_date_x', 'phenotypes_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df47, right_index=True, left_index=True, how = 'outer')
# ...

# %%
df48 = pd.read_csv('01-Nov-2016-ClinicalEvidenceSummaries.csv')
df48
# Out:
#         gene  entrez_id    variant                                  disease  \
# 0       JAK2       3717      V617F                        Lymphoid Leukemia
# 1     PDGFRA       5156      D842V           Gastrointestinal Stromal Tumor
# 2     DNMT3A       1788       R882                   Acute Myeloid Leukemia
# 3     DNMT3A       1788       R882                   Acute Myeloid Leukemia
# 4       JAK2       3717      V617F                 Chronic Myeloid Leukemia
# ...      ...        ...        ...                                      ...
# 1558     NF1       4763       LOSS  Malignant Peripheral Nerve Sheath Tumor
# 1559   SH2B3      10019  RS3184504                        Colorectal Cancer
# 1560   ERBB3       2065      V104M                     Urothelial Carcinoma
# 1561   ERBB3       2065      R103G                     Urothelial Carcinoma
# 1562   ERBB3       2065      G284R                     Urothelial Carcinoma
#
# ...

# %%
df = pd.merge(df, df48, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/3888911575.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'pubmed_id_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df48, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# 2     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 3     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 4       JAK2       3717.0     V617F        Chronic Myeloid Leukemia   8552.0
# ...      ...          ...       ...                             ...      ...
# 3883     NaN          NaN       NaN                             NaN      NaN
# ...

# %%
df49 = pd.read_csv('01-Nov-2017-ClinicalEvidenceSummaries.csv')
df49
# Out:
#         gene  entrez_id           variant  \
# 0       JAK2       3717             V617F
# 1     PDGFRA       5156             D842V
# 2     DNMT3A       1788              R882
# 3     DNMT3A       1788              R882
# 4       JAK2       3717             V617F
# ...      ...        ...               ...
# 2342   BRCA1        672  LOSS-OF-FUNCTION
# 2343   RAD50      10111            L1237F
# 2344     MET       4233    OVEREXPRESSION
# 2345    PTEN       5728              LOSS
# 2346  ERRFI1      54206           E384Ter
#
#                                    disease     doid               drugs  \
# 0                        Lymphoid Leukemia  10747.0                 NaN
# 1           Gastrointestinal Stromal Tumor   9253.0                 NaN
# 2                   Acute Myeloid Leukemia   9119.0                 NaN
# 3                   Acute Myeloid Leukemia   9119.0                 NaN
# 4                 Chronic Myeloid Leukemia   8552.0                 NaN
# ...

# %%
df = pd.merge(df, df49, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/1211794578.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'ensembl_version_x', 'evidence_type_x', 'chromosome_x', 'clinical_significance_x', 'stop2_x', 'variant_summary_x', 'representative_transcript_x', 'evidence_civic_url_x', 'entrez_id_x', 'disease_x', 'doid_x', 'variant_origin_x', 'reference_bases_x', 'evidence_status_x', 'representative_transcript2_x', 'chromosome2_x', 'start_x', 'drugs_x', 'gene_civic_url_x', 'variant_civic_url_x', 'variant_x', 'evidence_level_x', 'gene_id_x', 'evidence_id_x', 'citation_x', 'variant_id_x', 'evidence_direction_x', 'rating_x', 'stop_x', 'reference_build_x', 'gene_x', 'evidence_statement_x', 'variant_bases_x', 'start2_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df49, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# ...

# %%
df50 = pd.read_csv('01-Nov-2018-ClinicalEvidenceSummaries.csv')
df50
# Out:
#         gene  entrez_id           variant                             disease  \
# 0       JAK2       3717             V617F                   Lymphoid Leukemia
# 1     PDGFRA       5156             D842V      Gastrointestinal Stromal Tumor
# 2     DNMT3A       1788              R882              Acute Myeloid Leukemia
# 3     DNMT3A       1788              R882              Acute Myeloid Leukemia
# 4       JAK2       3717             V617F            Chronic Myeloid Leukemia
# ...      ...        ...               ...                                 ...
# 2907     VHL       7428  *214G (c.641T>G)           Von Hippel-Lindau Disease
# 2908     VHL       7428   E70K (c.208G>A)           Von Hippel-Lindau Disease
# 2909     VHL       7428   E70K (c.208G>A)           Von Hippel-Lindau Disease
# 2910   NTRK3       4916        ETV6-NTRK3  Pediatric B-lymphoblastic Leukemia
# 2911   ACVR1         90             G328V    Diffuse Intrinsic Pontine Glioma
#
# ...

# %%
df = pd.merge(df, df50, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/1282904084.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'pubmed_id_x', 'last_review_date_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df50, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# 2     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 3     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 4       JAK2       3717.0     V617F        Chronic Myeloid Leukemia   8552.0
# ...      ...          ...       ...                             ...      ...
# 3883     NaN          NaN       NaN                             NaN      NaN
# ...

# %%
df51 = pd.read_csv('01-Nov-2019-ClinicalEvidenceSummaries.csv')
df51
# Out:
#         gene  entrez_id        variant                         disease  \
# 0       JAK2       3717          V617F               Lymphoid Leukemia
# 1     PDGFRA       5156          D842V  Gastrointestinal Stromal Tumor
# 2     DNMT3A       1788           R882          Acute Myeloid Leukemia
# 3     DNMT3A       1788           R882          Acute Myeloid Leukemia
# 4       JAK2       3717          V617F        Chronic Myeloid Leukemia
# ...      ...        ...            ...                             ...
# 2825     KIT       3815          S628N                        Melanoma
# 2826     KIT       3815          D816V                          Cancer
# 2827     MET       4233         R1004G            Head And Neck Cancer
# 2828   FGF19       9965       Positive        Hepatocellular Carcinoma
# 2829   ERBB2       2064  AMPLIFICATION              Cholangiocarcinoma
#
#          doid phenotypes                    drugs drug_interaction_type  \
# ...

# %%
df = pd.merge(df, df51, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/2263389768.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'ensembl_version_x', 'evidence_type_x', 'chromosome_x', 'clinical_significance_x', 'stop2_x', 'variant_summary_x', 'representative_transcript_x', 'evidence_civic_url_x', 'entrez_id_x', 'disease_x', 'nct_ids_x', 'doid_x', 'variant_origin_x', 'reference_bases_x', 'evidence_status_x', 'representative_transcript2_x', 'chromosome2_x', 'start_x', 'drugs_x', 'gene_civic_url_x', 'variant_civic_url_x', 'variant_x', 'evidence_level_x', 'source_type_x', 'drug_interaction_type_x', 'gene_id_x', 'evidence_id_x', 'citation_x', 'variant_id_x', 'evidence_direction_x', 'rating_x', 'citation_id_x', 'stop_x', 'reference_build_x', 'gene_x', 'evidence_statement_x', 'variant_bases_x', 'asco_abstract_id_x', 'start2_x', 'phenotypes_x'} in the result is deprecated and will raise a MergeError in a future version.
# ...

# %%
df53 = pd.read_csv('01-Nov-2020-ClinicalEvidenceSummaries.csv')
df53
# Out:
#         gene  entrez_id           variant  \
# 0       JAK2       3717             V617F
# 1     PDGFRA       5156             D842V
# 2     DNMT3A       1788              R882
# 3     DNMT3A       1788              R882
# 4       JAK2       3717             V617F
# ...      ...        ...               ...
# 3598   FGFR3       2261             S249C
# 3599   NTRK1       4914      SQSTM1-NTRK1
# 3600    ATRX        546  Loss-of-function
# 3601   FOXO1       2308        PAX3-FOXO1
# 3602   FOXO1       2308        PAX7-FOXO1
#
#                                                 disease     doid  \
# 0                                     Lymphoid Leukemia  10747.0
# 1                        Gastrointestinal Stromal Tumor   9253.0
# 2                                Acute Myeloid Leukemia   9119.0
# 3                                Acute Myeloid Leukemia   9119.0
# 4                              Chronic Myeloid Leukemia   8552.0
# ...

# %%
df = pd.merge(df, df53, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/1019806592.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'last_review_date_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df53, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# 2     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 3     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 4       JAK2       3717.0     V617F        Chronic Myeloid Leukemia   8552.0
# ...      ...          ...       ...                             ...      ...
# 3883     NaN          NaN       NaN                             NaN      NaN
# ...

# %%
df54 = pd.read_csv('01-Nov-2021-ClinicalEvidenceSummaries.csv')
df54
# Out:
#         gene  entrez_id       variant                          disease  \
# 0       JAK2       3717         V617F                Lymphoid Leukemia
# 1     PDGFRA       5156         D842V   Gastrointestinal Stromal Tumor
# 2     DNMT3A       1788          R882           Acute Myeloid Leukemia
# 3     DNMT3A       1788          R882           Acute Myeloid Leukemia
# 4       JAK2       3717         V617F         Chronic Myeloid Leukemia
# ...      ...        ...           ...                              ...
# 3830   MYOD1       4654         L122R                 Rhabdomyosarcoma
# 3831    TP53       7157    ALTERATION                 Rhabdomyosarcoma
# 3832   NUP98       4928    NUP98-NSD1           Acute Myeloid Leukemia
# 3833   PDGFB       5155  COL1A1-PDGFB  Dermatofibrosarcoma Protuberans
# 3834  CTNNB1       1499          S45F                    Desmoid Tumor
#
#          doid                         phenotypes drugs drug_interaction_type  \
# ...

# %%
df = pd.merge(df, df54, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/1205715835.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'ensembl_version_x', 'evidence_type_x', 'chromosome_x', 'clinical_significance_x', 'is_flagged_x', 'stop2_x', 'variant_summary_x', 'representative_transcript_x', 'evidence_civic_url_x', 'entrez_id_x', 'disease_x', 'nct_ids_x', 'doid_x', 'variant_origin_x', 'reference_bases_x', 'evidence_status_x', 'representative_transcript2_x', 'chromosome2_x', 'start_x', 'drugs_x', 'gene_civic_url_x', 'variant_civic_url_x', 'variant_x', 'evidence_level_x', 'drug_interaction_type_x', 'source_type_x', 'gene_id_x', 'evidence_id_x', 'citation_x', 'variant_id_x', 'evidence_direction_x', 'rating_x', 'citation_id_x', 'stop_x', 'reference_build_x', 'gene_x', 'evidence_statement_x', 'variant_bases_x', 'asco_abstract_id_x', 'start2_x', 'phenotypes_x'} in the result is deprecated and will raise a MergeError in a future version.
# ...

# %%
df55 = pd.read_csv('01-Oct-2017-ClinicalEvidenceSummaries.csv')
df55
# Out:
#         gene  entrez_id           variant  \
# 0       JAK2       3717             V617F
# 1     PDGFRA       5156             D842V
# 2     DNMT3A       1788              R882
# 3     DNMT3A       1788              R882
# 4       JAK2       3717             V617F
# ...      ...        ...               ...
# 2309  ARID1A       8289   UNDEREXPRESSION
# 2310   BRCA1        672  LOSS-OF-FUNCTION
# 2311   RAD50      10111            L1237F
# 2312     MET       4233    OVEREXPRESSION
# 2313    PTEN       5728              LOSS
#
#                                    disease     doid               drugs  \
# 0                        Lymphoid Leukemia  10747.0                 NaN
# 1           Gastrointestinal Stromal Tumor   9253.0                 NaN
# 2                   Acute Myeloid Leukemia   9119.0                 NaN
# 3                   Acute Myeloid Leukemia   9119.0                 NaN
# 4                 Chronic Myeloid Leukemia   8552.0                 NaN
# ...

# %%
df = pd.merge(df, df55, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/546645213.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'last_review_date_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df55, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# 2     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 3     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 4       JAK2       3717.0     V617F        Chronic Myeloid Leukemia   8552.0
# ...      ...          ...       ...                             ...      ...
# 3883     NaN          NaN       NaN                             NaN      NaN
# ...

# %%
df56 = pd.read_csv('01-Oct-2018-ClinicalEvidenceSummaries.csv')
df56
# Out:
#         gene  entrez_id           variant                         disease  \
# 0       JAK2       3717             V617F               Lymphoid Leukemia
# 1     PDGFRA       5156             D842V  Gastrointestinal Stromal Tumor
# 2     DNMT3A       1788              R882          Acute Myeloid Leukemia
# 3     DNMT3A       1788              R882          Acute Myeloid Leukemia
# 4       JAK2       3717             V617F        Chronic Myeloid Leukemia
# ...      ...        ...               ...                             ...
# 2895   NTRK1       4914     NTRK1 FUSIONS                          Cancer
# 2896   NTRK3       4916     NTRK3 FUSIONS                          Cancer
# 2897   NTRK1       4914     NTRK1 FUSIONS                          Cancer
# 2898   PRKCB       5579             D427N           Adult T-cell Leukemia
# 2899     VHL       7428  *214G (c.641T>G)       Von Hippel-Lindau Disease
#
#          doid        phenotypes          drugs evidence_type  \
# ...

# %%
df = pd.merge(df, df56, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/1860574309.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'ensembl_version_x', 'evidence_type_x', 'chromosome_x', 'clinical_significance_x', 'stop2_x', 'variant_summary_x', 'representative_transcript_x', 'evidence_civic_url_x', 'entrez_id_x', 'disease_x', 'doid_x', 'variant_origin_x', 'reference_bases_x', 'evidence_status_x', 'representative_transcript2_x', 'chromosome2_x', 'start_x', 'drugs_x', 'gene_civic_url_x', 'variant_civic_url_x', 'variant_x', 'evidence_level_x', 'gene_id_x', 'evidence_id_x', 'citation_x', 'variant_id_x', 'evidence_direction_x', 'rating_x', 'stop_x', 'reference_build_x', 'gene_x', 'evidence_statement_x', 'pubmed_id_x', 'variant_bases_x', 'start2_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df56, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# ...

# %%
df58 = pd.read_csv('01-Oct-2019-ClinicalEvidenceSummaries.csv')
df58
# Out:
#         gene  entrez_id                       variant  \
# 0       JAK2       3717                         V617F
# 1     PDGFRA       5156                         D842V
# 2     DNMT3A       1788                          R882
# 3     DNMT3A       1788                          R882
# 4       JAK2       3717                         V617F
# ...      ...        ...                           ...
# 2818     KIT       3815                         T670I
# 2819     KIT       3815                         T670I
# 2820     ALK        238  ALTERNATIVE TRANSCRIPT (ATI)
# 2821     KIT       3815                         S628N
# 2822     KIT       3815                         D816V
#
#                              disease     doid phenotypes                drugs  \
# 0                  Lymphoid Leukemia  10747.0        NaN                  NaN
# 1     Gastrointestinal Stromal Tumor   9253.0        NaN                  NaN
# 2             Acute Myeloid Leukemia   9119.0        NaN                  NaN
# ...

# %%
df = pd.merge(df, df58, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/769344803.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'nct_ids_x', 'last_review_date_x', 'phenotypes_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df58, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# 2     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 3     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 4       JAK2       3717.0     V617F        Chronic Myeloid Leukemia   8552.0
# ...      ...          ...       ...                             ...      ...
# 3883     NaN          NaN       NaN                             NaN      NaN
# ...

# %%
df59 = pd.read_csv('01-Oct-2020-ClinicalEvidenceSummaries.csv')
df59
# Out:
#         gene  entrez_id           variant  \
# 0       JAK2       3717             V617F
# 1     PDGFRA       5156             D842V
# 2     DNMT3A       1788              R882
# 3     DNMT3A       1788              R882
# 4       JAK2       3717             V617F
# ...      ...        ...               ...
# 3576    BCL2        596             G101V
# 3577     RET       5979       RET FUSIONS
# 3578   FGFR3       2261             S249C
# 3579   NTRK1       4914      SQSTM1-NTRK1
# 3580    ATRX        546  Loss-of-function
#
#                                                 disease     doid  \
# 0                                     Lymphoid Leukemia  10747.0
# 1                        Gastrointestinal Stromal Tumor   9253.0
# 2                                Acute Myeloid Leukemia   9119.0
# 3                                Acute Myeloid Leukemia   9119.0
# 4                              Chronic Myeloid Leukemia   8552.0
# ...

# %%
df = pd.merge(df, df59, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/4123233506.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'ensembl_version_x', 'evidence_type_x', 'chromosome_x', 'clinical_significance_x', 'stop2_x', 'variant_summary_x', 'representative_transcript_x', 'evidence_civic_url_x', 'entrez_id_x', 'disease_x', 'doid_x', 'variant_origin_x', 'reference_bases_x', 'evidence_status_x', 'representative_transcript2_x', 'chromosome2_x', 'start_x', 'drugs_x', 'gene_civic_url_x', 'variant_civic_url_x', 'variant_x', 'evidence_level_x', 'drug_interaction_type_x', 'source_type_x', 'gene_id_x', 'evidence_id_x', 'citation_x', 'variant_id_x', 'evidence_direction_x', 'rating_x', 'citation_id_x', 'stop_x', 'reference_build_x', 'gene_x', 'evidence_statement_x', 'variant_bases_x', 'asco_abstract_id_x', 'start2_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df59, right_index=True, left_index=True, how = 'outer')
# ...

# %%
df60 = pd.read_csv('01-Oct-2021-ClinicalEvidenceSummaries.csv')
df60
# Out:
#         gene  entrez_id     variant                         disease    doid  \
# 0       JAK2       3717       V617F               Lymphoid Leukemia  1037.0
# 1     PDGFRA       5156       D842V  Gastrointestinal Stromal Tumor  9253.0
# 2     DNMT3A       1788        R882          Acute Myeloid Leukemia  9119.0
# 3     DNMT3A       1788        R882          Acute Myeloid Leukemia  9119.0
# 4       JAK2       3717       V617F        Chronic Myeloid Leukemia  8552.0
# ...      ...        ...         ...                             ...     ...
# 3828    EZH2       2146       Y641S                             NaN     NaN
# 3829    BRAF        673       G463E                          Cancer   162.0
# 3830   MYOD1       4654       L122R                Rhabdomyosarcoma  3247.0
# 3831    TP53       7157  ALTERATION                Rhabdomyosarcoma  3247.0
# 3832   NUP98       4928  NUP98-NSD1          Acute Myeloid Leukemia  9119.0
#
# ...

# %%
df = pd.merge(df, df60, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/3307585560.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'nct_ids_x', 'last_review_date_x', 'phenotypes_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df60, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# 2     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 3     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 4       JAK2       3717.0     V617F        Chronic Myeloid Leukemia   8552.0
# ...      ...          ...       ...                             ...      ...
# 3883     NaN          NaN       NaN                             NaN      NaN
# ...

# %%
df61 = pd.read_csv('01-Sep-2015-ClinicalEvidenceSummaries.csv')
df61
# Out:
#        gene  entrez_id           variant  \
# 0      JAK2       3717             V617F
# 1    PDGFRA       5156             D842V
# 2    DNMT3A       1788              R882
# 3    DNMT3A       1788              R882
# 4      JAK2       3717             V617F
# ..      ...        ...               ...
# 471   ERBB2       2064    OVEREXPRESSION
# 472   ERBB2       2064    OVEREXPRESSION
# 473    KRAS       3845  EXON 1 MUTATIONS
# 474   CHEK2      11200  LOSS-OF-FUNCTION
# 475  DNAJB1       3337     DNAJB1-PRKACA
#
#                                     disease     doid        drugs pubchem_ids  \
# 0                         Lymphoid Leukemia  10747.0          NaN         NaN
# 1            Gastrointestinal Stromal Tumor   9253.0          NaN         NaN
# 2                    Acute Myeloid Leukemia   9119.0          NaN         NaN
# 3                    Acute Myeloid Leukemia   9119.0          NaN         NaN
# ...

# %%
df = pd.merge(df, df61, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/1285913085.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'entrez_id_x', 'disease_x', 'variant_x', 'gene_x', 'doid_x', 'evidence_direction_x', 'evidence_type_x', 'citation_x', 'clinical_significance_x', 'drugs_x', 'rating_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df61, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# 2     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 3     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 4       JAK2       3717.0     V617F        Chronic Myeloid Leukemia   8552.0
# ...

# %%
df63 = pd.read_csv('01-Sep-2016-ClinicalEvidenceSummaries.csv')
df63
# Out:
#         gene  entrez_id     variant                         disease   doid  \
# 0       JAK2       3717       V617F               Lymphoid Leukemia  10747
# 1     PDGFRA       5156       D842V  Gastrointestinal Stromal Tumor   9253
# 2     DNMT3A       1788        R882          Acute Myeloid Leukemia   9119
# 3     DNMT3A       1788        R882          Acute Myeloid Leukemia   9119
# 4       JAK2       3717       V617F        Chronic Myeloid Leukemia   8552
# ...      ...        ...         ...                             ...    ...
# 1445    KRAS       3845    MUTATION             Lung Adenocarcinoma   3910
# 1446    EGFR       1956    MUTATION             Lung Adenocarcinoma   3910
# 1447    EGFR       1956  EXPRESSION               Colorectal Cancer   9256
# 1448    EGFR       1956  EXPRESSION               Colorectal Cancer   9256
# 1449   SOX10       6663        LOSS                        Melanoma   1909
#
#             drugs evidence_type evidence_direction evidence_level  \
# ...

# %%
df = pd.merge(df, df63, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/1857046383.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'ensembl_version_x', 'chromosome_x', 'stop2_x', 'variant_summary_x', 'representative_transcript_x', 'evidence_civic_url_x', 'variant_origin_x', 'reference_bases_x', 'evidence_status_x', 'representative_transcript2_x', 'chromosome2_x', 'start_x', 'gene_civic_url_x', 'variant_civic_url_x', 'evidence_level_x', 'gene_id_x', 'evidence_id_x', 'variant_id_x', 'stop_x', 'reference_build_x', 'evidence_statement_x', 'pubmed_id_x', 'variant_bases_x', 'start2_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df63, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# ...

# %%
df65 = pd.read_csv('01-Sep-2017-ClinicalEvidenceSummaries.csv')
df65
# Out:
#         gene  entrez_id                   variant  \
# 0       JAK2       3717                     V617F
# 1     PDGFRA       5156                     D842V
# 2     DNMT3A       1788                      R882
# 3     DNMT3A       1788                      R882
# 4       JAK2       3717                     V617F
# ...      ...        ...                       ...
# 2233     VHL       7428   V66fs (c.197_220delTGA)
# 2234     VHL       7428  F76del (c.226_228delTTC)
# 2235  ARID1A       8289           UNDEREXPRESSION
# 2236  ARID1A       8289           UNDEREXPRESSION
# 2237   RAD50      10111                    L1237F
#
#                              disease     doid               drugs  \
# 0                  Lymphoid Leukemia  10747.0                 NaN
# 1     Gastrointestinal Stromal Tumor   9253.0                 NaN
# 2             Acute Myeloid Leukemia   9119.0                 NaN
# 3             Acute Myeloid Leukemia   9119.0                 NaN
# ...

# %%
df = pd.merge(df, df65, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/2935822206.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'entrez_id_x', 'disease_x', 'variant_x', 'gene_x', 'doid_x', 'evidence_direction_x', 'evidence_type_x', 'citation_x', 'clinical_significance_x', 'drugs_x', 'rating_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df65, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# 2     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 3     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 4       JAK2       3717.0     V617F        Chronic Myeloid Leukemia   8552.0
# ...

# %%
df66 = pd.read_csv('01-Sep-2020-ClinicalEvidenceSummaries.csv')
df66
# Out:
#         gene  entrez_id         variant                               disease  \
# 0       JAK2       3717           V617F                     Lymphoid Leukemia
# 1     PDGFRA       5156           D842V        Gastrointestinal Stromal Tumor
# 2     DNMT3A       1788            R882                Acute Myeloid Leukemia
# 3     DNMT3A       1788            R882                Acute Myeloid Leukemia
# 4       JAK2       3717           V617F              Chronic Myeloid Leukemia
# ...      ...        ...             ...                                   ...
# 3550  PIK3CA       5290           I391M  Her2-receptor Positive Breast Cancer
# 3551  PIK3CA       5290        MUTATION  Her2-receptor Positive Breast Cancer
# 3552    PTEN       5728            LOSS  Her2-receptor Positive Breast Cancer
# 3553   ERBB3       2065  OVEREXPRESSION  Her2-receptor Positive Breast Cancer
# 3554    KRAS       3845        Wildtype                     Colorectal Cancer
#
# ...

# %%
df = pd.merge(df, df66, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/672729863.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'ensembl_version_x', 'chromosome_x', 'stop2_x', 'variant_summary_x', 'representative_transcript_x', 'evidence_civic_url_x', 'variant_origin_x', 'reference_bases_x', 'evidence_status_x', 'representative_transcript2_x', 'chromosome2_x', 'start_x', 'gene_civic_url_x', 'variant_civic_url_x', 'evidence_level_x', 'source_type_x', 'drug_interaction_type_x', 'gene_id_x', 'evidence_id_x', 'variant_id_x', 'citation_id_x', 'stop_x', 'reference_build_x', 'evidence_statement_x', 'variant_bases_x', 'asco_abstract_id_x', 'start2_x', 'last_review_date_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df66, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# ...

# %%
df67 = pd.read_csv('01-Sep-2019-ClinicalEvidenceSummaries.csv')
df67
# Out:
#         gene  entrez_id                       variant  \
# 0       JAK2       3717                         V617F
# 1     PDGFRA       5156                         D842V
# 2     DNMT3A       1788                          R882
# 3     DNMT3A       1788                          R882
# 4       JAK2       3717                         V617F
# ...      ...        ...                           ...
# 2818     KIT       3815                         T670I
# 2819     KIT       3815                         T670I
# 2820     ALK        238  ALTERNATIVE TRANSCRIPT (ATI)
# 2821     KIT       3815                         S628N
# 2822     KIT       3815                         D816V
#
#                              disease     doid phenotypes                drugs  \
# 0                  Lymphoid Leukemia  10747.0        NaN                  NaN
# 1     Gastrointestinal Stromal Tumor   9253.0        NaN                  NaN
# 2             Acute Myeloid Leukemia   9119.0        NaN                  NaN
# ...

# %%
df = pd.merge(df, df67, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/1067668094.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'entrez_id_x', 'disease_x', 'nct_ids_x', 'variant_x', 'gene_x', 'doid_x', 'evidence_direction_x', 'evidence_type_x', 'citation_x', 'clinical_significance_x', 'drugs_x', 'rating_x', 'phenotypes_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df67, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# 2     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 3     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 4       JAK2       3717.0     V617F        Chronic Myeloid Leukemia   8552.0
# ...

# %%
df68 = pd.read_csv('01-Sep-2019-ClinicalEvidenceSummaries.csv')
df68
# Out:
#         gene  entrez_id                       variant  \
# 0       JAK2       3717                         V617F
# 1     PDGFRA       5156                         D842V
# 2     DNMT3A       1788                          R882
# 3     DNMT3A       1788                          R882
# 4       JAK2       3717                         V617F
# ...      ...        ...                           ...
# 2818     KIT       3815                         T670I
# 2819     KIT       3815                         T670I
# 2820     ALK        238  ALTERNATIVE TRANSCRIPT (ATI)
# 2821     KIT       3815                         S628N
# 2822     KIT       3815                         D816V
#
#                              disease     doid phenotypes                drugs  \
# 0                  Lymphoid Leukemia  10747.0        NaN                  NaN
# 1     Gastrointestinal Stromal Tumor   9253.0        NaN                  NaN
# 2             Acute Myeloid Leukemia   9119.0        NaN                  NaN
# ...

# %%
df = pd.merge(df, df68, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/2980351048.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'ensembl_version_x', 'chromosome_x', 'stop2_x', 'variant_summary_x', 'representative_transcript_x', 'evidence_civic_url_x', 'variant_origin_x', 'reference_bases_x', 'evidence_status_x', 'representative_transcript2_x', 'chromosome2_x', 'start_x', 'gene_civic_url_x', 'variant_civic_url_x', 'evidence_level_x', 'source_type_x', 'drug_interaction_type_x', 'gene_id_x', 'evidence_id_x', 'variant_id_x', 'citation_id_x', 'stop_x', 'reference_build_x', 'evidence_statement_x', 'variant_bases_x', 'asco_abstract_id_x', 'start2_x', 'last_review_date_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df68, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# ...

# %%
df69 = pd.read_csv('01-Apr-2016-ClinicalEvidenceSummaries.csv')
df69
# Out:
#         gene  entrez_id           variant                         disease  \
# 0       JAK2       3717             V617F               Lymphoid Leukemia
# 1     PDGFRA       5156             D842V  Gastrointestinal Stromal Tumor
# 2     DNMT3A       1788              R882          Acute Myeloid Leukemia
# 3     DNMT3A       1788              R882          Acute Myeloid Leukemia
# 4       JAK2       3717             V617F        Chronic Myeloid Leukemia
# ...      ...        ...               ...                             ...
# 996     GNAQ       2776   EXON 5 MUTATION                  Uveal Melanoma
# 997   DNMT3A       1788          MUTATION        Myelodysplastic Syndrome
# 998      ALK        238  EML4-ALK E20;A20                          Cancer
# 999     ROS1       6098  CD74-ROS1 L2155S   Non-small Cell Lung Carcinoma
# 1000     ALK        238  EML4-ALK  V1180L   Non-small Cell Lung Carcinoma
#
#          doid                        drugs evidence_type evidence_direction  \
# ...

# %%
df = pd.merge(df, df69, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/4292370092.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'disease_x', 'entrez_id_x', 'variant_x', 'gene_x', 'doid_x', 'evidence_direction_x', 'evidence_type_x', 'pubmed_id_x', 'citation_x', 'clinical_significance_x', 'drugs_x', 'rating_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df69, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# 2     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 3     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 4       JAK2       3717.0     V617F        Chronic Myeloid Leukemia   8552.0
# ...

# %%
df70 = pd.read_csv('01-Apr-2017-ClinicalEvidenceSummaries.csv')
df70
# Out:
#         gene  entrez_id        variant                         disease  \
# 0       JAK2       3717          V617F               Lymphoid Leukemia
# 1     PDGFRA       5156          D842V  Gastrointestinal Stromal Tumor
# 2     DNMT3A       1788           R882          Acute Myeloid Leukemia
# 3     DNMT3A       1788           R882          Acute Myeloid Leukemia
# 4       JAK2       3717          V617F        Chronic Myeloid Leukemia
# ...      ...        ...            ...                             ...
# 1805   NTRK3       4916        FUSIONS                          Cancer
# 1806   NTRK1       4914   SQSTM1-NTRK1   Non-small Cell Lung Carcinoma
# 1807    ROS1       6098  REARRANGEMENT                          Cancer
# 1808     ALK        238    ALK FUSIONS                          Cancer
# 1809   NTRK1       4914     LMNA-NTRK1                         Sarcoma
#
#          doid                     drugs evidence_type evidence_direction  \
# ...

# %%
df = pd.merge(df, df70, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/3580959897.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'ensembl_version_x', 'chromosome_x', 'stop2_x', 'variant_summary_x', 'representative_transcript_x', 'evidence_civic_url_x', 'variant_origin_x', 'reference_bases_x', 'evidence_status_x', 'representative_transcript2_x', 'chromosome2_x', 'start_x', 'gene_civic_url_x', 'variant_civic_url_x', 'gene_id_x', 'evidence_id_x', 'variant_id_x', 'stop_x', 'reference_build_x', 'evidence_statement_x', 'variant_bases_x', 'start2_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df70, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# ...

# %%
df71 = pd.read_csv('01-Apr-2018-ClinicalEvidenceSummaries.csv')
df71
# Out:
#         gene  entrez_id           variant  \
# 0       JAK2     3717.0             V617F
# 1     PDGFRA     5156.0             D842V
# 2     DNMT3A     1788.0              R882
# 3     DNMT3A     1788.0              R882
# 4       JAK2     3717.0             V617F
# ...      ...        ...               ...
# 2501    BCL2      596.0          MUTATION
# 2502   RASA1     5921.0  LOSS-OF-FUNCTION
# 2503    TLK2    11011.0     AMPLIFICATION
# 2504     ALK      238.0       ALK FUSIONS
# 2505     ALK      238.0       ALK FUSIONS
#
#                                                disease     doid phenotypes  \
# 0                                    Lymphoid Leukemia  10747.0        NaN
# 1                       Gastrointestinal Stromal Tumor   9253.0        NaN
# 2                               Acute Myeloid Leukemia   9119.0        NaN
# 3                               Acute Myeloid Leukemia   9119.0        NaN
# 4                             Chronic Myeloid Leukemia   8552.0        NaN
# ...

# %%
df = pd.merge(df, df71, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/2016670448.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'entrez_id_x', 'nct_ids_x', 'disease_x', 'variant_x', 'gene_x', 'doid_x', 'evidence_direction_x', 'evidence_type_x', 'evidence_level_x', 'pubmed_id_x', 'citation_x', 'clinical_significance_x', 'drugs_x', 'rating_x', 'phenotypes_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df71, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# 2     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 3     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 4       JAK2       3717.0     V617F        Chronic Myeloid Leukemia   8552.0
# ...

# %%
df72 = pd.read_csv('01-Apr-2019-ClinicalEvidenceSummaries.csv')
df72
# Out:
#         gene  entrez_id           variant                         disease  \
# 0       JAK2       3717             V617F               Lymphoid Leukemia
# 1     PDGFRA       5156             D842V  Gastrointestinal Stromal Tumor
# 2     DNMT3A       1788              R882          Acute Myeloid Leukemia
# 3     DNMT3A       1788              R882          Acute Myeloid Leukemia
# 4       JAK2       3717             V617F        Chronic Myeloid Leukemia
# ...      ...        ...               ...                             ...
# 2759    BRAF        673             V600E               Colorectal Cancer
# 2760    BRAF        673             V600E               Colorectal Cancer
# 2761    BRAF        673          MUTATION               Colorectal Cancer
# 2762    BRAF        673          MUTATION               Colorectal Cancer
# 2763   CRLF2      64109  CRLF2-IGH fusion  Adult B-Lymphoblastic Leukemia
#
#          doid phenotypes drugs drug_interaction_type evidence_type  \
# ...

# %%
df = pd.merge(df, df72, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/1907833536.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'ensembl_version_x', 'chromosome_x', 'stop2_x', 'variant_summary_x', 'representative_transcript_x', 'evidence_civic_url_x', 'variant_origin_x', 'reference_bases_x', 'evidence_status_x', 'representative_transcript2_x', 'chromosome2_x', 'start_x', 'gene_civic_url_x', 'variant_civic_url_x', 'gene_id_x', 'evidence_id_x', 'variant_id_x', 'stop_x', 'reference_build_x', 'evidence_statement_x', 'variant_bases_x', 'start2_x', 'last_review_date_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df72, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# ...

# %%
df73 = pd.read_csv('01-Apr-2020-ClinicalEvidenceSummaries.csv')
df73
# Out:
#         gene  entrez_id        variant  \
# 0       JAK2       3717          V617F
# 1     PDGFRA       5156          D842V
# 2     DNMT3A       1788           R882
# 3     DNMT3A       1788           R882
# 4       JAK2       3717          V617F
# ...      ...        ...            ...
# 3006   DDIT3       1649      FUS-DDIT3
# 3007   NTRK3       4916     ETV6-NTRK3
# 3008   NTRK3       4916     ETV6-NTRK3
# 3009    ABL1         25  BCR-ABL F359V
# 3010  PIK3CA       5290          V955I
#
#                                       disease     doid phenotypes  \
# 0                           Lymphoid Leukemia  10747.0        NaN
# 1              Gastrointestinal Stromal Tumor   9253.0        NaN
# 2                      Acute Myeloid Leukemia   9119.0        NaN
# 3                      Acute Myeloid Leukemia   9119.0        NaN
# 4                    Chronic Myeloid Leukemia   8552.0        NaN
# ...                                       ...      ...        ...
# ...

# %%
df = pd.merge(df, df73, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/1112574295.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'entrez_id_x', 'disease_x', 'nct_ids_x', 'variant_x', 'gene_x', 'doid_x', 'evidence_direction_x', 'drug_interaction_type_x', 'evidence_type_x', 'evidence_level_x', 'source_type_x', 'citation_x', 'clinical_significance_x', 'asco_abstract_id_x', 'drugs_x', 'rating_x', 'phenotypes_x', 'citation_id_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df73, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# 2     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 3     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# ...

# %%
df74 = pd.read_csv('01-Apr-2021-ClinicalEvidenceSummaries.csv')
df74
# Out:
#          gene  entrez_id      variant  \
# 0        JAK2       3717        V617F
# 1      PDGFRA       5156        D842V
# 2      DNMT3A       1788         R882
# 3      DNMT3A       1788         R882
# 4        JAK2       3717        V617F
# ...       ...        ...          ...
# 3748     ABL1         25  NUP214-ABL1
# 3749     ABL1         25  LSM14A-ABL1
# 3750     BRAF        673        V600E
# 3751     ABL1         25    SNX2-ABL1
# 3752  PPP2R1A       5518        P179R
#
#                                                disease     doid phenotypes  \
# 0                                    Lymphoid Leukemia   1037.0        NaN
# 1                       Gastrointestinal Stromal Tumor   9253.0        NaN
# 2                               Acute Myeloid Leukemia   9119.0        NaN
# 3                               Acute Myeloid Leukemia   9119.0        NaN
# 4                             Chronic Myeloid Leukemia   8552.0        NaN
# ...

# %%
df = pd.merge(df, df74, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/4096991336.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'ensembl_version_x', 'chromosome_x', 'stop2_x', 'variant_summary_x', 'representative_transcript_x', 'evidence_civic_url_x', 'variant_origin_x', 'reference_bases_x', 'evidence_status_x', 'representative_transcript2_x', 'chromosome2_x', 'start_x', 'gene_civic_url_x', 'variant_civic_url_x', 'gene_id_x', 'evidence_id_x', 'variant_id_x', 'stop_x', 'reference_build_x', 'evidence_statement_x', 'variant_bases_x', 'start2_x', 'last_review_date_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df74, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# ...

# %%
df75 = pd.read_csv('01-Aug-2015-ClinicalEvidenceSummaries.csv')
df75
# Out:
#        gene  entrez_id              variant  \
# 0      JAK2       3717                V617F
# 1    PDGFRA       5156                D842V
# 2    DNMT3A       1788                 R882
# 3    DNMT3A       1788                 R882
# 4      JAK2       3717                V617F
# ..      ...        ...                  ...
# 466    TP53       7157             MUTATION
# 467    TP53       7157             MUTATION
# 468    TP53       7157  TRUNCATING MUTATION
# 469    TP53       7157  TRUNCATING MUTATION
# 470    TTF1       7270        AMPLIFICATION
#
#                                  disease     doid drugs pubchem_ids  \
# 0                      Lymphoid Leukemia  10747.0   NaN         NaN
# 1         Gastrointestinal Stromal Tumor   9253.0   NaN         NaN
# 2                 Acute Myeloid Leukemia   9119.0   NaN         NaN
# 3                 Acute Myeloid Leukemia   9119.0   NaN         NaN
# 4               Chronic Myeloid Leukemia   8552.0   NaN         NaN
# ...

# %%
df = pd.merge(df, df75, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/1198050818.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'entrez_id_x', 'disease_x', 'variant_x', 'gene_x', 'doid_x', 'evidence_direction_x', 'evidence_type_x', 'citation_x', 'clinical_significance_x', 'statement_x', 'drugs_x', 'rating_x', 'pubchem_ids_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df75, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# 2     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 3     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 4       JAK2       3717.0     V617F        Chronic Myeloid Leukemia   8552.0
# ...

# %%
df76 = pd.read_csv('01-Aug-2016-ClinicalEvidenceSummaries.csv')
df76
# Out:
#         gene  entrez_id           variant                         disease  \
# 0       JAK2       3717             V617F               Lymphoid Leukemia
# 1     PDGFRA       5156             D842V  Gastrointestinal Stromal Tumor
# 2     DNMT3A       1788              R882          Acute Myeloid Leukemia
# 3     DNMT3A       1788              R882          Acute Myeloid Leukemia
# 4       JAK2       3717             V617F        Chronic Myeloid Leukemia
# ...      ...        ...               ...                             ...
# 1380   MKI67       4288        EXPRESSION                 Prostate Cancer
# 1381     RB1       5925  LOSS-OF-FUNCTION         Glioblastoma Multiforme
# 1382  MAP2K1       5604             C121S                        Melanoma
# 1383  PIK3CA       5290          MUTATION                   Breast Cancer
# 1384     VHL       7428             R200W            Chuvash Polycythemia
#
#        doid                                   drugs evidence_type  \
# ...

# %%
df = pd.merge(df, df76, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/828395992.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'pubmed_id_x', 'evidence_level_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df76, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# 2     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 3     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 4       JAK2       3717.0     V617F        Chronic Myeloid Leukemia   8552.0
# ...      ...          ...       ...                             ...      ...
# 3883     NaN          NaN       NaN                             NaN      NaN
# ...

# %%
df77 = pd.read_csv('01-Aug-2017-ClinicalEvidenceSummaries.csv')
df77
# Out:
#         gene  entrez_id                   variant  \
# 0       JAK2       3717                     V617F
# 1     PDGFRA       5156                     D842V
# 2     DNMT3A       1788                      R882
# 3     DNMT3A       1788                      R882
# 4       JAK2       3717                     V617F
# ...      ...        ...                       ...
# 2149     VHL       7428     D92fs (c.275del18-nt)
# 2150     VHL       7428  F76del (c.226_228delTTC)
# 2151     VHL       7428        K159fs (c.475delA)
# 2152     VHL       7428   V66fs (c.197_220delTGA)
# 2153     VHL       7428  F76del (c.226_228delTTC)
#
#                              disease     doid drugs evidence_type  \
# 0                  Lymphoid Leukemia  10747.0   NaN    Diagnostic
# 1     Gastrointestinal Stromal Tumor   9253.0   NaN    Diagnostic
# 2             Acute Myeloid Leukemia   9119.0   NaN    Diagnostic
# 3             Acute Myeloid Leukemia   9119.0   NaN    Diagnostic
# ...

# %%
df = pd.merge(df, df77, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/1165860613.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'ensembl_version_x', 'evidence_type_x', 'chromosome_x', 'clinical_significance_x', 'stop2_x', 'variant_summary_x', 'representative_transcript_x', 'evidence_civic_url_x', 'entrez_id_x', 'disease_x', 'doid_x', 'variant_origin_x', 'reference_bases_x', 'evidence_status_x', 'representative_transcript2_x', 'chromosome2_x', 'start_x', 'drugs_x', 'gene_civic_url_x', 'variant_civic_url_x', 'variant_x', 'gene_id_x', 'evidence_id_x', 'citation_x', 'variant_id_x', 'evidence_direction_x', 'rating_x', 'stop_x', 'reference_build_x', 'gene_x', 'evidence_statement_x', 'variant_bases_x', 'start2_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df77, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# ...

# %%
df78 = pd.read_csv('01-Aug-2018-ClinicalEvidenceSummaries.csv')
df78
# Out:
#         gene  entrez_id                  variant  \
# 0       JAK2       3717                    V617F
# 1     PDGFRA       5156                    D842V
# 2     DNMT3A       1788                     R882
# 3     DNMT3A       1788                     R882
# 4       JAK2       3717                    V617F
# ...      ...        ...                      ...
# 2863    CALR        811                 MUTATION
# 2864    BRAF        673  intron 10 rearrangement
# 2865    BRAF        673   intron 9 rearrangement
# 2866    BRAF        673                    D594K
# 2867    BRAF        673                    D594K
#
#                              disease     doid phenotypes  \
# 0                  Lymphoid Leukemia  10747.0        NaN
# 1     Gastrointestinal Stromal Tumor   9253.0        NaN
# 2             Acute Myeloid Leukemia   9119.0        NaN
# 3             Acute Myeloid Leukemia   9119.0        NaN
# 4           Chronic Myeloid Leukemia   8552.0        NaN
# ...

# %%
df = pd.merge(df, df78, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/559932233.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'nct_ids_x', 'evidence_level_x', 'pubmed_id_x', 'last_review_date_x', 'phenotypes_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df78, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# 2     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 3     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 4       JAK2       3717.0     V617F        Chronic Myeloid Leukemia   8552.0
# ...      ...          ...       ...                             ...      ...
# ...

# %%
df79 = pd.read_csv('01-Aug-2019-ClinicalEvidenceSummaries.csv')
df79
# Out:
#         gene  entrez_id                       variant  \
# 0       JAK2       3717                         V617F
# 1     PDGFRA       5156                         D842V
# 2     DNMT3A       1788                          R882
# 3     DNMT3A       1788                          R882
# 4       JAK2       3717                         V617F
# ...      ...        ...                           ...
# 2812     KIT       3815                         N822K
# 2813     KIT       3815                         A829P
# 2814     KIT       3815                         T670I
# 2815     KIT       3815                         T670I
# 2816     ALK        238  ALTERNATIVE TRANSCRIPT (ATI)
#
#                              disease     doid phenotypes                drugs  \
# 0                  Lymphoid Leukemia  10747.0        NaN                  NaN
# 1     Gastrointestinal Stromal Tumor   9253.0        NaN                  NaN
# 2             Acute Myeloid Leukemia   9119.0        NaN                  NaN
# ...

# %%
df = pd.merge(df, df79, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/2801603787.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'ensembl_version_x', 'evidence_type_x', 'chromosome_x', 'clinical_significance_x', 'stop2_x', 'variant_summary_x', 'representative_transcript_x', 'evidence_civic_url_x', 'entrez_id_x', 'disease_x', 'doid_x', 'variant_origin_x', 'reference_bases_x', 'evidence_status_x', 'representative_transcript2_x', 'chromosome2_x', 'start_x', 'drugs_x', 'gene_civic_url_x', 'variant_civic_url_x', 'variant_x', 'source_type_x', 'drug_interaction_type_x', 'gene_id_x', 'evidence_id_x', 'citation_x', 'variant_id_x', 'evidence_direction_x', 'rating_x', 'citation_id_x', 'stop_x', 'reference_build_x', 'gene_x', 'evidence_statement_x', 'variant_bases_x', 'asco_abstract_id_x', 'start2_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df79, right_index=True, left_index=True, how = 'outer')
# ...

# %%
df80 = pd.read_csv('01-Aug-2020-ClinicalEvidenceSummaries.csv')
df80
# Out:
#         gene  entrez_id          variant                         disease  \
# 0       JAK2       3717            V617F               Lymphoid Leukemia
# 1     PDGFRA       5156            D842V  Gastrointestinal Stromal Tumor
# 2     DNMT3A       1788             R882          Acute Myeloid Leukemia
# 3     DNMT3A       1788             R882          Acute Myeloid Leukemia
# 4       JAK2       3717            V617F        Chronic Myeloid Leukemia
# ...      ...        ...              ...                             ...
# 3525    KRAS       3845  EXON 2 MUTATION               Colorectal Cancer
# 3526    BRAF        673            V600E               Colorectal Cancer
# 3527    BRAF        673            V600E               Colorectal Cancer
# 3528    ABL1         25    BCR-ABL Y253F        Chronic Myeloid Leukemia
# 3529    ABL1         25    BCR-ABL F317L        Chronic Myeloid Leukemia
#
#          doid phenotypes                             drugs  \
# ...

# %%
df = pd.merge(df, df80, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/467040070.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'last_review_date_x', 'nct_ids_x', 'evidence_level_x', 'phenotypes_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df80, right_index=True, left_index=True, how = 'outer')
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# 2     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 3     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 4       JAK2       3717.0     V617F        Chronic Myeloid Leukemia   8552.0
# ...      ...          ...       ...                             ...      ...
# 3883     NaN          NaN       NaN                             NaN      NaN
# ...

# %%
df81 = pd.read_csv('01-Aug-2021-ClinicalEvidenceSummaries.csv')
df81
# Out:
#         gene  entrez_id variant                         disease    doid  \
# 0       JAK2       3717   V617F               Lymphoid Leukemia  1037.0
# 1     PDGFRA       5156   D842V  Gastrointestinal Stromal Tumor  9253.0
# 2     DNMT3A       1788    R882          Acute Myeloid Leukemia  9119.0
# 3     DNMT3A       1788    R882          Acute Myeloid Leukemia  9119.0
# 4       JAK2       3717   V617F        Chronic Myeloid Leukemia  8552.0
# ...      ...        ...     ...                             ...     ...
# 3811    EZH2       2146   Y641N                             NaN     NaN
# 3812    EZH2       2146   Y641H                             NaN     NaN
# 3813    EZH2       2146   Y641S                             NaN     NaN
# 3814    BRAF        673   G463E                          Cancer   162.0
# 3815   MYOD1       4654   L122R                Rhabdomyosarcoma  3247.0
#
#      phenotypes drugs drug_interaction_type evidence_type evidence_direction  \
# ...

# %%
df = pd.merge(df, df81, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_1972/1036406939.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'ensembl_version_x', 'evidence_type_x', 'chromosome_x', 'clinical_significance_x', 'is_flagged_x', 'stop2_x', 'variant_summary_x', 'representative_transcript_x', 'evidence_civic_url_x', 'entrez_id_x', 'disease_x', 'doid_x', 'variant_origin_x', 'reference_bases_x', 'evidence_status_x', 'representative_transcript2_x', 'chromosome2_x', 'start_x', 'drugs_x', 'gene_civic_url_x', 'variant_civic_url_x', 'variant_x', 'drug_interaction_type_x', 'source_type_x', 'gene_id_x', 'evidence_id_x', 'citation_x', 'variant_id_x', 'evidence_direction_x', 'rating_x', 'citation_id_x', 'stop_x', 'reference_build_x', 'gene_x', 'evidence_statement_x', 'variant_bases_x', 'asco_abstract_id_x', 'start2_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df81, right_index=True, left_index=True, how = 'outer')
# ...

# %%
df82 = pd.read_csv('01-Dec-2015-ClinicalEvidenceSummaries.csv')
df82
# Out:
#        gene  entrez_id          variant                         disease  \
# 0      JAK2       3717            V617F               Lymphoid Leukemia
# 1    PDGFRA       5156            D842V  Gastrointestinal Stromal Tumor
# 2    DNMT3A       1788             R882          Acute Myeloid Leukemia
# 3    DNMT3A       1788             R882          Acute Myeloid Leukemia
# 4      JAK2       3717            V617F        Chronic Myeloid Leukemia
# ..      ...        ...              ...                             ...
# 513    EGFR       1956  EXON 4 DELETION       Epithelial Ovarian Cancer
# 514    KRAS       3845  3' UTR MUTATION       Epithelial Ovarian Cancer
# 515   ERCC5       2073  5' UTR MUTATION        Parietal Lobe Ependymoma
# 516     KIT       3815  3' UTR MUTATION      Acral Lentiginous Melanoma
# 517   NT5C2      22978            K359Q      Acute Lymphocytic Leukemia
#
#         doid                   drugs pubchem_ids evidence_type  \
# ...

# %%
dfEvidences = pd.merge(df, df82, right_index=True, left_index=True, how = 'outer')

dfEvidences.to_csv('dfEvidences.csv', index=False)

dfEvidences
# Out:
#       gene_x  entrez_id_x variant_x                       disease_x   doid_x  \
# 0       JAK2       3717.0     V617F               Lymphoid Leukemia  10747.0
# 1     PDGFRA       5156.0     D842V  Gastrointestinal Stromal Tumor   9253.0
# 2     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 3     DNMT3A       1788.0      R882          Acute Myeloid Leukemia   9119.0
# 4       JAK2       3717.0     V617F        Chronic Myeloid Leukemia   8552.0
# ...      ...          ...       ...                             ...      ...
# 3883     NaN          NaN       NaN                             NaN      NaN
# 3884     NaN          NaN       NaN                             NaN      NaN
# 3885     NaN          NaN       NaN                             NaN      NaN
# 3886     NaN          NaN       NaN                             NaN      NaN
# 3887     NaN          NaN       NaN                             NaN      NaN
#
# ...
