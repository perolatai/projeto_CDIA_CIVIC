# %% [markdown]
# # Junção CSV's Civic

# %% [markdown]
# Infelizmente, os dados que a API oferece não são suficientes para a realização da nossa análise. Por isso, usaremos dados fornecidos pelo CIVIC em formato TSV, que precisam ser convertidos para CSVs para que possamos trabalhar com esses dados. Assim como na API, os arquivos TSV também estão separados e precisam ser mesclados. Para isso, iremos utilizar a função "merge", que é usada para combinar dois ou mais conjuntos de dados com base em uma chave comum. Para essa etapa, precisamos apenas da importação do Pandas.

# %%
#Importação
import pandas as pd

# %% [markdown]
# A função "merge" receberá como entrada dois dataframes, "df_Assertion" e "df_Evidences", e retornará um novo dataframe que contém os dados combinados. Como mencionado anteriormente, os dados estão em formato TSV, mas foram convertidos para CSV com o uso de uma ferramenta externa. Abaixo, definiremos os arquivos que iremos utilizar.

# %%
#Definiçao dos arquivos que serão utilizados
df_Variant = pd.read_csv('01-Apr-2022-VariantSummaries.csv')
df_Evidences = pd.read_csv('01-Apr-2022-ClinicalEvidenceSummaries.csv')
df_Gene = pd.read_csv('01-Apr-2022-GeneSummaries.csv')
#df_Assertion = pd.read_csv('01-Apr-2022-AssertionSummaries.csv')

# %% [markdown]
# Possuímos quatro DataFrames diferentes: df_Variant, que possui **1533** linhas e **33** colunas, df_evidences, que possui **3897** linhas e **42** colunas, df_gene com **477** linhas e **7** colunas e, por último, df_Assertion com **22** linhas e **28** colunas.
#
# Antes de podermos realizar o merge, precisamos fazer um pequeno tratamento nos dados fornecidos. Inicialmente, precisamos trocar o nome de duas colunas do df_Assertion, que possuem os mesmos valores e significado no df_evidences, porém com nomes diferentes. Para isso, usaremos o método "rename".

# %%
#Trocar o nome das colunas.
#df_Assertion.rename(columns={'assertion_type': 'evidence_type'}, inplace = True)
#df_Assertion.rename(columns={'assertion_direction': 'evidence_direction'}, inplace = True)

# %% [markdown]
# Após trocarmos os nomes dessas colunas, precisamos apagar algumas outras do mesmo df, pois essas colunas não se encontram em nenhum outro df, e por conta disso, a mesclagem se torna um problema. Por isso, essas colunas estão sendo excluídas, mas nenhum dado importante será perdido.

# %%
#Apagando colunas
# df_Assertion = df_Assertion.drop(['acmg_codes', 'amp_category', 'nccn_guideline', 
#                                   'fda_companion_test', 'assertion_summary', 'assertion_description',
#                                   'assertion_id', 'fda_companion_test', 'regulatory_approval',
#                                   'assertion_civic_url', 'evidence_item_ids', 'nccn_guideline_version', 'evidence_items_civic_url' ],axis=1)

# %% [markdown]
# Com as colunas apagadas, podemos realizar o primeiro merge. Inicialmente, iremos juntar o df_Assertion tratado e o df_evidences, ambos com a maior quantidade de linhas e colunas. Para essa mesclagem, não é necessário passar uma chave específica, podemos simplesmente usar o método "how='outer'". Assim, criaremos um df nomeado Civic que possui a junção de todos os registros dos dois conjuntos de dados originais, mantendo os valores nulos onde não há correspondência entre as chaves de junção, por esse motivo as colunas foram excluídas e tiveram seus nomes trocados.
#
# Usaremos esse método, pois desejamos manter todas as informações de ambos os DataFrames. Caso esse não fosse o objetivo, poderíamos ter usado outros parâmetros, como "inner", "left" ou "right".

# %%
#Merge entre df_Assertion e df_Evidences
#Civic = pd.merge(df_Assertion, df_Evidences, how='outer')

# %% [markdown]
# Com a primeira junção finalizada, realizaremos a segunda juntando o novo DataFrame nomeado Civic com o df_Variant. Para que essa mesclagem funcione, usaremos como chave a coluna 'variant_id' e como parâmetro usaremos o left_on e o right_on, fazendo o uso desses parâmetros teremos especificado as colunas que serão utilizadas como chaves de junção para o conjunto de dados.
#
# Para que nossos dados não fiquem poluídos e que não precisemos ter um trabalho extra excluindo colunas repetidas que serão geradas com o merge, pois nosso conjunto de dados possuem colunas com o mesmo nome, iremos definir o parâmetro "suffixes" como uma tupla vazia e uma tupla com o sufixo "_y", o que garantirá que não haverá colunas duplicadas após a junção.
#
# Após a junção, usaremos o método "filter" para selecionar apenas as colunas que possuem o sufixo "_y" no nome e usaremos o método "drop" para removê-las.

# %%
df_Variant.rename(columns={'summary': 'variant_summary'}, inplace = True)
df_Variant = df_Variant.drop(['assertion_ids', 'is_flagged'],axis=1)

# %%
df_Evidences
# Out:
#         gene  entrez_id          variant                         disease  \
# 0       JAK2       3717            V617F               Lymphoid Leukemia
# 1     PDGFRA       5156            D842V  Gastrointestinal Stromal Tumor
# 2     DNMT3A       1788             R882          Acute Myeloid Leukemia
# 3     DNMT3A       1788             R882          Acute Myeloid Leukemia
# 4       JAK2       3717            V617F        Chronic Myeloid Leukemia
# ...      ...        ...              ...                             ...
# 3892   ERCC1       2067  Underexpression         Ovary Epithelial Cancer
# 3893   NTRK1       4914    Amplification                     Solid Tumor
# 3894    CTCF      10664            K365T                             NaN
# 3895     KIT       3815       EXPRESSION                    Glioblastoma
# 3896   SSTR5       6755       expression            Neuroendocrine Tumor
#
#         doid phenotypes              drugs drug_interaction_type  \
# 0     1037.0        NaN                NaN                   NaN
# 1     9253.0        NaN                NaN                   NaN
# 2     9119.0        NaN                NaN                   NaN
# 3     9119.0        NaN                NaN                   NaN
# 4     8552.0        NaN                NaN                   NaN
# ...      ...        ...                ...                   ...
# 3892  2152.0        NaN  Platinum Compound                   NaN
# 3893     NaN        NaN      Larotrectinib                   NaN
# 3894     NaN        NaN                NaN                   NaN
# 3895  3068.0        NaN          Sunitinib                   NaN
# 3896   169.0        NaN        Pasireotide                   NaN
#
#      evidence_type evidence_direction  ... representative_transcript2  \
# 0       Diagnostic           Supports  ...                        NaN
# 1       Diagnostic           Supports  ...                        NaN
# 2       Diagnostic           Supports  ...                        NaN
# 3       Diagnostic           Supports  ...                        NaN
# 4       Diagnostic           Supports  ...                        NaN
# ...            ...                ...  ...                        ...
# 3892    Predictive           Supports  ...                        NaN
# 3893    Predictive           Supports  ...                        NaN
# 3894    Functional           Supports  ...                        NaN
# 3895    Predictive           Supports  ...                        NaN
# 3896    Predictive           Supports  ...                        NaN
#
#      ensembl_version reference_build  \
# 0               75.0          GRCh37
# 1               75.0          GRCh37
# 2               75.0          GRCh37
# 3               75.0          GRCh37
# 4               75.0          GRCh37
# ...              ...             ...
# 3892            75.0          GRCh37
# 3893            75.0          GRCh37
# 3894             NaN             NaN
# 3895            75.0          GRCh37
# 3896             NaN             NaN
#
#                                         variant_summary variant_origin  \
# 0     JAK2 V617F is a highly recurrent mutation in m...        Somatic
# 1     PDGFRA D842 mutations are characterized broadl...        Somatic
# 2     DNMT3A R882 mutations are associated with cyto...        Somatic
# 3     DNMT3A R882 mutations are associated with cyto...        Somatic
# 4     JAK2 V617F is a highly recurrent mutation in m...        Somatic
# ...                                                 ...            ...
# 3892                                                NaN            NaN
# 3893                                                NaN        Somatic
# 3894                                                NaN            NaN
# 3895                                                NaN        Somatic
# 3896                                                NaN        Somatic
#
#              last_review_date  \
# 0     2020-11-20 16:18:21 UTC
# 1     2015-06-21 16:49:38 UTC
# 2     2016-03-26 22:10:59 UTC
# 3     2016-03-16 22:09:27 UTC
# 4     2015-06-21 16:49:39 UTC
# ...                       ...
# 3892  2022-03-01 18:44:57 UTC
# 3893  2022-02-24 18:44:37 UTC
# 3894  2022-03-08 18:33:47 UTC
# 3895  2022-03-15 18:35:48 UTC
# 3896  2022-03-15 18:09:18 UTC
#
#                                      evidence_civic_url  \
# 0     https://civic.genome.wustl.edu/links/evidence_...
# 1     https://civic.genome.wustl.edu/links/evidence_...
# 2     https://civic.genome.wustl.edu/links/evidence_...
# 3     https://civic.genome.wustl.edu/links/evidence_...
# 4     https://civic.genome.wustl.edu/links/evidence_...
# ...                                                 ...
# 3892  https://civic.genome.wustl.edu/links/evidence_...
# 3893  https://civic.genome.wustl.edu/links/evidence_...
# 3894  https://civic.genome.wustl.edu/links/evidence_...
# 3895  https://civic.genome.wustl.edu/links/evidence_...
# 3896  https://civic.genome.wustl.edu/links/evidence_...
#
#                                       variant_civic_url  \
# 0      https://civic.genome.wustl.edu/links/variants/64
# 1      https://civic.genome.wustl.edu/links/variants/99
# 2      https://civic.genome.wustl.edu/links/variants/32
# 3      https://civic.genome.wustl.edu/links/variants/32
# 4      https://civic.genome.wustl.edu/links/variants/64
# ...                                                 ...
# 3892  https://civic.genome.wustl.edu/links/variants/...
# 3893  https://civic.genome.wustl.edu/links/variants/...
# 3894  https://civic.genome.wustl.edu/links/variants/...
# 3895  https://civic.genome.wustl.edu/links/variants/429
# 3896  https://civic.genome.wustl.edu/links/variants/...
#
#                                        gene_civic_url is_flagged
# 0       https://civic.genome.wustl.edu/links/genes/28      False
# 1       https://civic.genome.wustl.edu/links/genes/38      False
# 2       https://civic.genome.wustl.edu/links/genes/18      False
# 3       https://civic.genome.wustl.edu/links/genes/18      False
# 4       https://civic.genome.wustl.edu/links/genes/28      False
# ...                                               ...        ...
# 3892  https://civic.genome.wustl.edu/links/genes/1735      False
# 3893  https://civic.genome.wustl.edu/links/genes/3983      False
# 3894  https://civic.genome.wustl.edu/links/genes/8508      False
# 3895    https://civic.genome.wustl.edu/links/genes/29      False
# 3896  https://civic.genome.wustl.edu/links/genes/5499      False
#
# [3897 rows x 42 columns]

# %%
df_Evidences.columns
# Out:
# Index(['gene', 'entrez_id', 'variant', 'disease', 'doid', 'phenotypes',
#        'drugs', 'drug_interaction_type', 'evidence_type', 'evidence_direction',
#        'evidence_level', 'clinical_significance', 'evidence_statement',
#        'citation_id', 'source_type', 'asco_abstract_id', 'citation', 'nct_ids',
#        'rating', 'evidence_status', 'evidence_id', 'variant_id', 'gene_id',
#        'chromosome', 'start', 'stop', 'reference_bases', 'variant_bases',
#        'representative_transcript', 'chromosome2', 'start2', 'stop2',
#        'representative_transcript2', 'ensembl_version', 'reference_build',
#        'variant_summary', 'variant_origin', 'last_review_date',
#        'evidence_civic_url', 'variant_civic_url', 'gene_civic_url',
#        'is_flagged'],
#       dtype='object')

# %%
df_Variant.columns
# Out:
# Index(['variant_id', 'variant_civic_url', 'gene', 'entrez_id', 'variant',
#        'variant_summary', 'variant_groups', 'chromosome', 'start', 'stop',
#        'reference_bases', 'variant_bases', 'representative_transcript',
#        'ensembl_version', 'reference_build', 'chromosome2', 'start2', 'stop2',
#        'representative_transcript2', 'variant_types', 'hgvs_expressions',
#        'last_review_date', 'civic_variant_evidence_score',
#        'allele_registry_id', 'clinvar_ids', 'variant_aliases',
#        'assertion_civic_urls', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31',
#        'Unnamed: 32'],
#       dtype='object')

# %%
df_Gene.columns
# Out:
# Index(['gene_id', 'gene', 'entrez_id', 'description'], dtype='object')

# %%
#Merge entre Civic e df_Variant
Civic = pd.merge(df_Evidences, df_Variant,  left_on='variant_id', right_on='variant_id', how='left', suffixes=('','_y'))
Civic.drop(Civic.filter(regex='_y$').columns, axis=1, inplace=True)

# %% [markdown]
# Com três DataFrames iniciais juntos, seguiremos para o df_genes. Assim como o df_Assertion, ele precisa ser tratado antes da junção, porém por motivos diferentes. O df_genes possui valores duplicados que se encontram em outros DataFrames. Esses valores serão excluídos, e manteremos apenas as colunas "description", que não possuímos em outros DataFrames, e "name", que usaremos como chave de junção.

# %%
#Apagando colunas
df_Gene = df_Gene.drop(['gene_civic_url', 'last_review_date', 'is_flagged'],axis=1)

# %% [markdown]
# Também não possuímos a coluna "name" em nenhum outro dataframe, mas seus valores correspondem às colunas denominadas como "gene" em outros dataframes, por isso faremos um rename nesse dataframe.

# %%
#Trocando o nome da coluna name para gene.
df_Gene.rename(columns={'name': 'gene'}, inplace = True)

# %% [markdown]
# Com o "df_gene" tratado, realizaremos o último merge juntando o conjunto total ao último dataframe. Usaremos as colunas "gene" como chave de junção e passaremos o mesmo parâmetro "suffixes" para apagar colunas duplicadas.

# %%
#Merge entre Civic e df_gene
Civic = pd.merge(Civic, df_Gene,  left_on='gene', right_on='gene', how='left', suffixes=('','_y'))
Civic.drop(Civic.filter(regex='_y$').columns, axis=1, inplace=True)

# %% [markdown]
# Agora, com o dataframe pronto, realizaremos o último tratamento dessa etapa. Aqui, apagaremos colunas sem valor para nossa análise, como URLs e a última edição ("last_review_date"), colunas com valores nulos em todos os dataframes e colunas que não serão usadas.

# %%
#Removendo colunas
Civic = Civic.drop(['gene_civic_url', 'Unnamed: 32', 'Unnamed: 31', 'Unnamed: 29',
                    'Unnamed: 30', 'assertion_civic_urls', 'variant_civic_url', 
                    'evidence_civic_url', 'last_review_date', 'asco_abstract_id',
                    'nct_ids', 'chromosome2', 'start2', 'stop2', 'representative_transcript2',
                    'variant_groups'
],axis=1)
Civic
# Out:
#         gene  entrez_id          variant                         disease  \
# 0       JAK2       3717            V617F               Lymphoid Leukemia
# 1     PDGFRA       5156            D842V  Gastrointestinal Stromal Tumor
# 2     DNMT3A       1788             R882          Acute Myeloid Leukemia
# 3     DNMT3A       1788             R882          Acute Myeloid Leukemia
# 4       JAK2       3717            V617F        Chronic Myeloid Leukemia
# ...      ...        ...              ...                             ...
# 3892   ERCC1       2067  Underexpression         Ovary Epithelial Cancer
# 3893   NTRK1       4914    Amplification                     Solid Tumor
# 3894    CTCF      10664            K365T                             NaN
# 3895     KIT       3815       EXPRESSION                    Glioblastoma
# 3896   SSTR5       6755       expression            Neuroendocrine Tumor
#
#         doid phenotypes              drugs drug_interaction_type  \
# 0     1037.0        NaN                NaN                   NaN
# 1     9253.0        NaN                NaN                   NaN
# 2     9119.0        NaN                NaN                   NaN
# 3     9119.0        NaN                NaN                   NaN
# 4     8552.0        NaN                NaN                   NaN
# ...      ...        ...                ...                   ...
# 3892  2152.0        NaN  Platinum Compound                   NaN
# 3893     NaN        NaN      Larotrectinib                   NaN
# 3894     NaN        NaN                NaN                   NaN
# 3895  3068.0        NaN          Sunitinib                   NaN
# 3896   169.0        NaN        Pasireotide                   NaN
#
#      evidence_type evidence_direction  ...  \
# 0       Diagnostic           Supports  ...
# 1       Diagnostic           Supports  ...
# 2       Diagnostic           Supports  ...
# 3       Diagnostic           Supports  ...
# 4       Diagnostic           Supports  ...
# ...            ...                ...  ...
# 3892    Predictive           Supports  ...
# 3893    Predictive           Supports  ...
# 3894    Functional           Supports  ...
# 3895    Predictive           Supports  ...
# 3896    Predictive           Supports  ...
#
#                                         variant_summary variant_origin  \
# 0     JAK2 V617F is a highly recurrent mutation in m...        Somatic
# 1     PDGFRA D842 mutations are characterized broadl...        Somatic
# 2     DNMT3A R882 mutations are associated with cyto...        Somatic
# 3     DNMT3A R882 mutations are associated with cyto...        Somatic
# 4     JAK2 V617F is a highly recurrent mutation in m...        Somatic
# ...                                                 ...            ...
# 3892                                                NaN            NaN
# 3893                                                NaN        Somatic
# 3894                                                NaN            NaN
# 3895                                                NaN        Somatic
# 3896                                                NaN        Somatic
#
#      is_flagged                              variant_types  \
# 0         False  missense_variant,gain_of_function_variant
# 1         False                           missense_variant
# 2         False                           missense_variant
# 3         False                           missense_variant
# 4         False  missense_variant,gain_of_function_variant
# ...         ...                                        ...
# 3892      False                                        NaN
# 3893      False                   transcript_amplification
# 3894      False                                        NaN
# 3895      False                                        NaN
# 3896      False                                        NaN
#
#                                        hgvs_expressions  \
# 0     NC_000009.11:g.5073770G>T,NM_004972.3:c.1849G>...
# 1     NM_006206.4:c.2525A>T,NP_006197.1:p.Asp842Val,...
# 2                                                   NaN
# 3                                                   NaN
# 4     NC_000009.11:g.5073770G>T,NM_004972.3:c.1849G>...
# ...                                                 ...
# 3892                                                NaN
# 3893                                                NaN
# 3894                                                NaN
# 3895                                                NaN
# 3896                                                NaN
#
#      civic_variant_evidence_score  allele_registry_id  \
# 0                            83.0            CA124183
# 1                           100.5            CA123194
# 2                           510.0                 NaN
# 3                           510.0                 NaN
# 4                            83.0            CA124183
# ...                           ...                 ...
# 3892                         15.0                 NaN
# 3893                          5.0                 NaN
# 3894                          0.0                 NaN
# 3895                         20.0                 NaN
# 3896                          0.0                 NaN
#
#                                     clinvar_ids        variant_aliases  \
# 0                                         14662   VAL617PHE,RS77375493
# 1                                         13543  ASP842VAL,RS121908585
# 2     375882,375883,375884,375879,375880,375881     R693,ARG882,ARG693
# 3     375882,375883,375884,375879,375880,375881     R693,ARG882,ARG693
# 4                                         14662   VAL617PHE,RS77375493
# ...                                         ...                    ...
# 3892                                        NaN                    NaN
# 3893                                        NaN                    NaN
# 3894                                        NaN                    NaN
# 3895                                        NaN                    NaN
# 3896                                        NaN                    NaN
#
#                                             description
# 0     JAK2 is a kinase that is misregulated or mutat...
# 1     Commonly mutated in GI tract tumors, PDGFR fam...
# 2     DNMT3A is one of several epigenetic modifiers ...
# 3     DNMT3A is one of several epigenetic modifiers ...
# 4     JAK2 is a kinase that is misregulated or mutat...
# ...                                                 ...
# 3892                                                NaN
# 3893                                                NaN
# 3894                                                NaN
# 3895  c-KIT activation has been shown to have oncoge...
# 3896                                                NaN
#
# [3897 rows x 39 columns]

# %% [markdown]
# Para que o dataframe "Civic" final possa ser utilizado pelo restante do grupo, iremos salvá-lo como CSV.

# %%
#Salvando o df Civic como um csv
#Civic.to_csv('Civic.csv', index=False)

# %% [markdown]
# Diante disso, podemos ver que nosso código consiste na leitura de quatro arquivos csv (df_Variant, df_Evidence, df_Gene, Df_Assertion) fornecidos pelo proprio Civic, e na sua mesclagem em um dataframe final chamado Civic, tambem possuimos alguns tratamentos sendo realizados nos dados, como a exclusão de colunas não relevantes, a renomeação de colunas e a remoçao de valores duplicados.
# Ao final o Dataframe Civic é salvo em um arquivo csv para ser utilizado posteriormente.
