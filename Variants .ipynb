# %%
import pandas as pd

# %%
df1 = pd.read_csv('01-Apr-2016-VariantSummaries.csv')
df1
# Out:
#      variant_id                                  variant_civic_url     gene  \
# 0             1  https://civic.genome.wustl.edu/#/events/genes/...     ABL1
# 1             2  https://civic.genome.wustl.edu/#/events/genes/...     ABL1
# 2             3  https://civic.genome.wustl.edu/#/events/genes/...     ABL1
# 3             4  https://civic.genome.wustl.edu/#/events/genes/...     AKT1
# 4             5  https://civic.genome.wustl.edu/#/events/genes/...      ALK
# ..          ...                                                ...      ...
# 478         526  https://civic.genome.wustl.edu/#/events/genes/...  BCL2L11
# 479         527  https://civic.genome.wustl.edu/#/events/genes/...      ALK
# 480         528  https://civic.genome.wustl.edu/#/events/genes/...      ALK
# 481         529  https://civic.genome.wustl.edu/#/events/genes/...    SIRT1
# 482         530  https://civic.genome.wustl.edu/#/events/genes/...     KRAS
#
#      entrez_id                variant  \
# ...

# %%
df2 = pd.read_csv('01-Apr-2017-VariantSummaries.csv')
df2
# Out:
#       variant_id                                  variant_civic_url    gene  \
# 0              1  https://civic.genome.wustl.edu/#/events/genes/...    ABL1
# 1              2  https://civic.genome.wustl.edu/#/events/genes/...    ABL1
# 2              3  https://civic.genome.wustl.edu/#/events/genes/...    ABL1
# 3              4  https://civic.genome.wustl.edu/#/events/genes/...    AKT1
# 4              5  https://civic.genome.wustl.edu/#/events/genes/...     ALK
# ...          ...                                                ...     ...
# 1074        1293  https://civic.genome.wustl.edu/#/events/genes/...  ARID1A
# 1075        1294  https://civic.genome.wustl.edu/#/events/genes/...     VHL
# 1076        1295  https://civic.genome.wustl.edu/#/events/genes/...     ALK
# 1077        1296  https://civic.genome.wustl.edu/#/events/genes/...  CTNNB1
# 1078        1298  https://civic.genome.wustl.edu/#/events/genes/...    BRAF
#
#       entrez_id              variant  \
# ...

# %%
df = pd.merge(df1, df2, right_index=True, left_index=True, how = 'outer')
df
df.to_csv('df.csv', index=False)

# %%
df3 = pd.read_csv('01-Apr-2018-VariantSummaries.csv')
df3
# Out:
#       variant_id                                  variant_civic_url  gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1  ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2  ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3  ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4  AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5   ALK
# ...          ...                                                ...   ...
# 1798        2270  https://civic.genome.wustl.edu/links/variants/...   VHL
# 1799        2271  https://civic.genome.wustl.edu/links/variants/...   VHL
# 1800        2272  https://civic.genome.wustl.edu/links/variants/...   VHL
# 1801        2273  https://civic.genome.wustl.edu/links/variants/...   VHL
# 1802        2274  https://civic.genome.wustl.edu/links/variants/...   VHL
#
#       entrez_id                    variant  \
# ...

# %%
df = pd.merge(df, df3, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# 4              5.0  https://civic.genome.wustl.edu/#/events/genes/...    ALK
# ...            ...                                                ...    ...
# 1798           NaN                                                NaN    NaN
# 1799           NaN                                                NaN    NaN
# 1800           NaN                                                NaN    NaN
# 1801           NaN                                                NaN    NaN
# 1802           NaN                                                NaN    NaN
#
#       entrez_id_x      variant_x  \
# ...

# %%
df4 = pd.read_csv('01-Apr-2019-VariantSummaries.csv')
df4
# Out:
#       variant_id                                  variant_civic_url   gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1   ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2   ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3   ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4   AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5    ALK
# ...          ...                                                ...    ...
# 2175        2675  https://civic.genome.wustl.edu/links/variants/...   MSH2
# 2176        2676  https://civic.genome.wustl.edu/links/variants/...  EP300
# 2177        2677  https://civic.genome.wustl.edu/links/variants/...  ERBB2
# 2178        2678  https://civic.genome.wustl.edu/links/variants/...   ABL1
# 2179        2679  https://civic.genome.wustl.edu/links/variants/...   WEE1
#
#       entrez_id           variant  \
# ...

# %%
df = pd.merge(df, df4, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/3337349739.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'variant_id_x', 'chromosome2_x', 'variant_groups_x', 'stop2_x', 'chromosome_x', 'variant_civic_url_x', 'entrez_id_x', 'variant_bases_x', 'ensembl_version_x', 'gene_x', 'start_x', 'reference_build_x', 'summary_x', 'variant_x', 'reference_bases_x', 'representative_transcript_x', 'start2_x', 'representative_transcript2_x', 'stop_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df4, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# ...

# %%
df5 = pd.read_csv('01-Apr-2020-VariantSummaries.csv')
df5
# Out:
#       variant_id                                  variant_civic_url    gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1    ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2    ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3    ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4    AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5     ALK
# ...          ...                                                ...     ...
# 2496        2998  https://civic.genome.wustl.edu/links/variants/...    EGFR
# 2497        2999  https://civic.genome.wustl.edu/links/variants/...    EGFR
# 2498        3000  https://civic.genome.wustl.edu/links/variants/...    EGFR
# 2499        3001  https://civic.genome.wustl.edu/links/variants/...  PIK3CA
# 2500        3002  https://civic.genome.wustl.edu/links/variants/...     NF2
#
#       entrez_id        variant  \
# ...

# %%
df = pd.merge(df, df5, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/3575292880.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'variant_types_x', 'hgvs_expressions_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df5, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# 4              5.0  https://civic.genome.wustl.edu/#/events/genes/...    ALK
# ...            ...                                                ...    ...
# 2496           NaN                                                NaN    NaN
# ...

# %%
df6 = pd.read_csv('01-Apr-2021-VariantSummaries.csv')
df6
# Out:
#       variant_id                                  variant_civic_url     gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1     ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2     ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3     ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4     AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5      ALK
# ...          ...                                                ...      ...
# 1472        3247  https://civic.genome.wustl.edu/links/variants/...      VHL
# 1473        3257  https://civic.genome.wustl.edu/links/variants/...     AKT1
# 1474        3272  https://civic.genome.wustl.edu/links/variants/...     ABL1
# 1475        3274  https://civic.genome.wustl.edu/links/variants/...   PDGFRA
# 1476        3299  https://civic.genome.wustl.edu/links/variants/...  PPP2R1A
#
#       entrez_id                variant  \
# ...

# %%
df = pd.merge(df, df6, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/788311426.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'variant_id_x', 'chromosome2_x', 'variant_groups_x', 'stop2_x', 'chromosome_x', 'last_review_date_x', 'variant_civic_url_x', 'entrez_id_x', 'variant_bases_x', 'ensembl_version_x', 'gene_x', 'start_x', 'reference_build_x', 'summary_x', 'variant_x', 'reference_bases_x', 'representative_transcript_x', 'start2_x', 'representative_transcript2_x', 'stop_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df6, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# ...

# %%
df7 = pd.read_csv('01-Aug-2015-VariantSummaries.csv')
df7
# Out:
#      gene  entrez_id               variant  \
# 0    ABL1         25               BCR-ABL
# 1    ABL1         25         BCR-ABL T315I
# 2    ABL1         25         BCR-ABL E255K
# 3    AKT1        207                  E17K
# 4     ALK        238              EML4-ALK
# ..    ...        ...                   ...
# 217  TERT       7015     PROMOTER MUTATION
# 218  TP53       7157  DELETERIOUS MUTATION
# 219  TP53       7157              MUTATION
# 220  TP53       7157   TRUNCATING MUTATION
# 221  TTF1       7270         AMPLIFICATION
#
#                                                summary  \
# 0    The BCR-ABL fusion protein, commonly referred ...
# 1    While the efficacy of imatinib has revolutioni...
# 2    While the efficacy of imatinib has revolutioni...
# 3    AKT1 E17K is a recurrent mutation that has bee...
# 4    The EML4-ALK fusion has been seen in non-small...
# ..                                                 ...
# ...

# %%
df = pd.merge(df, df7, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# 4              5.0  https://civic.genome.wustl.edu/#/events/genes/...    ALK
# ...            ...                                                ...    ...
# 2496           NaN                                                NaN    NaN
# 2497           NaN                                                NaN    NaN
# 2498           NaN                                                NaN    NaN
# 2499           NaN                                                NaN    NaN
# 2500           NaN                                                NaN    NaN
#
#       entrez_id_x      variant_x  \
# ...

# %%
df8 = pd.read_csv('01-Aug-2017-VariantSummaries.csv')
df8
# Out:
#       variant_id                                  variant_civic_url    gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1    ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2    ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3    ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4    AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5     ALK
# ...          ...                                                ...     ...
# 1706        2161  https://civic.genome.wustl.edu/links/variants/...     VHL
# 1707        2162  https://civic.genome.wustl.edu/links/variants/...     VHL
# 1708        2163  https://civic.genome.wustl.edu/links/variants/...   CTLA4
# 1709        2164  https://civic.genome.wustl.edu/links/variants/...  CX3CL1
# 1710        2165  https://civic.genome.wustl.edu/links/variants/...   FANCA
#
#       entrez_id           variant  \
# ...

# %%
df = pd.merge(df, df8, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/223680818.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'summary_x', 'variant_x', 'variant_groups_x', 'hgvs_expressions_x', 'variant_types_x', 'entrez_id_x', 'gene_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df8, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# 4              5.0  https://civic.genome.wustl.edu/#/events/genes/...    ALK
# ...            ...                                                ...    ...
# ...

# %%
df9 = pd.read_csv('01-Aug-2018-VariantSummaries.csv')
df9
# Out:
#       variant_id                                  variant_civic_url   gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1   ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2   ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3   ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4   AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5    ALK
# ...          ...                                                ...    ...
# 1912        2406  https://civic.genome.wustl.edu/links/variants/...  FGFR3
# 1913        2407  https://civic.genome.wustl.edu/links/variants/...  FGFR3
# 1914        2408  https://civic.genome.wustl.edu/links/variants/...   BRAF
# 1915        2409  https://civic.genome.wustl.edu/links/variants/...  ERCC1
# 1916        2410  https://civic.genome.wustl.edu/links/variants/...  ERCC1
#
#       entrez_id          variant  \
# ...

# %%
df = pd.merge(df, df9, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/1959774139.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'reference_build_x', 'chromosome_x', 'last_review_date_x', 'variant_id_x', 'reference_bases_x', 'representative_transcript_x', 'chromosome2_x', 'variant_civic_url_x', 'start2_x', 'stop_x', 'stop2_x', 'representative_transcript2_x', 'variant_bases_x', 'ensembl_version_x', 'start_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df9, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# ...

# %%
df10 = pd.read_csv('01-Aug-2019-VariantSummaries.csv')
df10
# Out:
#       variant_id                                  variant_civic_url    gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1    ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2    ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3    ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4    AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5     ALK
# ...          ...                                                ...     ...
# 2245        2747  https://civic.genome.wustl.edu/links/variants/...   CCND3
# 2246        2748  https://civic.genome.wustl.edu/links/variants/...    ETV6
# 2247        2749  https://civic.genome.wustl.edu/links/variants/...  NFE2L2
# 2248        2750  https://civic.genome.wustl.edu/links/variants/...     ALK
# 2249        2751  https://civic.genome.wustl.edu/links/variants/...    TP53
#
# ...

# %%
df = pd.merge(df, df10, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/1798698559.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'summary_x', 'variant_x', 'variant_groups_x', 'hgvs_expressions_x', 'variant_types_x', 'entrez_id_x', 'gene_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df10, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# 4              5.0  https://civic.genome.wustl.edu/#/events/genes/...    ALK
# ...            ...                                                ...    ...
# ...

# %%
df11 = pd.read_csv('01-Aug-2020-VariantSummaries.csv')
df11
# Out:
#       variant_id                                  variant_civic_url  gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1  ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2  ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3  ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4  AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5   ALK
# ...          ...                                                ...   ...
# 1430        3042  https://civic.genome.wustl.edu/links/variants/...  CDK6
# 1431        3049  https://civic.genome.wustl.edu/links/variants/...   ATM
# 1432        3050  https://civic.genome.wustl.edu/links/variants/...   ATM
# 1433        3051  https://civic.genome.wustl.edu/links/variants/...   ATM
# 1434        3075  https://civic.genome.wustl.edu/links/variants/...  FLT3
#
#       entrez_id        variant  \
# 0            25        BCR-ABL
# ...

# %%
df = pd.merge(df, df11, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/2556175001.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'variant_aliases_x', 'variant_id_x', 'chromosome2_x', 'Unnamed: 31_x', 'Unnamed: 29_x', 'stop2_x', 'assertion_ids_x', 'chromosome_x', 'last_review_date_x', 'civic_variant_evidence_score_x', 'clinvar_ids_x', 'variant_civic_url_x', 'variant_bases_x', 'ensembl_version_x', 'Unnamed: 30_x', 'start_x', 'reference_build_x', 'reference_bases_x', 'representative_transcript_x', 'start2_x', 'representative_transcript2_x', 'allele_registry_id_x', 'stop_x', 'assertion_civic_urls_x', 'Unnamed: 28_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df11, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# ...

# %%
df12 = pd.read_csv('01-Aug-2021-VariantSummaries.csv')
df12
# Out:
#       variant_id                                  variant_civic_url  gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1  ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2  ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3  ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4  AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5   ALK
# ...          ...                                                ...   ...
# 1500        3382  https://civic.genome.wustl.edu/links/variants/...  PTEN
# 1501        3426  https://civic.genome.wustl.edu/links/variants/...  EZH2
# 1502        3427  https://civic.genome.wustl.edu/links/variants/...  EZH2
# 1503        3428  https://civic.genome.wustl.edu/links/variants/...  EZH2
# 1504        3432  https://civic.genome.wustl.edu/links/variants/...  BRAF
#
#       entrez_id        variant  \
# 0            25        BCR-ABL
# ...

# %%
df = pd.merge(df, df12, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/1640034033.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'summary_x', 'variant_x', 'variant_groups_x', 'hgvs_expressions_x', 'variant_types_x', 'entrez_id_x', 'gene_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df12, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# 4              5.0  https://civic.genome.wustl.edu/#/events/genes/...    ALK
# ...            ...                                                ...    ...
# ...

# %%
df13 = pd.read_csv('01-Dec-2015-VariantSummaries.csv')
df13
# Out:
#       gene  entrez_id                                  variant  \
# 0     ABL1         25                                  BCR-ABL
# 1     ABL1         25                            BCR-ABL T315I
# 2     ABL1         25                            BCR-ABL E255K
# 3     AKT1        207                                     E17K
# 4      ALK        238                                 EML4-ALK
# ..     ...        ...                                      ...
# 223  ABCB1       5243                                 G2677T/A
# 224  ABCB1       5243  SAME-SENSE MUTATION AT CODON 3435 (C>T)
# 225  ERCC2       2068                                    K751Q
# 226   TYMS       7298     5' TANDEM REPEAT VARIANT (2TPR>3TPR)
# 227  LRP1B      53353                                 DELETION
#
#                                                summary  \
# 0    The BCR-ABL fusion protein, commonly referred ...
# 1    While the efficacy of imatinib has revolutioni...
# ...

# %%
df = pd.merge(df, df13, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# 4              5.0  https://civic.genome.wustl.edu/#/events/genes/...    ALK
# ...            ...                                                ...    ...
# 2496           NaN                                                NaN    NaN
# 2497           NaN                                                NaN    NaN
# 2498           NaN                                                NaN    NaN
# 2499           NaN                                                NaN    NaN
# 2500           NaN                                                NaN    NaN
#
#       entrez_id_x      variant_x  \
# ...

# %%
df15 = pd.read_csv('01-Dec-2017-VariantSummaries.csv')
df15
# Out:
#       variant_id                                  variant_civic_url    gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1    ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2    ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3    ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4    AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5     ALK
# ...          ...                                                ...     ...
# 1738        2197  https://civic.genome.wustl.edu/links/variants/...  DICER1
# 1739        2198  https://civic.genome.wustl.edu/links/variants/...  DICER1
# 1740        2199  https://civic.genome.wustl.edu/links/variants/...  DICER1
# 1741        2200  https://civic.genome.wustl.edu/links/variants/...  DICER1
# 1742        2201  https://civic.genome.wustl.edu/links/variants/...  DICER1
#
#       entrez_id        variant  \
# ...

# %%
df = pd.merge(df, df15, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/2984092553.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'variant_id_x', 'chromosome2_x', 'variant_groups_x', 'stop2_x', 'chromosome_x', 'last_review_date_x', 'variant_civic_url_x', 'entrez_id_x', 'variant_bases_x', 'ensembl_version_x', 'gene_x', 'start_x', 'reference_build_x', 'summary_x', 'reference_bases_x', 'representative_transcript_x', 'start2_x', 'representative_transcript2_x', 'variant_x', 'stop_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df15, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# ...

# %%
df16 = pd.read_csv('01-Dec-2018-VariantSummaries.csv')
df16
# Out:
#       variant_id                                  variant_civic_url    gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1    ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2    ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3    ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4    AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5     ALK
# ...          ...                                                ...     ...
# 2078        2574  https://civic.genome.wustl.edu/links/variants/...  SETBP1
# 2079        2575  https://civic.genome.wustl.edu/links/variants/...    ABL1
# 2080        2576  https://civic.genome.wustl.edu/links/variants/...  CTNNB1
# 2081        2577  https://civic.genome.wustl.edu/links/variants/...  PDGFRB
# 2082        2578  https://civic.genome.wustl.edu/links/variants/...  NOTCH3
#
#       entrez_id                           variant  \
# ...

# %%
df = pd.merge(df, df16, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/2221169544.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'variant_types_x', 'hgvs_expressions_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df16, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# 4              5.0  https://civic.genome.wustl.edu/#/events/genes/...    ALK
# ...            ...                                                ...    ...
# 2496           NaN                                                NaN    NaN
# ...

# %%
df17 = pd.read_csv('01-Dec-2019-VariantSummaries.csv')
df17
# Out:
#       variant_id                                  variant_civic_url  gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1  ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2  ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3  ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4  AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5   ALK
# ...          ...                                                ...   ...
# 2382        2878  https://civic.genome.wustl.edu/links/variants/...   VHL
# 2383        2879  https://civic.genome.wustl.edu/links/variants/...   VHL
# 2384        2880  https://civic.genome.wustl.edu/links/variants/...   VHL
# 2385        2881  https://civic.genome.wustl.edu/links/variants/...   VHL
# 2386        2882  https://civic.genome.wustl.edu/links/variants/...   VHL
#
#       entrez_id                   variant  \
# ...

# %%
df = pd.merge(df, df17, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/1178724849.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'variant_aliases_x', 'variant_id_x', 'chromosome2_x', 'Unnamed: 31_x', 'Unnamed: 29_x', 'variant_groups_x', 'stop2_x', 'assertion_ids_x', 'chromosome_x', 'civic_variant_evidence_score_x', 'last_review_date_x', 'clinvar_ids_x', 'variant_civic_url_x', 'entrez_id_x', 'variant_bases_x', 'ensembl_version_x', 'gene_x', 'Unnamed: 30_x', 'start_x', 'reference_build_x', 'summary_x', 'variant_x', 'allele_registry_id_x', 'reference_bases_x', 'representative_transcript_x', 'start2_x', 'stop_x', 'assertion_civic_urls_x', 'representative_transcript2_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df17, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# ...

# %%
df18 = pd.read_csv('01-Dec-2020-VariantSummaries.csv')
df18
# Out:
#       variant_id                                  variant_civic_url    gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1    ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2    ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3    ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4    AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5     ALK
# ...          ...                                                ...     ...
# 1461        3203  https://civic.genome.wustl.edu/links/variants/...    ATRX
# 1462        3214  https://civic.genome.wustl.edu/links/variants/...    JAK2
# 1463        3222  https://civic.genome.wustl.edu/links/variants/...  PIK3CA
# 1464        3224  https://civic.genome.wustl.edu/links/variants/...   NTRK1
# 1465        3225  https://civic.genome.wustl.edu/links/variants/...   NTRK1
#
#       entrez_id             variant  \
# ...

# %%
df = pd.merge(df, df18, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/119578406.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Unnamed: 28_x', 'variant_types_x', 'hgvs_expressions_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df18, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# 4              5.0  https://civic.genome.wustl.edu/#/events/genes/...    ALK
# ...            ...                                                ...    ...
# 2496           NaN                                                NaN    NaN
# ...

# %%
df19 = pd.read_csv('01-Dec-2021-VariantSummaries.csv')
df19
# Out:
#       variant_id                                  variant_civic_url  gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1  ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2  ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3  ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4  AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5   ALK
# ...          ...                                                ...   ...
# 1507        3579  https://civic.genome.wustl.edu/links/variants/...  TP53
# 1508        3580  https://civic.genome.wustl.edu/links/variants/...  TP53
# 1509        3581  https://civic.genome.wustl.edu/links/variants/...  TP53
# 1510        3582  https://civic.genome.wustl.edu/links/variants/...  TP53
# 1511        3583  https://civic.genome.wustl.edu/links/variants/...  TP53
#
#       entrez_id        variant  \
# 0            25        BCR-ABL
# ...

# %%
df = pd.merge(df, df19, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/1888988120.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'variant_aliases_x', 'variant_id_x', 'chromosome2_x', 'Unnamed: 31_x', 'variant_groups_x', 'Unnamed: 29_x', 'stop2_x', 'assertion_ids_x', 'chromosome_x', 'last_review_date_x', 'civic_variant_evidence_score_x', 'clinvar_ids_x', 'variant_civic_url_x', 'entrez_id_x', 'variant_bases_x', 'ensembl_version_x', 'gene_x', 'Unnamed: 30_x', 'start_x', 'reference_build_x', 'summary_x', 'variant_x', 'reference_bases_x', 'representative_transcript_x', 'start2_x', 'representative_transcript2_x', 'stop_x', 'allele_registry_id_x', 'assertion_civic_urls_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df19, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# ...

# %%
df20 = pd.read_csv('01-Feb-2016-VariantSummaries.csv')
df20
# Out:
#        gene  entrez_id         variant  \
# 0      ABL1       25.0         BCR-ABL
# 1      ABL1       25.0   BCR-ABL T315I
# 2      ABL1       25.0   BCR-ABL E255K
# 3      AKT1      207.0            E17K
# 4       ALK      238.0        EML4-ALK
# ..      ...        ...             ...
# 451     KIT     3815.0       RS3733542
# 452    TBK1    29110.0  OVEREXPRESSION
# 453    KRAS     3845.0       WILD TYPE
# 454   STK11     6794.0            LOSS
# 455  HAVCR2    84868.0  OVEREXPRESSION
#
#                                                summary  \
# 0    The BCR-ABL fusion protein, commonly referred ...
# 1    While the efficacy of imatinib has revolutioni...
# 2    While the efficacy of imatinib has revolutioni...
# 3    AKT1 E17K is a recurrent mutation that has bee...
# 4    The EML4-ALK fusion has been seen in non-small...
# ..                                                 ...
# 451                                                NaN
# ...

# %%
df = pd.merge(df, df20, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# 4              5.0  https://civic.genome.wustl.edu/#/events/genes/...    ALK
# ...            ...                                                ...    ...
# 2496           NaN                                                NaN    NaN
# 2497           NaN                                                NaN    NaN
# 2498           NaN                                                NaN    NaN
# 2499           NaN                                                NaN    NaN
# 2500           NaN                                                NaN    NaN
#
#       entrez_id_x      variant_x  \
# ...

# %%
df21 = pd.read_csv('01-Feb-2017-VariantSummaries.csv')
df21
# Out:
#      variant_id                                  variant_civic_url   gene  \
# 0             1  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1             2  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2             3  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3             4  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# 4             5  https://civic.genome.wustl.edu/#/events/genes/...    ALK
# ..          ...                                                ...    ...
# 748         830  https://civic.genome.wustl.edu/#/events/genes/...  FGFR3
# 749         835  https://civic.genome.wustl.edu/#/events/genes/...   AKT3
# 750         836  https://civic.genome.wustl.edu/#/events/genes/...   AKT3
# 751         837  https://civic.genome.wustl.edu/#/events/genes/...    SMO
# 752         838  https://civic.genome.wustl.edu/#/events/genes/...   PTEN
#
#      entrez_id        variant  \
# 0           25        BCR-ABL
# ...

# %%
df = pd.merge(df, df21, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/3857731425.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'summary_x', 'variant_x', 'variant_groups_x', 'hgvs_expressions_x', 'variant_types_x', 'entrez_id_x', 'gene_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df21, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# 4              5.0  https://civic.genome.wustl.edu/#/events/genes/...    ALK
# ...            ...                                                ...    ...
# ...

# %%
df22 = pd.read_csv('01-Feb-2018-VariantSummaries.csv')
df22
# Out:
#       variant_id                                  variant_civic_url   gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1   ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2   ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3   ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4   AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5    ALK
# ...          ...                                                ...    ...
# 1773        2236  https://civic.genome.wustl.edu/links/variants/...    ATM
# 1774        2237  https://civic.genome.wustl.edu/links/variants/...  KDM5C
# 1775        2238  https://civic.genome.wustl.edu/links/variants/...  BARD1
# 1776        2239  https://civic.genome.wustl.edu/links/variants/...   TPT1
# 1777        2240  https://civic.genome.wustl.edu/links/variants/...   TLK2
#
#       entrez_id             variant  \
# ...

# %%
df = pd.merge(df, df22, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/1993464068.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'reference_build_x', 'chromosome_x', 'variant_id_x', 'reference_bases_x', 'representative_transcript_x', 'chromosome2_x', 'variant_civic_url_x', 'start2_x', 'stop_x', 'stop2_x', 'representative_transcript2_x', 'variant_bases_x', 'ensembl_version_x', 'start_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df22, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# ...

# %%
df23 = pd.read_csv('01-Feb-2019-VariantSummaries.csv')
df23
# Out:
#       variant_id                                  variant_civic_url    gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1    ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2    ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3    ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4    AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5     ALK
# ...          ...                                                ...     ...
# 2093        2593  https://civic.genome.wustl.edu/links/variants/...   NUP98
# 2094        2594  https://civic.genome.wustl.edu/links/variants/...   ASCL1
# 2095        2595  https://civic.genome.wustl.edu/links/variants/...   HDAC2
# 2096        2596  https://civic.genome.wustl.edu/links/variants/...   LZTR1
# 2097        2597  https://civic.genome.wustl.edu/links/variants/...  DICER1
#
#       entrez_id                       variant  \
# ...

# %%
df = pd.merge(df, df23, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/1479165768.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'last_review_date_x', 'summary_x', 'variant_x', 'variant_groups_x', 'hgvs_expressions_x', 'civic_actionability_score_x', 'variant_types_x', 'entrez_id_x', 'gene_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df23, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# 4              5.0  https://civic.genome.wustl.edu/#/events/genes/...    ALK
# ...

# %%
df24 = pd.read_csv('01-Feb-2020-VariantSummaries.csv')
df24
# Out:
#       variant_id                                  variant_civic_url   gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1   ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2   ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3   ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4   AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5    ALK
# ...          ...                                                ...    ...
# 2439        2936  https://civic.genome.wustl.edu/links/variants/...  PRPS1
# 2440        2937  https://civic.genome.wustl.edu/links/variants/...  PRPS1
# 2441        2938  https://civic.genome.wustl.edu/links/variants/...  PRPS1
# 2442        2939  https://civic.genome.wustl.edu/links/variants/...  PRPS1
# 2443        2940  https://civic.genome.wustl.edu/links/variants/...  PRPS1
#
#       entrez_id        variant  \
# 0            25        BCR-ABL
# ...

# %%
df = pd.merge(df, df24, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/1262843643.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'reference_build_x', 'chromosome_x', 'variant_id_x', 'reference_bases_x', 'representative_transcript_x', 'chromosome2_x', 'variant_civic_url_x', 'start2_x', 'stop_x', 'stop2_x', 'representative_transcript2_x', 'variant_bases_x', 'ensembl_version_x', 'start_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df24, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# ...

# %%
df25 = pd.read_csv('01-Feb-2021-VariantSummaries.csv')
df25
# Out:
#       variant_id                                  variant_civic_url   gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1   ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2   ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3   ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4   AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5    ALK
# ...          ...                                                ...    ...
# 1461        3225  https://civic.genome.wustl.edu/links/variants/...  NTRK1
# 1462        3244  https://civic.genome.wustl.edu/links/variants/...    VHL
# 1463        3245  https://civic.genome.wustl.edu/links/variants/...    VHL
# 1464        3246  https://civic.genome.wustl.edu/links/variants/...    VHL
# 1465        3247  https://civic.genome.wustl.edu/links/variants/...    VHL
#
#       entrez_id                        variant  \
# ...

# %%
df = pd.merge(df, df25, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/195689625.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'variant_aliases_x', 'last_review_date_x', 'civic_variant_evidence_score_x', 'Unnamed: 30_x', 'summary_x', 'clinvar_ids_x', 'variant_x', 'allele_registry_id_x', 'Unnamed: 31_x', 'variant_groups_x', 'hgvs_expressions_x', 'Unnamed: 29_x', 'assertion_ids_x', 'assertion_civic_urls_x', 'variant_types_x', 'entrez_id_x', 'Unnamed: 28_x', 'gene_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df25, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# ...

# %%
df26 = pd.read_csv('01-Feb-2022-VariantSummaries.csv')
df26
# Out:
#       variant_id                                  variant_civic_url   gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1   ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2   ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3   ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4   AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5    ALK
# ...          ...                                                ...    ...
# 1519        3644  https://civic.genome.wustl.edu/links/variants/...   PIM1
# 1520        3645  https://civic.genome.wustl.edu/links/variants/...   PIM1
# 1521        3661  https://civic.genome.wustl.edu/links/variants/...  ACVR1
# 1522        3662  https://civic.genome.wustl.edu/links/variants/...  ACVR1
# 1523        3727  https://civic.genome.wustl.edu/links/variants/...   FLCN
#
#       entrez_id        variant  \
# 0            25        BCR-ABL
# ...

# %%
df = pd.merge(df, df26, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/3915522968.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'reference_build_x', 'chromosome_x', 'variant_id_x', 'reference_bases_x', 'representative_transcript_x', 'chromosome2_x', 'variant_civic_url_x', 'start2_x', 'stop_x', 'stop2_x', 'representative_transcript2_x', 'variant_bases_x', 'ensembl_version_x', 'start_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df26, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# ...

# %%
df27 = pd.read_csv('01-Jan-2016-VariantSummaries.csv')
df27
# Out:
#        gene  entrez_id                 variant  \
# 0      ABL1       25.0                 BCR-ABL
# 1      ABL1       25.0           BCR-ABL T315I
# 2      ABL1       25.0           BCR-ABL E255K
# 3      AKT1      207.0                    E17K
# 4       ALK      238.0                EML4-ALK
# ..      ...        ...                     ...
# 378   STAT3     6774.0     SH2 DOMAIN MUTATION
# 379  POU5F1     5460.0              EXPRESSION
# 380   ERBB2     2064.0  KINASE DOMAIN MUTATION
# 381   ERBB2     2064.0             M774INSAYVM
# 382    EGFR     1956.0                   C797S
#
#                                                summary  \
# 0    The BCR-ABL fusion protein, commonly referred ...
# 1    While the efficacy of imatinib has revolutioni...
# 2    While the efficacy of imatinib has revolutioni...
# 3    AKT1 E17K is a recurrent mutation that has bee...
# 4    The EML4-ALK fusion has been seen in non-small...
# ..                                                 ...
# ...

# %%
df = pd.merge(df, df27, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/1488477255.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'summary_x', 'variant_x', 'variant_groups_x', 'entrez_id_x', 'gene_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df27, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# 4              5.0  https://civic.genome.wustl.edu/#/events/genes/...    ALK
# ...            ...                                                ...    ...
# 2496           NaN                                                NaN    NaN
# ...

# %%
df28 = pd.read_csv('01-Jan-2017-VariantSummaries.csv')
df28
# Out:
#      variant_id                                  variant_civic_url   gene  \
# 0             1  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1             2  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2             3  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3             4  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# 4             5  https://civic.genome.wustl.edu/#/events/genes/...    ALK
# ..          ...                                                ...    ...
# 735         817  https://civic.genome.wustl.edu/#/events/genes/...  ERBB2
# 736         818  https://civic.genome.wustl.edu/#/events/genes/...  ERBB2
# 737         819  https://civic.genome.wustl.edu/#/events/genes/...  PTPRB
# 738         820  https://civic.genome.wustl.edu/#/events/genes/...    VHL
# 739         821  https://civic.genome.wustl.edu/#/events/genes/...  HLA-C
#
#      entrez_id                              variant  \
# ...

# %%
df = pd.merge(df, df28, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/589876970.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'variant_types_x', 'hgvs_expressions_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df28, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# 4              5.0  https://civic.genome.wustl.edu/#/events/genes/...    ALK
# ...            ...                                                ...    ...
# 2496           NaN                                                NaN    NaN
# ...

# %%
df29 = pd.read_csv('01-Jan-2018-VariantSummaries.csv')
df29
# Out:
#       variant_id                                  variant_civic_url      gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1      ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2      ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3      ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4      AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5       ALK
# ...          ...                                                ...       ...
# 1746        2206  https://civic.genome.wustl.edu/links/variants/...     FGFR2
# 1747        2207  https://civic.genome.wustl.edu/links/variants/...  PDCD1LG2
# 1748        2208  https://civic.genome.wustl.edu/links/variants/...      LAG3
# 1749        2209  https://civic.genome.wustl.edu/links/variants/...      DLL3
# 1750        2210  https://civic.genome.wustl.edu/links/variants/...      ASNS
#
# ...

# %%
df = pd.merge(df, df29, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/4103862143.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'variant_id_x', 'chromosome2_x', 'variant_groups_x', 'stop2_x', 'chromosome_x', 'last_review_date_x', 'variant_civic_url_x', 'entrez_id_x', 'variant_bases_x', 'ensembl_version_x', 'gene_x', 'start_x', 'reference_build_x', 'summary_x', 'variant_x', 'reference_bases_x', 'representative_transcript_x', 'start2_x', 'representative_transcript2_x', 'stop_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df29, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# ...

# %%
df30 = pd.read_csv('01-Jan-2019-VariantSummaries.csv')
df30
# Out:
#       variant_id                                  variant_civic_url   gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1   ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2   ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3   ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4   AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5    ALK
# ...          ...                                                ...    ...
# 2083        2584  https://civic.genome.wustl.edu/links/variants/...   CDK9
# 2084        2585  https://civic.genome.wustl.edu/links/variants/...  VEGFA
# 2085        2586  https://civic.genome.wustl.edu/links/variants/...  PARP1
# 2086        2587  https://civic.genome.wustl.edu/links/variants/...   JAK2
# 2087        2588  https://civic.genome.wustl.edu/links/variants/...   EPOR
#
#       entrez_id         variant  \
# 0            25         BCR-ABL
# ...

# %%
df = pd.merge(df, df30, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/2031976264.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'variant_types_x', 'hgvs_expressions_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df30, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# 4              5.0  https://civic.genome.wustl.edu/#/events/genes/...    ALK
# ...            ...                                                ...    ...
# 2496           NaN                                                NaN    NaN
# ...

# %%
df31 = pd.read_csv('01-Jan-2020-VariantSummaries.csv')
df31
# Out:
#       variant_id                                  variant_civic_url    gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1    ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2    ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3    ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4    AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5     ALK
# ...          ...                                                ...     ...
# 2393        2889  https://civic.genome.wustl.edu/links/variants/...    ABL1
# 2394        2890  https://civic.genome.wustl.edu/links/variants/...    ABL1
# 2395        2891  https://civic.genome.wustl.edu/links/variants/...   RCSD1
# 2396        2892  https://civic.genome.wustl.edu/links/variants/...  CTNNB1
# 2397        2893  https://civic.genome.wustl.edu/links/variants/...    DPYD
#
#       entrez_id              variant  \
# ...

# %%
df = pd.merge(df, df31, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/3139731954.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'variant_aliases_x', 'variant_id_x', 'chromosome2_x', 'Unnamed: 31_x', 'Unnamed: 29_x', 'variant_groups_x', 'stop2_x', 'assertion_ids_x', 'chromosome_x', 'civic_variant_evidence_score_x', 'last_review_date_x', 'clinvar_ids_x', 'variant_civic_url_x', 'entrez_id_x', 'variant_bases_x', 'ensembl_version_x', 'gene_x', 'Unnamed: 30_x', 'start_x', 'reference_build_x', 'summary_x', 'variant_x', 'allele_registry_id_x', 'reference_bases_x', 'representative_transcript_x', 'start2_x', 'stop_x', 'assertion_civic_urls_x', 'representative_transcript2_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df31, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# ...

# %%
df32 = pd.read_csv('01-Jan-2021-VariantSummaries.csv')
df32
# Out:
#       variant_id                                  variant_civic_url    gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1    ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2    ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3    ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4    AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5     ALK
# ...          ...                                                ...     ...
# 1454        3203  https://civic.genome.wustl.edu/links/variants/...    ATRX
# 1455        3214  https://civic.genome.wustl.edu/links/variants/...    JAK2
# 1456        3222  https://civic.genome.wustl.edu/links/variants/...  PIK3CA
# 1457        3224  https://civic.genome.wustl.edu/links/variants/...   NTRK1
# 1458        3225  https://civic.genome.wustl.edu/links/variants/...   NTRK1
#
#       entrez_id             variant  \
# ...

# %%
df = pd.merge(df, df32, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/860818591.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Unnamed: 28_x', 'variant_types_x', 'hgvs_expressions_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df32, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# 4              5.0  https://civic.genome.wustl.edu/#/events/genes/...    ALK
# ...            ...                                                ...    ...
# 2496           NaN                                                NaN    NaN
# ...

# %%
df33 = pd.read_csv('01-Jan-2022-VariantSummaries.csv')
df33
# Out:
#       variant_id                                  variant_civic_url   gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1   ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2   ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3   ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4   AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5    ALK
# ...          ...                                                ...    ...
# 1514        3643  https://civic.genome.wustl.edu/links/variants/...   PIM1
# 1515        3644  https://civic.genome.wustl.edu/links/variants/...   PIM1
# 1516        3645  https://civic.genome.wustl.edu/links/variants/...   PIM1
# 1517        3661  https://civic.genome.wustl.edu/links/variants/...  ACVR1
# 1518        3662  https://civic.genome.wustl.edu/links/variants/...  ACVR1
#
#       entrez_id        variant  \
# 0            25        BCR-ABL
# ...

# %%
df = pd.merge(df, df33, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/307649183.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'variant_aliases_x', 'variant_id_x', 'chromosome2_x', 'Unnamed: 31_x', 'variant_groups_x', 'Unnamed: 29_x', 'stop2_x', 'assertion_ids_x', 'chromosome_x', 'last_review_date_x', 'civic_variant_evidence_score_x', 'clinvar_ids_x', 'variant_civic_url_x', 'entrez_id_x', 'variant_bases_x', 'ensembl_version_x', 'Unnamed: 32_x', 'gene_x', 'is_flagged_x', 'Unnamed: 30_x', 'start_x', 'reference_build_x', 'summary_x', 'variant_x', 'reference_bases_x', 'representative_transcript_x', 'start2_x', 'representative_transcript2_x', 'stop_x', 'allele_registry_id_x', 'assertion_civic_urls_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df33, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# ...

# %%
df34 = pd.read_csv('01-Jul-2015-VariantSummaries.csv')
df34
# Out:
#       gene  entrez_id           variant  \
# 0     ABL1         25           BCR-ABL
# 1     ABL1         25     BCR-ABL T315I
# 2     ABL1         25     BCR-ABL E255K
# 3     AKT1        207              E17K
# 4      ALK        238          EML4-ALK
# ..     ...        ...               ...
# 163   FLI1       2313   TYPE 1 EWS-FLI1
# 164   EZH2       2146              Y641
# 165   BCL2        596  LOSS-OF-FUNCTION
# 166  KMT2D       8085  Loss-of-function
# 167    BTK        695             C481S
#
#                                                summary  \
# 0    The BCR-ABL fusion protein, commonly referred ...
# 1    While the efficacy of imatinib has revolutioni...
# 2    While the efficacy of imatinib has revolutioni...
# 3    AKT1 E17K is a recurrent mutation that has bee...
# 4    The EML4-ALK fusion has been seen in non-small...
# ..                                                 ...
# 163                                                NaN
# ...

# %%
df = pd.merge(df, df34, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# 4              5.0  https://civic.genome.wustl.edu/#/events/genes/...    ALK
# ...            ...                                                ...    ...
# 2496           NaN                                                NaN    NaN
# 2497           NaN                                                NaN    NaN
# 2498           NaN                                                NaN    NaN
# 2499           NaN                                                NaN    NaN
# 2500           NaN                                                NaN    NaN
#
#       entrez_id_x      variant_x  \
# ...

# %%
df35 = pd.read_csv('01-Jul-2016-VariantSummaries.csv')
df35
# Out:
#      variant_id                                  variant_civic_url  gene  \
# 0             1  https://civic.genome.wustl.edu/#/events/genes/...  ABL1
# 1             2  https://civic.genome.wustl.edu/#/events/genes/...  ABL1
# 2             3  https://civic.genome.wustl.edu/#/events/genes/...  ABL1
# 3             4  https://civic.genome.wustl.edu/#/events/genes/...  AKT1
# 4             5  https://civic.genome.wustl.edu/#/events/genes/...   ALK
# ..          ...                                                ...   ...
# 560         616  https://civic.genome.wustl.edu/#/events/genes/...   B2M
# 561         617  https://civic.genome.wustl.edu/#/events/genes/...  BRAF
# 562         618  https://civic.genome.wustl.edu/#/events/genes/...  BRAF
# 563         619  https://civic.genome.wustl.edu/#/events/genes/...  COX2
# 564         620  https://civic.genome.wustl.edu/#/events/genes/...   ALK
#
#      entrez_id               variant  \
# 0           25               BCR-ABL
# ...

# %%
df = pd.merge(df, df35, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/3150173672.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'summary_x', 'variant_x', 'variant_groups_x', 'variant_types_x', 'entrez_id_x', 'gene_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df35, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# 4              5.0  https://civic.genome.wustl.edu/#/events/genes/...    ALK
# ...            ...                                                ...    ...
# ...

# %%
df36 = pd.read_csv('01-Jul-2017-VariantSummaries.csv')
df36
# Out:
#       variant_id                                  variant_civic_url    gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1    ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2    ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3    ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4    AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5     ALK
# ...          ...                                                ...     ...
# 1596        2045  https://civic.genome.wustl.edu/links/variants/...     VHL
# 1597        2046  https://civic.genome.wustl.edu/links/variants/...     VHL
# 1598        2047  https://civic.genome.wustl.edu/links/variants/...  CTNNB1
# 1599        2048  https://civic.genome.wustl.edu/links/variants/...     VHL
# 1600        2049  https://civic.genome.wustl.edu/links/variants/...     VHL
#
#       entrez_id                           variant  \
# ...

# %%
df = pd.merge(df, df35, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/3150173672.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'reference_build_x', 'chromosome_x', 'variant_id_x', 'reference_bases_x', 'representative_transcript_x', 'chromosome2_x', 'variant_civic_url_x', 'start2_x', 'stop_x', 'stop2_x', 'representative_transcript2_x', 'variant_bases_x', 'ensembl_version_x', 'start_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df35, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# ...

# %%
df37 = pd.read_csv('01-Jul-2018-VariantSummaries.csv')
df37
# Out:
#       variant_id                                  variant_civic_url  gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1  ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2  ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3  ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4  AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5   ALK
# ...          ...                                                ...   ...
# 1880        2367  https://civic.genome.wustl.edu/links/variants/...   VHL
# 1881        2368  https://civic.genome.wustl.edu/links/variants/...   VHL
# 1882        2369  https://civic.genome.wustl.edu/links/variants/...   VHL
# 1883        2370  https://civic.genome.wustl.edu/links/variants/...  ABL1
# 1884        2371  https://civic.genome.wustl.edu/links/variants/...  ABL1
#
#       entrez_id               variant  \
# 0            25               BCR-ABL
# ...

# %%
df = pd.merge(df, df37, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/48481928.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'summary_x', 'variant_x', 'variant_groups_x', 'hgvs_expressions_x', 'civic_actionability_score_x', 'variant_types_x', 'entrez_id_x', 'gene_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df37, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# 4              5.0  https://civic.genome.wustl.edu/#/events/genes/...    ALK
# ...            ...                                                ...    ...
# ...

# %%
df38 = pd.read_csv('01-Jul-2019-VariantSummaries.csv')
df38
# Out:
#       variant_id                                  variant_civic_url   gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1   ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2   ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3   ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4   AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5    ALK
# ...          ...                                                ...    ...
# 2240        2739  https://civic.genome.wustl.edu/links/variants/...  CRLF2
# 2241        2740  https://civic.genome.wustl.edu/links/variants/...  IKZF1
# 2242        2741  https://civic.genome.wustl.edu/links/variants/...   EGFR
# 2243        2743  https://civic.genome.wustl.edu/links/variants/...  FGFR1
# 2244        2744  https://civic.genome.wustl.edu/links/variants/...  IKZF1
#
#       entrez_id                      variant  \
# ...

# %%
df = pd.merge(df, df38, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/778974800.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'reference_build_x', 'chromosome_x', 'last_review_date_x', 'variant_id_x', 'reference_bases_x', 'representative_transcript_x', 'chromosome2_x', 'variant_civic_url_x', 'start2_x', 'stop_x', 'stop2_x', 'representative_transcript2_x', 'variant_bases_x', 'ensembl_version_x', 'start_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df38, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# ...

# %%
df39 = pd.read_csv('01-Jul-2020-VariantSummaries.csv')
df39
# Out:
#       variant_id                                  variant_civic_url  gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1  ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2  ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3  ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4  AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5   ALK
# ...          ...                                                ...   ...
# 2570        3092  https://civic.genome.wustl.edu/links/variants/...   VHL
# 2571        3093  https://civic.genome.wustl.edu/links/variants/...   VHL
# 2572        3094  https://civic.genome.wustl.edu/links/variants/...   VHL
# 2573        3095  https://civic.genome.wustl.edu/links/variants/...   VHL
# 2574        3096  https://civic.genome.wustl.edu/links/variants/...   VHL
#
#       entrez_id                   variant  \
# ...

# %%
df = pd.merge(df, df39, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/2601563594.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'variant_aliases_x', 'civic_variant_evidence_score_x', 'Unnamed: 30_x', 'summary_x', 'clinvar_ids_x', 'variant_x', 'allele_registry_id_x', 'Unnamed: 31_x', 'variant_groups_x', 'hgvs_expressions_x', 'Unnamed: 29_x', 'assertion_ids_x', 'assertion_civic_urls_x', 'variant_types_x', 'entrez_id_x', 'Unnamed: 28_x', 'gene_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df39, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# ...

# %%
df40 = pd.read_csv('01-Jul-2021-VariantSummaries.csv')
df40
# Out:
#       variant_id                                  variant_civic_url    gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1    ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2    ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3    ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4    AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5     ALK
# ...          ...                                                ...     ...
# 1495        3364  https://civic.genome.wustl.edu/links/variants/...    EZH2
# 1496        3371  https://civic.genome.wustl.edu/links/variants/...     ALK
# 1497        3373  https://civic.genome.wustl.edu/links/variants/...    CD44
# 1498        3381  https://civic.genome.wustl.edu/links/variants/...  PIK3R2
# 1499        3382  https://civic.genome.wustl.edu/links/variants/...    PTEN
#
#       entrez_id        variant  \
# ...

# %%
df = pd.merge(df, df40, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/2156593589.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'reference_build_x', 'chromosome_x', 'last_review_date_x', 'variant_id_x', 'reference_bases_x', 'representative_transcript_x', 'chromosome2_x', 'variant_civic_url_x', 'start2_x', 'stop_x', 'stop2_x', 'representative_transcript2_x', 'variant_bases_x', 'ensembl_version_x', 'start_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df40, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# ...

# %%
df41 = pd.read_csv('01-Jun-2016-VariantSummaries.csv')
df1
# Out:
#      variant_id                                  variant_civic_url     gene  \
# 0             1  https://civic.genome.wustl.edu/#/events/genes/...     ABL1
# 1             2  https://civic.genome.wustl.edu/#/events/genes/...     ABL1
# 2             3  https://civic.genome.wustl.edu/#/events/genes/...     ABL1
# 3             4  https://civic.genome.wustl.edu/#/events/genes/...     AKT1
# 4             5  https://civic.genome.wustl.edu/#/events/genes/...      ALK
# ..          ...                                                ...      ...
# 478         526  https://civic.genome.wustl.edu/#/events/genes/...  BCL2L11
# 479         527  https://civic.genome.wustl.edu/#/events/genes/...      ALK
# 480         528  https://civic.genome.wustl.edu/#/events/genes/...      ALK
# 481         529  https://civic.genome.wustl.edu/#/events/genes/...    SIRT1
# 482         530  https://civic.genome.wustl.edu/#/events/genes/...     KRAS
#
#      entrez_id                variant  \
# ...

# %%
df = pd.merge(df, df41, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/3281551551.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'summary_x', 'variant_x', 'variant_groups_x', 'variant_types_x', 'entrez_id_x', 'gene_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df41, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# 4              5.0  https://civic.genome.wustl.edu/#/events/genes/...    ALK
# ...            ...                                                ...    ...
# ...

# %%
df42 = pd.read_csv('01-Jun-2017-VariantSummaries.csv')
df42
# Out:
#       variant_id                                  variant_civic_url  gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1  ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2  ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3  ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4  AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5   ALK
# ...          ...                                                ...   ...
# 1414        1862  https://civic.genome.wustl.edu/links/variants/...   VHL
# 1415        1863  https://civic.genome.wustl.edu/links/variants/...  EGFR
# 1416        1864  https://civic.genome.wustl.edu/links/variants/...   VHL
# 1417        1865  https://civic.genome.wustl.edu/links/variants/...   VHL
# 1418        1866  https://civic.genome.wustl.edu/links/variants/...  EGFR
#
#       entrez_id            variant  \
# 0            25            BCR-ABL
# ...

# %%
df = pd.merge(df, df42, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/788123071.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'reference_build_x', 'chromosome_x', 'variant_id_x', 'reference_bases_x', 'representative_transcript_x', 'chromosome2_x', 'variant_civic_url_x', 'hgvs_expressions_x', 'stop_x', 'start2_x', 'stop2_x', 'representative_transcript2_x', 'variant_bases_x', 'ensembl_version_x', 'start_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df42, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# ...

# %%
df43 = pd.read_csv('01-Jun-2018-VariantSummaries.csv')
df43
# Out:
#       variant_id                                  variant_civic_url   gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1   ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2   ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3   ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4   AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5    ALK
# ...          ...                                                ...    ...
# 1854        2329  https://civic.genome.wustl.edu/links/variants/...    VHL
# 1855        2330  https://civic.genome.wustl.edu/links/variants/...  ERBB2
# 1856        2331  https://civic.genome.wustl.edu/links/variants/...  ERBB2
# 1857        2332  https://civic.genome.wustl.edu/links/variants/...   EGFR
# 1858        2333  https://civic.genome.wustl.edu/links/variants/...   EGFR
#
#       entrez_id                 variant  \
# ...

# %%
df = pd.merge(df, df43, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/4179008961.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'last_review_date_x', 'summary_x', 'variant_x', 'variant_groups_x', 'variant_types_x', 'entrez_id_x', 'gene_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df43, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# 4              5.0  https://civic.genome.wustl.edu/#/events/genes/...    ALK
# ...            ...                                                ...    ...
# ...

# %%
df44 = pd.read_csv('01-Jun-2019-VariantSummaries.csv')
df44
# Out:
#       variant_id                                  variant_civic_url   gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1   ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2   ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3   ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4   AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5    ALK
# ...          ...                                                ...    ...
# 2216        2715  https://civic.genome.wustl.edu/links/variants/...   MTOR
# 2217        2716  https://civic.genome.wustl.edu/links/variants/...   MTOR
# 2218        2717  https://civic.genome.wustl.edu/links/variants/...  PSMD4
# 2219        2718  https://civic.genome.wustl.edu/links/variants/...  CCNE1
# 2220        2719  https://civic.genome.wustl.edu/links/variants/...   TP53
#
#       entrez_id              variant  \
# ...

# %%
df = pd.merge(df, df44, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/1425460145.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'variant_aliases_x', 'variant_id_x', 'chromosome2_x', 'Unnamed: 31_x', 'Unnamed: 29_x', 'hgvs_expressions_x', 'stop2_x', 'assertion_ids_x', 'chromosome_x', 'civic_variant_evidence_score_x', 'clinvar_ids_x', 'variant_civic_url_x', 'variant_bases_x', 'ensembl_version_x', 'Unnamed: 30_x', 'start_x', 'reference_build_x', 'reference_bases_x', 'allele_registry_id_x', 'representative_transcript_x', 'start2_x', 'representative_transcript2_x', 'stop_x', 'assertion_civic_urls_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df44, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# ...

# %%
df45 = pd.read_csv('01-Jun-2020-VariantSummaries.csv')
df45
# Out:
#       variant_id                                  variant_civic_url   gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1   ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2   ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3   ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4   AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5    ALK
# ...          ...                                                ...    ...
# 2549        3065  https://civic.genome.wustl.edu/links/variants/...  FGFR2
# 2550        3066  https://civic.genome.wustl.edu/links/variants/...    VHL
# 2551        3067  https://civic.genome.wustl.edu/links/variants/...    VHL
# 2552        3068  https://civic.genome.wustl.edu/links/variants/...    VHL
# 2553        3069  https://civic.genome.wustl.edu/links/variants/...  NTRK3
#
#       entrez_id              variant  \
# ...

# %%
df = pd.merge(df, df45, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/4020360775.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'last_review_date_x', 'summary_x', 'variant_x', 'variant_groups_x', 'variant_types_x', 'entrez_id_x', 'Unnamed: 28_x', 'gene_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df45, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# 4              5.0  https://civic.genome.wustl.edu/#/events/genes/...    ALK
# ...            ...                                                ...    ...
# ...

# %%
df46 = pd.read_csv('01-Jun-2021-VariantSummaries.csv')
df46
# Out:
#       variant_id                                  variant_civic_url     gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1     ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2     ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3     ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4     AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5      ALK
# ...          ...                                                ...      ...
# 1487        3274  https://civic.genome.wustl.edu/links/variants/...   PDGFRA
# 1488        3299  https://civic.genome.wustl.edu/links/variants/...  PPP2R1A
# 1489        3311  https://civic.genome.wustl.edu/links/variants/...   PIK3CA
# 1490        3313  https://civic.genome.wustl.edu/links/variants/...   CDKN1A
# 1491        3318  https://civic.genome.wustl.edu/links/variants/...     TP53
#
# ...

# %%
df = pd.merge(df, df46, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/2803490763.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'variant_aliases_x', 'variant_id_x', 'chromosome2_x', 'Unnamed: 31_x', 'Unnamed: 29_x', 'hgvs_expressions_x', 'stop2_x', 'assertion_ids_x', 'chromosome_x', 'civic_variant_evidence_score_x', 'clinvar_ids_x', 'variant_civic_url_x', 'variant_bases_x', 'ensembl_version_x', 'Unnamed: 32_x', 'is_flagged_x', 'Unnamed: 30_x', 'start_x', 'reference_build_x', 'reference_bases_x', 'representative_transcript_x', 'start2_x', 'representative_transcript2_x', 'allele_registry_id_x', 'stop_x', 'assertion_civic_urls_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df46, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# ...

# %%
df47 = pd.read_csv('01-Mar-2016-VariantSummaries.csv')
df47
# Out:
#      gene  entrez_id           variant  \
# 0    ABL1         25           BCR-ABL
# 1    ABL1         25     BCR-ABL T334I
# 2    ABL1         25     BCR-ABL E255K
# 3    AKT1        207              E17K
# 4     ALK        238          EML4-ALK
# ..    ...        ...               ...
# 451   ALK        238       ALK FUSIONS
# 452   ALK        238  EML4-ALK E20;A20
# 453   ALK        238   EML4-ALK E2;A20
# 454   KDR       3791             R961W
# 455   ALK        238   EML4-ALK E6;A20
#
#                                                summary  \
# 0    The BCR-ABL fusion protein, commonly referred ...
# 1    While the efficacy of imatinib has revolutioni...
# 2    While the efficacy of imatinib has revolutioni...
# 3    AKT1 E17K is a recurrent mutation that has bee...
# 4    The EML4-ALK fusion has been seen in non-small...
# ..                                                 ...
# 451                                                NaN
# ...

# %%
df = pd.merge(df, df47, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/915395000.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'summary_x', 'variant_x', 'variant_groups_x', 'entrez_id_x', 'gene_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df47, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# 4              5.0  https://civic.genome.wustl.edu/#/events/genes/...    ALK
# ...            ...                                                ...    ...
# 2570           NaN                                                NaN    NaN
# ...

# %%
df48 = pd.read_csv('01-Mar-2017-VariantSummaries.csv')
df48
# Out:
#       variant_id                                  variant_civic_url   gene  \
# 0              1  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# 4              5  https://civic.genome.wustl.edu/#/events/genes/...    ALK
# ...          ...                                                ...    ...
# 1029        1250  https://civic.genome.wustl.edu/#/events/genes/...  BRCA2
# 1030        1251  https://civic.genome.wustl.edu/#/events/genes/...  BRCA2
# 1031        1252  https://civic.genome.wustl.edu/#/events/genes/...  BRCA2
# 1032        1253  https://civic.genome.wustl.edu/#/events/genes/...  BRCA2
# 1033        1254  https://civic.genome.wustl.edu/#/events/genes/...   TP53
#
#       entrez_id        variant  \
# 0            25        BCR-ABL
# ...

# %%
df = pd.merge(df, df48, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/3888911575.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'reference_build_x', 'chromosome_x', 'reference_bases_x', 'representative_transcript_x', 'chromosome2_x', 'start2_x', 'representative_transcript2_x', 'stop_x', 'stop2_x', 'variant_types_x', 'variant_bases_x', 'ensembl_version_x', 'start_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df48, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# ...

# %%
df49 = pd.read_csv('01-Mar-2018-VariantSummaries.csv')
df49
# Out:
#       variant_id                                  variant_civic_url   gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1   ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2   ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3   ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4   AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5    ALK
# ...          ...                                                ...    ...
# 1773        2236  https://civic.genome.wustl.edu/links/variants/...    ATM
# 1774        2237  https://civic.genome.wustl.edu/links/variants/...  KDM5C
# 1775        2238  https://civic.genome.wustl.edu/links/variants/...  BARD1
# 1776        2239  https://civic.genome.wustl.edu/links/variants/...   TPT1
# 1777        2240  https://civic.genome.wustl.edu/links/variants/...   TLK2
#
#       entrez_id             variant  \
# ...

# %%
df = pd.merge(df, df49, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/1211794578.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'last_review_date_x', 'variant_id_x', 'summary_x', 'variant_x', 'variant_civic_url_x', 'variant_groups_x', 'hgvs_expressions_x', 'entrez_id_x', 'gene_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df49, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# 4              5.0  https://civic.genome.wustl.edu/#/events/genes/...    ALK
# ...

# %%
df50 = pd.read_csv('01-Mar-2019-VariantSummaries.csv')
df50
# Out:
#       variant_id                                  variant_civic_url     gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1     ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2     ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3     ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4     AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5      ALK
# ...          ...                                                ...      ...
# 2138        2640  https://civic.genome.wustl.edu/links/variants/...    NTRK2
# 2139        2641  https://civic.genome.wustl.edu/links/variants/...    FGFR1
# 2140        2642  https://civic.genome.wustl.edu/links/variants/...   PTPN11
# 2141        2643  https://civic.genome.wustl.edu/links/variants/...      KIT
# 2142        2644  https://civic.genome.wustl.edu/links/variants/...  SMARCA4
#
#       entrez_id           variant  \
# ...

# %%
df = pd.merge(df, df50, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/1282904084.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'reference_build_x', 'chromosome_x', 'reference_bases_x', 'representative_transcript_x', 'chromosome2_x', 'start2_x', 'representative_transcript2_x', 'civic_actionability_score_x', 'stop_x', 'stop2_x', 'variant_types_x', 'variant_bases_x', 'ensembl_version_x', 'start_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df50, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# ...

# %%
df51 = pd.read_csv('01-Mar-2020-VariantSummaries.csv')
df51
# Out:
#       variant_id                                  variant_civic_url    gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1    ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2    ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3    ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4    AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5     ALK
# ...          ...                                                ...     ...
# 2467        2969  https://civic.genome.wustl.edu/links/variants/...   HMGA2
# 2468        2970  https://civic.genome.wustl.edu/links/variants/...   VEGFC
# 2469        2971  https://civic.genome.wustl.edu/links/variants/...  PDGFRA
# 2470        2972  https://civic.genome.wustl.edu/links/variants/...   PDGFB
# 2471        2973  https://civic.genome.wustl.edu/links/variants/...  PDGFRB
#
#       entrez_id         variant  \
# ...

# %%
df = pd.merge(df, df51, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/2263389768.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'last_review_date_x', 'variant_id_x', 'summary_x', 'variant_x', 'variant_civic_url_x', 'variant_groups_x', 'hgvs_expressions_x', 'entrez_id_x', 'gene_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df51, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# 4              5.0  https://civic.genome.wustl.edu/#/events/genes/...    ALK
# ...

# %%
df52 = pd.read_csv('01-Mar-2021-VariantSummaries.csv')
df52
# Out:
#       variant_id                                  variant_civic_url    gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1    ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2    ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3    ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4    AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5     ALK
# ...          ...                                                ...     ...
# 1465        3245  https://civic.genome.wustl.edu/links/variants/...     VHL
# 1466        3246  https://civic.genome.wustl.edu/links/variants/...     VHL
# 1467        3247  https://civic.genome.wustl.edu/links/variants/...     VHL
# 1468        3257  https://civic.genome.wustl.edu/links/variants/...    AKT1
# 1469        3274  https://civic.genome.wustl.edu/links/variants/...  PDGFRA
#
#       entrez_id                        variant  \
# ...

# %%
df = pd.merge(df, df52, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/2872334555.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'variant_aliases_x', 'chromosome2_x', 'Unnamed: 31_x', 'Unnamed: 29_x', 'stop2_x', 'assertion_ids_x', 'variant_types_x', 'chromosome_x', 'civic_variant_evidence_score_x', 'clinvar_ids_x', 'variant_bases_x', 'ensembl_version_x', 'Unnamed: 30_x', 'start_x', 'reference_build_x', 'reference_bases_x', 'representative_transcript_x', 'start2_x', 'representative_transcript2_x', 'allele_registry_id_x', 'stop_x', 'assertion_civic_urls_x', 'Unnamed: 28_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df52, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# ...

# %%
df53 = pd.read_csv('01-Mar-2022-VariantSummaries.csv')
df53
# Out:
#       variant_id                                  variant_civic_url     gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1     ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2     ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3     ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4     AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5      ALK
# ...          ...                                                ...      ...
# 1522        3661  https://civic.genome.wustl.edu/links/variants/...    ACVR1
# 1523        3662  https://civic.genome.wustl.edu/links/variants/...    ACVR1
# 1524        3727  https://civic.genome.wustl.edu/links/variants/...     FLCN
# 1525        3728  https://civic.genome.wustl.edu/links/variants/...  SLC29A1
# 1526        3737  https://civic.genome.wustl.edu/links/variants/...     EZH2
#
#       entrez_id              variant  \
# ...

# %%
df = pd.merge(df, df53, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/1019806592.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'last_review_date_x', 'variant_id_x', 'summary_x', 'variant_x', 'variant_civic_url_x', 'variant_groups_x', 'hgvs_expressions_x', 'entrez_id_x', 'gene_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df53, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# 4              5.0  https://civic.genome.wustl.edu/#/events/genes/...    ALK
# ...

# %%
df54 = pd.read_csv('01-May-2015-VariantSummaries.csv')
df54
# Out:
#        gene  entrez_id        variant  \
# 0      ABL1         25        BCR-ABL
# 1      ABL1         25  BCR-ABL T315I
# 2      ABL1         25  BCR-ABL E255K
# 3      AKT1        207           E17K
# 4       ALK        238       EML4-ALK
# ..      ...        ...            ...
# 145    KRAS       3845           G12A
# 146    MTOR       2475         Q2223K
# 147  PDGFRA       5156          G853D
# 148    BRAF        673          G469L
# 149     KIT       3815          K642E
#
#                                                summary  \
# 0    The BCR-ABL fusion protein, commonly referred ...
# 1    While the efficacy of imatinib has revolutioni...
# 2    While the efficacy of imatinib has revolutioni...
# 3    AKT1 E17K is a recurrent mutation that has bee...
# 4    The EML4-ALK fusion has been seen in non-small...
# ..                                                 ...
# 145  KRAS G12A, like EGFR T790M, has been shown to ...
# ...

# %%
df = pd.merge(df, df54, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# 4              5.0  https://civic.genome.wustl.edu/#/events/genes/...    ALK
# ...            ...                                                ...    ...
# 2570           NaN                                                NaN    NaN
# 2571           NaN                                                NaN    NaN
# 2572           NaN                                                NaN    NaN
# 2573           NaN                                                NaN    NaN
# 2574           NaN                                                NaN    NaN
#
#       entrez_id_x      variant_x  \
# ...

# %%
df55 = pd.read_csv('01-May-2016-VariantSummaries.csv')
df55
# Out:
#      variant_id                                  variant_civic_url      gene  \
# 0             1  https://civic.genome.wustl.edu/#/events/genes/...      ABL1
# 1             2  https://civic.genome.wustl.edu/#/events/genes/...      ABL1
# 2             3  https://civic.genome.wustl.edu/#/events/genes/...      ABL1
# 3             4  https://civic.genome.wustl.edu/#/events/genes/...      AKT1
# 4             5  https://civic.genome.wustl.edu/#/events/genes/...       ALK
# ..          ...                                                ...       ...
# 498         548  https://civic.genome.wustl.edu/#/events/genes/...  PPP1R15A
# 499         549  https://civic.genome.wustl.edu/#/events/genes/...       ALK
# 500         550  https://civic.genome.wustl.edu/#/events/genes/...       ALK
# 501         551  https://civic.genome.wustl.edu/#/events/genes/...       ALK
# 502         552  https://civic.genome.wustl.edu/#/events/genes/...       ALK
#
#      entrez_id            variant  \
# ...

# %%
df = pd.merge(df, df55, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/546645213.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'reference_build_x', 'chromosome_x', 'summary_x', 'reference_bases_x', 'representative_transcript_x', 'chromosome2_x', 'start2_x', 'representative_transcript2_x', 'stop_x', 'stop2_x', 'variant_x', 'variant_groups_x', 'variant_types_x', 'entrez_id_x', 'variant_bases_x', 'ensembl_version_x', 'start_x', 'gene_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df55, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# ...

# %%
df56 = pd.read_csv('01-May-2017-VariantSummaries.csv')
df56
# Out:
#       variant_id                                  variant_civic_url   gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1   ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2   ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3   ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4   AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5    ALK
# ...          ...                                                ...    ...
# 1018        1314  https://civic.genome.wustl.edu/links/variants/...  ERBB2
# 1019        1316  https://civic.genome.wustl.edu/links/variants/...    KIT
# 1020        1317  https://civic.genome.wustl.edu/links/variants/...   NRAS
# 1021        1318  https://civic.genome.wustl.edu/links/variants/...   TP53
# 1022        1319  https://civic.genome.wustl.edu/links/variants/...   GNAS
#
#       entrez_id             variant  \
# ...

# %%
df = pd.merge(df, df56, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/1860574309.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'variant_id_x', 'variant_civic_url_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df56, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# 4              5.0  https://civic.genome.wustl.edu/#/events/genes/...    ALK
# ...            ...                                                ...    ...
# 2570           NaN                                                NaN    NaN
# ...

# %%
df57 = pd.read_csv('01-May-2019-VariantSummaries.csv')
df57
# Out:
#       variant_id                                  variant_civic_url   gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1   ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2   ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3   ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4   AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5    ALK
# ...          ...                                                ...    ...
# 2188        2688  https://civic.genome.wustl.edu/links/variants/...  FGFR3
# 2189        2689  https://civic.genome.wustl.edu/links/variants/...    NF1
# 2190        2690  https://civic.genome.wustl.edu/links/variants/...  NTRK1
# 2191        2691  https://civic.genome.wustl.edu/links/variants/...  NTRK3
# 2192        2692  https://civic.genome.wustl.edu/links/variants/...    B2M
#
#       entrez_id        variant  \
# 0            25        BCR-ABL
# ...

# %%
df = pd.merge(df, df57, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/3969930715.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'variant_aliases_x', 'chromosome2_x', 'Unnamed: 29_x', 'variant_groups_x', 'stop2_x', 'assertion_ids_x', 'hgvs_expressions_x', 'variant_types_x', 'chromosome_x', 'civic_variant_evidence_score_x', 'last_review_date_x', 'clinvar_ids_x', 'entrez_id_x', 'variant_bases_x', 'ensembl_version_x', 'gene_x', 'Unnamed: 30_x', 'start_x', 'reference_build_x', 'summary_x', 'variant_x', 'allele_registry_id_x', 'reference_bases_x', 'representative_transcript_x', 'start2_x', 'stop_x', 'assertion_civic_urls_x', 'representative_transcript2_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df57, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# ...

# %%
df58 = pd.read_csv('01-May-2020-VariantSummaries.csv')
df58
# Out:
#       variant_id                                  variant_civic_url  gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1  ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2  ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3  ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4  AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5   ALK
# ...          ...                                                ...   ...
# 2517        3021  https://civic.genome.wustl.edu/links/variants/...   VHL
# 2518        3022  https://civic.genome.wustl.edu/links/variants/...   VHL
# 2519        3023  https://civic.genome.wustl.edu/links/variants/...   PML
# 2520        3024  https://civic.genome.wustl.edu/links/variants/...   PML
# 2521        3025  https://civic.genome.wustl.edu/links/variants/...   PML
#
#       entrez_id                    variant  \
# ...

# %%
df = pd.merge(df, df58, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/769344803.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'variant_id_x', 'Unnamed: 28_x', 'Unnamed: 31_x', 'variant_civic_url_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df58, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# 4              5.0  https://civic.genome.wustl.edu/#/events/genes/...    ALK
# ...            ...                                                ...    ...
# 2570           NaN                                                NaN    NaN
# ...

# %%
df59 = pd.read_csv('01-May-2021-VariantSummaries.csv')
df59
# Out:
#       variant_id                                  variant_civic_url     gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1     ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2     ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3     ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4     AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5      ALK
# ...          ...                                                ...      ...
# 1487        3274  https://civic.genome.wustl.edu/links/variants/...   PDGFRA
# 1488        3299  https://civic.genome.wustl.edu/links/variants/...  PPP2R1A
# 1489        3311  https://civic.genome.wustl.edu/links/variants/...   PIK3CA
# 1490        3313  https://civic.genome.wustl.edu/links/variants/...   CDKN1A
# 1491        3318  https://civic.genome.wustl.edu/links/variants/...     TP53
#
# ...

# %%
df = pd.merge(df, df59, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/4123233506.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'variant_aliases_x', 'chromosome2_x', 'variant_groups_x', 'hgvs_expressions_x', 'stop2_x', 'assertion_ids_x', 'Unnamed: 29_x', 'variant_types_x', 'chromosome_x', 'last_review_date_x', 'civic_variant_evidence_score_x', 'clinvar_ids_x', 'entrez_id_x', 'variant_bases_x', 'ensembl_version_x', 'Unnamed: 32_x', 'gene_x', 'is_flagged_x', 'Unnamed: 30_x', 'start_x', 'reference_build_x', 'summary_x', 'variant_x', 'reference_bases_x', 'representative_transcript_x', 'start2_x', 'representative_transcript2_x', 'stop_x', 'allele_registry_id_x', 'assertion_civic_urls_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df59, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# ...

# %%
df60 = pd.read_csv('01-Nov-2015-VariantSummaries.csv')
df60
# Out:
#        gene  entrez_id        variant  \
# 0      ABL1         25        BCR-ABL
# 1      ABL1         25  BCR-ABL T315I
# 2      ABL1         25  BCR-ABL E255K
# 3      AKT1        207           E17K
# 4       ALK        238       EML4-ALK
# ..      ...        ...            ...
# 209     ATM        472      V2288fs*1
# 210     ATM        472         N2875H
# 211     NF2       4771         Y177fs
# 212  PDGFRA       5156          V561A
# 213    TERT       7015          C228T
#
#                                                summary  \
# 0    The BCR-ABL fusion protein, commonly referred ...
# 1    While the efficacy of imatinib has revolutioni...
# 2    While the efficacy of imatinib has revolutioni...
# 3    AKT1 E17K is a recurrent mutation that has bee...
# 4    The EML4-ALK fusion has been seen in non-small...
# ..                                                 ...
# 209  A frameshift mutation predicted to cause trunc...
# ...

# %%
df = pd.merge(df, df60, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# 4              5.0  https://civic.genome.wustl.edu/#/events/genes/...    ALK
# ...            ...                                                ...    ...
# 2570           NaN                                                NaN    NaN
# 2571           NaN                                                NaN    NaN
# 2572           NaN                                                NaN    NaN
# 2573           NaN                                                NaN    NaN
# 2574           NaN                                                NaN    NaN
#
#       entrez_id_x      variant_x  \
# ...

# %%
df61 = pd.read_csv('01-Nov-2017-VariantSummaries.csv')
df61
# Out:
#       variant_id                                  variant_civic_url    gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1    ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2    ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3    ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4    AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5     ALK
# ...          ...                                                ...     ...
# 1720        2179  https://civic.genome.wustl.edu/links/variants/...    NRG1
# 1721        2180  https://civic.genome.wustl.edu/links/variants/...  TSPYL1
# 1722        2181  https://civic.genome.wustl.edu/links/variants/...     VHL
# 1723        2182  https://civic.genome.wustl.edu/links/variants/...     VHL
# 1724        2183  https://civic.genome.wustl.edu/links/variants/...  ERRFI1
#
#       entrez_id                               variant  \
# ...

# %%
df = pd.merge(df, df61, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/1285913085.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'variant_id_x', 'summary_x', 'variant_x', 'variant_civic_url_x', 'variant_groups_x', 'entrez_id_x', 'gene_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df61, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# 4              5.0  https://civic.genome.wustl.edu/#/events/genes/...    ALK
# ...            ...                                                ...    ...
# ...

# %%
df62 = pd.read_csv('01-Nov-2018-VariantSummaries.csv')
df62
# Out:
#       variant_id                                  variant_civic_url  gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1  ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2  ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3  ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4  AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5   ALK
# ...          ...                                                ...   ...
# 2074        2568  https://civic.genome.wustl.edu/links/variants/...   RET
# 2075        2569  https://civic.genome.wustl.edu/links/variants/...  EZH2
# 2076        2570  https://civic.genome.wustl.edu/links/variants/...  HRAS
# 2077        2571  https://civic.genome.wustl.edu/links/variants/...  ABL2
# 2078        2572  https://civic.genome.wustl.edu/links/variants/...  JAK2
#
#       entrez_id        variant  \
# 0            25        BCR-ABL
# ...

# %%
df = pd.merge(df, df62, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/1453027688.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'reference_build_x', 'chromosome_x', 'last_review_date_x', 'reference_bases_x', 'representative_transcript_x', 'chromosome2_x', 'start2_x', 'representative_transcript2_x', 'stop_x', 'stop2_x', 'hgvs_expressions_x', 'variant_types_x', 'variant_bases_x', 'ensembl_version_x', 'start_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df62, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# ...

# %%
df63 = pd.read_csv('01-Nov-2019-VariantSummaries.csv')
df63
# Out:
#       variant_id                                  variant_civic_url   gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1   ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2   ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3   ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4   AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5    ALK
# ...          ...                                                ...    ...
# 2371        2867  https://civic.genome.wustl.edu/links/variants/...    VHL
# 2372        2868  https://civic.genome.wustl.edu/links/variants/...    VHL
# 2373        2869  https://civic.genome.wustl.edu/links/variants/...    VHL
# 2374        2870  https://civic.genome.wustl.edu/links/variants/...    VHL
# 2375        2871  https://civic.genome.wustl.edu/links/variants/...  BRCA2
#
#       entrez_id              variant  \
# ...

# %%
df = pd.merge(df, df63, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/1857046383.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'variant_id_x', 'summary_x', 'variant_x', 'Unnamed: 31_x', 'variant_civic_url_x', 'variant_groups_x', 'entrez_id_x', 'gene_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df63, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# 4              5.0  https://civic.genome.wustl.edu/#/events/genes/...    ALK
# ...            ...                                                ...    ...
# ...

# %%
df64 = pd.read_csv('01-Nov-2020-VariantSummaries.csv')
df64
# Out:
#       variant_id                                  variant_civic_url    gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1    ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2    ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3    ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4    AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5     ALK
# ...          ...                                                ...     ...
# 1450        3158  https://civic.genome.wustl.edu/links/variants/...   NTRK2
# 1451        3200  https://civic.genome.wustl.edu/links/variants/...    KRAS
# 1452        3203  https://civic.genome.wustl.edu/links/variants/...    ATRX
# 1453        3214  https://civic.genome.wustl.edu/links/variants/...    JAK2
# 1454        3222  https://civic.genome.wustl.edu/links/variants/...  PIK3CA
#
#       entrez_id           variant  \
# ...

# %%
df = pd.merge(df, df64, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/1283523534.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'variant_aliases_x', 'chromosome2_x', 'Unnamed: 29_x', 'hgvs_expressions_x', 'stop2_x', 'assertion_ids_x', 'variant_types_x', 'chromosome_x', 'last_review_date_x', 'civic_variant_evidence_score_x', 'clinvar_ids_x', 'variant_bases_x', 'ensembl_version_x', 'Unnamed: 30_x', 'start_x', 'reference_build_x', 'reference_bases_x', 'representative_transcript_x', 'start2_x', 'representative_transcript2_x', 'allele_registry_id_x', 'stop_x', 'assertion_civic_urls_x', 'Unnamed: 28_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df64, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# ...

# %%
df65 = pd.read_csv('01-Nov-2021-VariantSummaries.csv')
df65
# Out:
#       variant_id                                  variant_civic_url  gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1  ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2  ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3  ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4  AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5   ALK
# ...          ...                                                ...   ...
# 1501        3382  https://civic.genome.wustl.edu/links/variants/...  PTEN
# 1502        3426  https://civic.genome.wustl.edu/links/variants/...  EZH2
# 1503        3427  https://civic.genome.wustl.edu/links/variants/...  EZH2
# 1504        3428  https://civic.genome.wustl.edu/links/variants/...  EZH2
# 1505        3432  https://civic.genome.wustl.edu/links/variants/...  BRAF
#
#       entrez_id        variant  \
# 0            25        BCR-ABL
# ...

# %%
df = pd.merge(df, df65, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/2935822206.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'variant_id_x', 'summary_x', 'variant_x', 'Unnamed: 31_x', 'variant_civic_url_x', 'variant_groups_x', 'entrez_id_x', 'gene_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df65, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# 4              5.0  https://civic.genome.wustl.edu/#/events/genes/...    ALK
# ...            ...                                                ...    ...
# ...

# %%
df66 = pd.read_csv('01-Oct-2015-VariantSummaries.csv')
df66
# Out:
#       gene  entrez_id             variant  \
# 0     ABL1         25             BCR-ABL
# 1     ABL1         25       BCR-ABL T315I
# 2     ABL1         25       BCR-ABL E255K
# 3     AKT1        207                E17K
# 4      ALK        238            EML4-ALK
# ..     ...        ...                 ...
# 204  NT5C2      22978               R367Q
# 205  NT5C2      22978               R359Q
# 206  NT5C2      22978               D407A
# 207   ABL1         25       BCR-ABL F317L
# 208   TP53       7157  DNA binding domain
#
#                                                summary  \
# 0    The BCR-ABL fusion protein, commonly referred ...
# 1    While the efficacy of imatinib has revolutioni...
# 2    While the efficacy of imatinib has revolutioni...
# 3    AKT1 E17K is a recurrent mutation that has bee...
# 4    The EML4-ALK fusion has been seen in non-small...
# ..                                                 ...
# 204                                                NaN
# ...

# %%
df = pd.merge(df, df66, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# 4              5.0  https://civic.genome.wustl.edu/#/events/genes/...    ALK
# ...            ...                                                ...    ...
# 2570           NaN                                                NaN    NaN
# 2571           NaN                                                NaN    NaN
# 2572           NaN                                                NaN    NaN
# 2573           NaN                                                NaN    NaN
# 2574           NaN                                                NaN    NaN
#
#       entrez_id_x      variant_x  \
# ...

# %%
df67 = pd.read_csv('01-Oct-2017-VariantSummaries.csv')
df67
# Out:
#       variant_id                                  variant_civic_url  gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1  ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2  ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3  ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4  AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5   ALK
# ...          ...                                                ...   ...
# 1722        2175  https://civic.genome.wustl.edu/links/variants/...   VHL
# 1723        2176  https://civic.genome.wustl.edu/links/variants/...   VHL
# 1724        2177  https://civic.genome.wustl.edu/links/variants/...   VHL
# 1725        2178  https://civic.genome.wustl.edu/links/variants/...  NRG1
# 1726        2179  https://civic.genome.wustl.edu/links/variants/...  NRG1
#
#       entrez_id             variant  \
# 0            25             BCR-ABL
# ...

# %%
df = pd.merge(df, df67, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/1067668094.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'chromosome2_x', 'variant_groups_x', 'hgvs_expressions_x', 'stop2_x', 'variant_types_x', 'chromosome_x', 'last_review_date_x', 'entrez_id_x', 'variant_bases_x', 'ensembl_version_x', 'gene_x', 'start_x', 'reference_build_x', 'summary_x', 'reference_bases_x', 'representative_transcript_x', 'start2_x', 'representative_transcript2_x', 'variant_x', 'stop_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df67, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# ...

# %%
df68 = pd.read_csv('01-Oct-2018-VariantSummaries.csv')
df68
# Out:
#       variant_id                                  variant_civic_url    gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1    ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2    ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3    ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4    AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5     ALK
# ...          ...                                                ...     ...
# 2071        2564  https://civic.genome.wustl.edu/links/variants/...     MYC
# 2072        2565  https://civic.genome.wustl.edu/links/variants/...  PTPN12
# 2073        2566  https://civic.genome.wustl.edu/links/variants/...    ABL1
# 2074        2567  https://civic.genome.wustl.edu/links/variants/...    ETV6
# 2075        2568  https://civic.genome.wustl.edu/links/variants/...     RET
#
#       entrez_id           variant  \
# ...

# %%
df = pd.merge(df, df8, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/223680818.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'variant_id_x', 'variant_civic_url_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df8, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# 4              5.0  https://civic.genome.wustl.edu/#/events/genes/...    ALK
# ...            ...                                                ...    ...
# 2570           NaN                                                NaN    NaN
# ...

# %%
df69 = pd.read_csv('01-Oct-2019-VariantSummaries.csv')
df69
# Out:
#       variant_id                                  variant_civic_url      gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1      ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2      ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3      ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4      AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5       ALK
# ...          ...                                                ...       ...
# 2313        2814  https://civic.genome.wustl.edu/links/variants/...      DRD5
# 2314        2815  https://civic.genome.wustl.edu/links/variants/...  HIST1H3B
# 2315        2816  https://civic.genome.wustl.edu/links/variants/...       ALK
# 2316        2817  https://civic.genome.wustl.edu/links/variants/...      FLT3
# 2317        2818  https://civic.genome.wustl.edu/links/variants/...       VHL
#
# ...

# %%
df = pd.merge(df, df69, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/4292370092.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'variant_aliases_x', 'chromosome2_x', 'Unnamed: 29_x', 'variant_groups_x', 'stop2_x', 'assertion_ids_x', 'hgvs_expressions_x', 'variant_types_x', 'chromosome_x', 'civic_variant_evidence_score_x', 'last_review_date_x', 'clinvar_ids_x', 'entrez_id_x', 'variant_bases_x', 'ensembl_version_x', 'gene_x', 'Unnamed: 30_x', 'start_x', 'reference_build_x', 'summary_x', 'variant_x', 'allele_registry_id_x', 'reference_bases_x', 'representative_transcript_x', 'start2_x', 'stop_x', 'assertion_civic_urls_x', 'representative_transcript2_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df69, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# ...

# %%
df70 = pd.read_csv('01-Oct-2020-VariantSummaries.csv')
df70
# Out:
#       variant_id                                  variant_civic_url   gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1   ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2   ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3   ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4   AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5    ALK
# ...          ...                                                ...    ...
# 1445        3075  https://civic.genome.wustl.edu/links/variants/...   FLT3
# 1446        3082  https://civic.genome.wustl.edu/links/variants/...   BCL2
# 1447        3158  https://civic.genome.wustl.edu/links/variants/...  NTRK2
# 1448        3200  https://civic.genome.wustl.edu/links/variants/...   KRAS
# 1449        3203  https://civic.genome.wustl.edu/links/variants/...   ATRX
#
#       entrez_id           variant  \
# ...

# %%
df = pd.merge(df, df70, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/3580959897.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'variant_id_x', 'Unnamed: 28_x', 'Unnamed: 31_x', 'variant_civic_url_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df70, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# 4              5.0  https://civic.genome.wustl.edu/#/events/genes/...    ALK
# ...            ...                                                ...    ...
# 2570           NaN                                                NaN    NaN
# ...

# %%
df71 = pd.read_csv('01-Oct-2021-VariantSummaries.csv')
df71
# Out:
#       variant_id                                  variant_civic_url  gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1  ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2  ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3  ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4  AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5   ALK
# ...          ...                                                ...   ...
# 1501        3382  https://civic.genome.wustl.edu/links/variants/...  PTEN
# 1502        3426  https://civic.genome.wustl.edu/links/variants/...  EZH2
# 1503        3427  https://civic.genome.wustl.edu/links/variants/...  EZH2
# 1504        3428  https://civic.genome.wustl.edu/links/variants/...  EZH2
# 1505        3432  https://civic.genome.wustl.edu/links/variants/...  BRAF
#
#       entrez_id        variant  \
# 0            25        BCR-ABL
# ...

# %%
df = pd.merge(df, df71, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/2016670448.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'variant_aliases_x', 'chromosome2_x', 'variant_groups_x', 'hgvs_expressions_x', 'stop2_x', 'assertion_ids_x', 'Unnamed: 29_x', 'variant_types_x', 'chromosome_x', 'last_review_date_x', 'civic_variant_evidence_score_x', 'clinvar_ids_x', 'entrez_id_x', 'variant_bases_x', 'ensembl_version_x', 'Unnamed: 32_x', 'gene_x', 'is_flagged_x', 'Unnamed: 30_x', 'start_x', 'reference_build_x', 'summary_x', 'variant_x', 'reference_bases_x', 'representative_transcript_x', 'start2_x', 'representative_transcript2_x', 'stop_x', 'allele_registry_id_x', 'assertion_civic_urls_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df71, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# ...

# %%
df72 = pd.read_csv('01-Sep-2015-VariantSummaries.csv')
df72
# Out:
#       gene  entrez_id           variant  \
# 0     ABL1         25           BCR-ABL
# 1     ABL1         25     BCR-ABL T315I
# 2     ABL1         25     BCR-ABL E255K
# 3     AKT1        207              E17K
# 4      ALK        238          EML4-ALK
# ..     ...        ...               ...
# 224  CHEK2      11200  LOSS-OF-FUNCTION
# 225  ERBB2       2064    OVEREXPRESSION
# 226   KRAS       3845  EXON 1 MUTATIONS
# 227     AR        367             F876L
# 228     AR        367              W741
#
#                                                summary  \
# 0    The BCR-ABL fusion protein, commonly referred ...
# 1    While the efficacy of imatinib has revolutioni...
# 2    While the efficacy of imatinib has revolutioni...
# 3    AKT1 E17K is a recurrent mutation that has bee...
# 4    The EML4-ALK fusion has been seen in non-small...
# ..                                                 ...
# 224                                                NaN
# ...

# %%
df = pd.merge(df, df72, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# 4              5.0  https://civic.genome.wustl.edu/#/events/genes/...    ALK
# ...            ...                                                ...    ...
# 2570           NaN                                                NaN    NaN
# 2571           NaN                                                NaN    NaN
# 2572           NaN                                                NaN    NaN
# 2573           NaN                                                NaN    NaN
# 2574           NaN                                                NaN    NaN
#
#       entrez_id_x      variant_x  \
# ...

# %%
df73 = pd.read_csv('01-Sep-2017-VariantSummaries.csv')
df73
# Out:
#       variant_id                                  variant_civic_url    gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1    ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2    ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3    ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4    AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5     ALK
# ...          ...                                                ...     ...
# 1711        2164  https://civic.genome.wustl.edu/links/variants/...  CX3CL1
# 1712        2165  https://civic.genome.wustl.edu/links/variants/...   FANCA
# 1713        2166  https://civic.genome.wustl.edu/links/variants/...    NRG1
# 1714        2167  https://civic.genome.wustl.edu/links/variants/...   FGFR4
# 1715        2168  https://civic.genome.wustl.edu/links/variants/...   RAD50
#
#       entrez_id          variant  \
# ...

# %%
df = pd.merge(df, df73, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/1112574295.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'variant_id_x', 'summary_x', 'variant_x', 'variant_civic_url_x', 'variant_groups_x', 'entrez_id_x', 'gene_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df73, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# 4              5.0  https://civic.genome.wustl.edu/#/events/genes/...    ALK
# ...            ...                                                ...    ...
# ...

# %%
df74 = pd.read_csv('01-Sep-2019-VariantSummaries.csv')
df74
# Out:
#       variant_id                                  variant_civic_url   gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1   ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2   ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3   ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4   AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5    ALK
# ...          ...                                                ...    ...
# 2281        2782  https://civic.genome.wustl.edu/links/variants/...    TEK
# 2282        2783  https://civic.genome.wustl.edu/links/variants/...  FGF19
# 2283        2784  https://civic.genome.wustl.edu/links/variants/...  FGF19
# 2284        2785  https://civic.genome.wustl.edu/links/variants/...   FLT3
# 2285        2786  https://civic.genome.wustl.edu/links/variants/...   TP53
#
#       entrez_id         variant  \
# 0            25         BCR-ABL
# ...

# %%
df = pd.merge(df, df74, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/4096991336.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'reference_build_x', 'chromosome_x', 'last_review_date_x', 'reference_bases_x', 'representative_transcript_x', 'Unnamed: 31_x', 'chromosome2_x', 'start2_x', 'stop_x', 'stop2_x', 'representative_transcript2_x', 'hgvs_expressions_x', 'variant_types_x', 'variant_bases_x', 'ensembl_version_x', 'start_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df74, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# ...

# %%
df75 = pd.read_csv('01-Sep-2020-VariantSummaries.csv')
df75
# Out:
#       variant_id                                  variant_civic_url   gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1   ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2   ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3   ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4   AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5    ALK
# ...          ...                                                ...    ...
# 1433        3051  https://civic.genome.wustl.edu/links/variants/...    ATM
# 1434        3070  https://civic.genome.wustl.edu/links/variants/...   FLT3
# 1435        3075  https://civic.genome.wustl.edu/links/variants/...   FLT3
# 1436        3158  https://civic.genome.wustl.edu/links/variants/...  NTRK2
# 1437        3200  https://civic.genome.wustl.edu/links/variants/...   KRAS
#
#       entrez_id        variant  \
# 0            25        BCR-ABL
# ...

# %%
df = pd.merge(df, df75, right_index=True, left_index=True, how = 'outer')

df.to_csv('df.csv', index=False)

df
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/1198050818.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'variant_aliases_x', 'civic_variant_evidence_score_x', 'Unnamed: 30_x', 'variant_id_x', 'summary_x', 'clinvar_ids_x', 'variant_x', 'allele_registry_id_x', 'variant_civic_url_x', 'variant_groups_x', 'Unnamed: 29_x', 'assertion_ids_x', 'assertion_civic_urls_x', 'entrez_id_x', 'Unnamed: 28_x', 'gene_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = pd.merge(df, df75, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# ...

# %%
df76 = pd.read_csv('01-Sep-2021-VariantSummaries.csv')
df76
# Out:
#       variant_id                                  variant_civic_url  gene  \
# 0              1    https://civic.genome.wustl.edu/links/variants/1  ABL1
# 1              2    https://civic.genome.wustl.edu/links/variants/2  ABL1
# 2              3    https://civic.genome.wustl.edu/links/variants/3  ABL1
# 3              4    https://civic.genome.wustl.edu/links/variants/4  AKT1
# 4              5    https://civic.genome.wustl.edu/links/variants/5   ALK
# ...          ...                                                ...   ...
# 1501        3382  https://civic.genome.wustl.edu/links/variants/...  PTEN
# 1502        3426  https://civic.genome.wustl.edu/links/variants/...  EZH2
# 1503        3427  https://civic.genome.wustl.edu/links/variants/...  EZH2
# 1504        3428  https://civic.genome.wustl.edu/links/variants/...  EZH2
# 1505        3432  https://civic.genome.wustl.edu/links/variants/...  BRAF
#
#       entrez_id        variant  \
# 0            25        BCR-ABL
# ...

# %%
dfVariants = pd.merge(df, df76, right_index=True, left_index=True, how = 'outer')

dfVariants.to_csv('df_Variant.csv', index=False)

dfVariants
# Out:
# C:\Users\positivo\AppData\Local\Temp/ipykernel_15300/1798777909.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'reference_build_x', 'chromosome_x', 'last_review_date_x', 'reference_bases_x', 'representative_transcript_x', 'chromosome2_x', 'start2_x', 'representative_transcript2_x', 'stop_x', 'stop2_x', 'hgvs_expressions_x', 'Unnamed: 31_x', 'variant_types_x', 'variant_bases_x', 'ensembl_version_x', 'start_x'} in the result is deprecated and will raise a MergeError in a future version.
#   dfVariants = pd.merge(df, df76, right_index=True, left_index=True, how = 'outer')
#       variant_id_x                                variant_civic_url_x gene_x  \
# 0              1.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 1              2.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 2              3.0  https://civic.genome.wustl.edu/#/events/genes/...   ABL1
# 3              4.0  https://civic.genome.wustl.edu/#/events/genes/...   AKT1
# ...
